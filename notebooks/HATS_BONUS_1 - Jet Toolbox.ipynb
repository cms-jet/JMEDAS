# %% [markdown]
# Most jet tools are incorporated into CMSSW via the [JetToolbox](https://twiki.cern.ch/twiki/bin/view/CMS/JetToolbox). General information can be found on the previous link.
#
# A config file `Analysis/JMEDAS/scripts/ClusterWithToolboxAndMakeHistos.py` has been provided which uses the jet toolbox to produce three additional jet collections. Take a look at this file and you will see:
#
# ```python
# from Analysis.JetToolbox.jetToolbox_cff import *
#
# # AK R=0.4 jets from CHS inputs with basic grooming, W tagging, and top tagging
# jetToolbox( process, 'ak4', 'ak4JetSubs', 'out',
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   addTrimming=True, addFiltering=True,
#   addSoftDropSubjets=True,
#   addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
#   JETCorrPayload = 'AK4PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # AK R=0.8 jets from CHS inputs with basic grooming, W tagging, and top tagging
# jetToolbox( process, 'ak8', 'ak8JetSubs', 'out',
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   addTrimming=True, addFiltering=True,
#   addSoftDropSubjets=True,
#   addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # AK R=0.8 from PUPPI inputs with basic grooming, W tagging, and top tagging
# jetToolbox( process, 'ak8', 'ak8JetSubs', 'out',
#   PUMethod='Puppi',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   addTrimming=True, addFiltering=True,
#   addSoftDropSubjets=True,
#   addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
#   JETCorrPayload = 'AK8PFPuppi', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # CA R=0.8 jets from CHS inputs with basic grooming, W tagging, and top tagging
# jetToolbox( process, 'ca8', 'ca8JetSubs', 'out',
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   addTrimming=True, addFiltering=True,
#   addSoftDropSubjets=True,
#   addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # KT R=0.8 jets from CHS inputs with basic grooming, W tagging, and top tagging
# jetToolbox( process, 'kt8', 'kt8JetSubs', 'out',
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   addTrimming=True, addFiltering=True,
#   addSoftDropSubjets=True,
#   addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # AK R=1.2 jets from CHS inputs with basic grooming, W tagging, and top tagging
# jetToolbox( process, 'ak12', 'ak12JetSubs', 'out',
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   addTrimming=True, addFiltering=True,
#   addSoftDropSubjets=True,
#   addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # AK R=1.5 jets from CHS inputs with basic grooming, W tagging, and top tagging
# jetToolbox( process, 'ak15', 'ak15JetSubs', 'out',
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   addTrimming=True, addFiltering=True,
#   addSoftDropSubjets=True,
#   addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# ```
#
# The snippet above first imports the jet toolbox. Then it configures the jet toolbox to produce various new jet collections which are not in the miniAOD by default. What parameters are varied for each jet collection?
#
# You can run the config file via:

# %%
import os
import sys

##### REMEMBER TO MANUALLY COPY THE PROXY TO THE TMP FOLDER AND TO MODIFY THE NEXT LINE
os.environ['X509_USER_PROXY'] = '/eos/home-a/algomez/tmp/x509up_u15148'
if os.path.isfile(os.environ['X509_USER_PROXY']): pass
else: print("os.environ['X509_USER_PROXY'] ",os.environ['X509_USER_PROXY'])
os.environ['X509_CERT_DIR'] = '/cvmfs/cms.cern.ch/grid/etc/grid-security/certificates'
os.environ['X509_VOMS_DIR'] = '/cvmfs/cms.cern.ch/grid/etc/grid-security/vomsdir'

# %%
# %%bash
# cmsRun $CMSSW_BASE/src/Analysis/JMEDAS/scripts/ClusterWithToolboxAndMakeHistos.py
# Out:
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the jet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK4 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK4PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsAK4PFCHSSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ak4PFJetsCHSSoftDropMass, selectedPatJetsAK4PFCHSSoftDropPacked:SubJets, ak4PFJetsCHSPrunedMass, ak4PFJetsCHSTrimmedMass, ak4PFJetsCHSFilteredMass, NjettinessAK4CHS.
# |---- jetToolBox: Creating selectedPatJetsAK4PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags'] in the jet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK8 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsAK8PFCHSSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ak8PFJetsCHSSoftDropMass, selectedPatJetsAK8PFCHSSoftDropPacked:SubJets, ak8PFJetsCHSPrunedMass, ak8PFJetsCHSTrimmedMass, ak8PFJetsCHSFilteredMass, NjettinessAK8CHS.
# |---- jetToolBox: Creating selectedPatJetsAK8PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags'] in the jet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK8 JETS USING Puppi
# |---- jetToolBox: Applying these corrections: ('AK8PFPuppi', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsAK8PFPuppiSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ak8PFJetsPuppiSoftDropMass, selectedPatJetsAK8PFPuppiSoftDropPacked:SubJets, ak8PFJetsPuppiPrunedMass, ak8PFJetsPuppiTrimmedMass, ak8PFJetsPuppiFilteredMass, NjettinessAK8Puppi.
# |---- jetToolBox: Creating selectedPatJetsAK8PFPuppi collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags'] in the jet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR CA8 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsCA8PFCHSSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ca8PFJetsCHSSoftDropMass, selectedPatJetsCA8PFCHSSoftDropPacked:SubJets, ca8PFJetsCHSPrunedMass, ca8PFJetsCHSTrimmedMass, ca8PFJetsCHSFilteredMass, NjettinessCA8CHS.
# |---- jetToolBox: Creating selectedPatJetsCA8PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: CMS recommends the following jet algorithms: ak4 ak8 ca4 ca8 ca10 ca15. You are using kt8 .
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags'] in the jet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR KT8 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsKT8PFCHSSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running kt8PFJetsCHSSoftDropMass, selectedPatJetsKT8PFCHSSoftDropPacked:SubJets, kt8PFJetsCHSPrunedMass, kt8PFJetsCHSTrimmedMass, kt8PFJetsCHSFilteredMass, NjettinessKT8CHS.
# |---- jetToolBox: Creating selectedPatJetsKT8PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: CMS recommends the following jet algorithms: ak4 ak8 ca4 ca8 ca10 ca15. You are using ak12 .
# |---- jetToolBox: btag discriminators are recommended for AK4 and AK8 jets. For a different cone size, please especify the discriminators. Turning OFF all the default btag discriminators.
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK12 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsAK12PFCHSSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ak12PFJetsCHSSoftDropMass, selectedPatJetsAK12PFCHSSoftDropPacked:SubJets, ak12PFJetsCHSPrunedMass, ak12PFJetsCHSTrimmedMass, ak12PFJetsCHSFilteredMass, NjettinessAK12CHS.
# |---- jetToolBox: Creating selectedPatJetsAK12PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: CMS recommends the following jet algorithms: ak4 ak8 ca4 ca8 ca10 ca15. You are using ak15 .
# |---- jetToolBox: btag discriminators are recommended for AK4 and AK8 jets. For a different cone size, please especify the discriminators. Turning OFF all the default btag discriminators.
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK15 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsAK15PFCHSSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ak15PFJetsCHSSoftDropMass, selectedPatJetsAK15PFCHSSoftDropPacked:SubJets, ak15PFJetsCHSPrunedMass, ak15PFJetsCHSTrimmedMass, ak15PFJetsCHSFilteredMass, NjettinessAK15CHS.
# |---- jetToolBox: Creating selectedPatJetsAK15PFCHS collection.
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# 20-Aug-2020 16:25:40 CEST  Initiating request to open file root://eoscms.cern.ch//eos/cms/store/mc/RunIIFall17MiniAODv2/ZprimeToTT_M3000_W300_TuneCP2_13TeV-madgraphMLM-pythia8/MINIAODSIM/PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/80000/0C8FF51D-9A26-E911-A64C-24BE05C626B1.root
# %MSG-w XrdAdaptorInternal:  file_open 20-Aug-2020 16:25:42 CEST pre-events
# Failed to open file at URL root://eoscms.cern.ch:1094//eos/cms/store/mc/RunIIFall17MiniAODv2/ZprimeToTT_M3000_W300_TuneCP2_13TeV-madgraphMLM-pythia8/MINIAODSIM/PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/80000/0C8FF51D-9A26-E911-A64C-24BE05C626B1.root.
# %MSG
# %MSG-w XrdAdaptorInternal:  file_open 20-Aug-2020 16:25:42 CEST pre-events
# Failed to open file at URL root://eoscms.cern.ch:1094//eos/cms/store/mc/RunIIFall17MiniAODv2/ZprimeToTT_M3000_W300_TuneCP2_13TeV-madgraphMLM-pythia8/MINIAODSIM/PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/80000/0C8FF51D-9A26-E911-A64C-24BE05C626B1.root?tried=.
# %MSG
# 20-Aug-2020 16:25:42 CEST  Fallback request to file root://xrootd-cms.infn.it//store/mc/RunIIFall17MiniAODv2/ZprimeToTT_M3000_W300_TuneCP2_13TeV-madgraphMLM-pythia8/MINIAODSIM/PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/80000/0C8FF51D-9A26-E911-A64C-24BE05C626B1.root
# %MSG-w XrdAdaptor:  file_open 20-Aug-2020 16:25:57 CEST pre-events
# Data is served from T2_US_Purdue instead of original site T2_IT_Pisa
# %MSG
# 20-Aug-2020 16:25:59 CEST  Successfully opened file root://xrootd-cms.infn.it//store/mc/RunIIFall17MiniAODv2/ZprimeToTT_M3000_W300_TuneCP2_13TeV-madgraphMLM-pythia8/MINIAODSIM/PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/80000/0C8FF51D-9A26-E911-A64C-24BE05C626B1.root
# Begin processing the 1st record. Run 1, Event 5827, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:17.894 CEST
# Begin processing the 2nd record. Run 1, Event 5832, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:45.508 CEST
# Begin processing the 3rd record. Run 1, Event 5824, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:46.904 CEST
# Begin processing the 4th record. Run 1, Event 5816, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:48.229 CEST
# Begin processing the 5th record. Run 1, Event 5836, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:49.802 CEST
# Begin processing the 6th record. Run 1, Event 5822, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:50.983 CEST
# Begin processing the 7th record. Run 1, Event 5818, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:52.631 CEST
# Begin processing the 8th record. Run 1, Event 5820, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:53.684 CEST
# Begin processing the 9th record. Run 1, Event 5835, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:55.134 CEST
# Begin processing the 10th record. Run 1, Event 5809, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:56.493 CEST
# Begin processing the 11th record. Run 1, Event 5848, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:57.968 CEST
# Begin processing the 12th record. Run 1, Event 5821, LumiSection 3 on stream 0 at 20-Aug-2020 16:26:59.429 CEST
# Begin processing the 13th record. Run 1, Event 5841, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:00.820 CEST
# Begin processing the 14th record. Run 1, Event 5866, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:02.431 CEST
# Begin processing the 15th record. Run 1, Event 5874, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:03.579 CEST
# Begin processing the 16th record. Run 1, Event 5889, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:04.797 CEST
# Begin processing the 17th record. Run 1, Event 5826, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:06.206 CEST
# Begin processing the 18th record. Run 1, Event 5892, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:08.271 CEST
# Begin processing the 19th record. Run 1, Event 5865, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:09.537 CEST
# Begin processing the 20th record. Run 1, Event 5855, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:11.362 CEST
# Begin processing the 21st record. Run 1, Event 5831, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:13.074 CEST
# Begin processing the 22nd record. Run 1, Event 5869, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:18.608 CEST
# Begin processing the 23rd record. Run 1, Event 5891, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:19.785 CEST
# Begin processing the 24th record. Run 1, Event 5860, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:21.017 CEST
# Begin processing the 25th record. Run 1, Event 5899, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:22.512 CEST
# Begin processing the 26th record. Run 1, Event 5895, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:23.964 CEST
# Begin processing the 27th record. Run 1, Event 5859, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:25.528 CEST
# Begin processing the 28th record. Run 1, Event 5898, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:27.370 CEST
# Begin processing the 29th record. Run 1, Event 5893, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:28.741 CEST
# Begin processing the 30th record. Run 1, Event 5896, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:30.115 CEST
# Begin processing the 31st record. Run 1, Event 5901, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:31.465 CEST
# Begin processing the 32nd record. Run 1, Event 5906, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:32.963 CEST
# Begin processing the 33rd record. Run 1, Event 5916, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:34.399 CEST
# Begin processing the 34th record. Run 1, Event 5868, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:35.853 CEST
# Begin processing the 35th record. Run 1, Event 5904, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:37.451 CEST
# Begin processing the 36th record. Run 1, Event 5908, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:38.623 CEST
# Begin processing the 37th record. Run 1, Event 5932, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:39.828 CEST
# Begin processing the 38th record. Run 1, Event 5936, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:41.099 CEST
# Begin processing the 39th record. Run 1, Event 5913, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:42.343 CEST
# Begin processing the 40th record. Run 1, Event 5915, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:43.734 CEST
# Begin processing the 41st record. Run 1, Event 5934, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:45.393 CEST
# Begin processing the 42nd record. Run 1, Event 5921, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:46.822 CEST
# Begin processing the 43rd record. Run 1, Event 5920, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:48.688 CEST
# Begin processing the 44th record. Run 1, Event 5958, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:50.557 CEST
# Begin processing the 45th record. Run 1, Event 5903, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:51.521 CEST
# Begin processing the 46th record. Run 1, Event 5961, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:53.366 CEST
# Begin processing the 47th record. Run 1, Event 5967, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:54.994 CEST
# Begin processing the 48th record. Run 1, Event 5938, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:56.218 CEST
# %MSG-w FreeTrajectoryState:   InclusiveCandidateVertexFinder:inclusiveCandidateVertexFinderCvsL  20-Aug-2020 16:27:56 CEST Run: 1 Event: 5938
# (was exception) FreeTrajectoryState: attempt to access errors when none available
# Curvilinear error valid/values :0
# [ -2.40264e+17-2.29014e+17  1.8559e+13-4.96874e-06-7.03562e-06
#   -2.29014e+17-2.13976e+17 1.73406e+13-4.64249e-06-6.57365e-06
#     1.8559e+13 1.73406e+13-7.69669e+12-5.73258e-07 3.24594e-08
#   -4.96874e-06-4.64249e-06-5.73258e-07 1.58902e-06-1.32387e-07
#   -7.03562e-06-6.57365e-06 3.24594e-08-1.32387e-07 2.17397e-06 ]
# %MSG
# %MSG-w FreeTrajectoryState:   InclusiveCandidateVertexFinder:inclusiveCandidateVertexFinderCvsL  20-Aug-2020 16:27:56 CEST Run: 1 Event: 5938
# (was exception) FreeTrajectoryState: attempt to access errors when none available
# Curvilinear error valid/values :0
# [ -6.29078e+17 4.72788e+17-5.43029e+13-1.46582e-05 0.000605335
#    4.72788e+17-3.51327e+17  2.9014e+13 1.08924e-05-0.000449822
#   -5.43029e+13  2.9014e+13-7.94775e+12-1.04431e-07 1.40229e-06
#   -1.46582e-05 1.08924e-05-1.04431e-07 2.32186e-07 -1.8175e-06
#    0.000605335-0.000449822 1.40229e-06 -1.8175e-06 7.45172e-05 ]
# %MSG
# Begin processing the 49th record. Run 1, Event 5917, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:57.702 CEST
# Begin processing the 50th record. Run 1, Event 5950, LumiSection 3 on stream 0 at 20-Aug-2020 16:27:59.591 CEST
# Begin processing the 51st record. Run 1, Event 5980, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:01.128 CEST
# Begin processing the 52nd record. Run 1, Event 5975, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:02.194 CEST
# Begin processing the 53rd record. Run 1, Event 5981, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:03.607 CEST
# Begin processing the 54th record. Run 1, Event 5997, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:04.804 CEST
# Begin processing the 55th record. Run 1, Event 5990, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:05.995 CEST
# Begin processing the 56th record. Run 1, Event 5979, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:07.079 CEST
# Begin processing the 57th record. Run 1, Event 5962, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:08.529 CEST
# Begin processing the 58th record. Run 1, Event 6005, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:10.034 CEST
# Begin processing the 59th record. Run 1, Event 6023, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:11.454 CEST
# Begin processing the 60th record. Run 1, Event 5960, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:12.511 CEST
# Begin processing the 61st record. Run 1, Event 5993, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:14.120 CEST
# Begin processing the 62nd record. Run 1, Event 6006, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:15.420 CEST
# Begin processing the 63rd record. Run 1, Event 6000, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:16.812 CEST
# Begin processing the 64th record. Run 1, Event 6007, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:18.353 CEST
# Begin processing the 65th record. Run 1, Event 6027, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:19.596 CEST
# Begin processing the 66th record. Run 1, Event 6030, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:20.864 CEST
# Begin processing the 67th record. Run 1, Event 6044, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:21.852 CEST
# Begin processing the 68th record. Run 1, Event 6017, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:22.817 CEST
# Begin processing the 69th record. Run 1, Event 6038, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:24.268 CEST
# Begin processing the 70th record. Run 1, Event 6037, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:25.516 CEST
# Begin processing the 71st record. Run 1, Event 6028, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:26.584 CEST
# Begin processing the 72nd record. Run 1, Event 6008, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:28.090 CEST
# Begin processing the 73rd record. Run 1, Event 6069, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:29.579 CEST
# Begin processing the 74th record. Run 1, Event 6043, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:30.677 CEST
# Begin processing the 75th record. Run 1, Event 6041, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:31.886 CEST
# Begin processing the 76th record. Run 1, Event 6053, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:33.345 CEST
# Begin processing the 77th record. Run 1, Event 6042, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:34.479 CEST
# Begin processing the 78th record. Run 1, Event 6062, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:36.181 CEST
# Begin processing the 79th record. Run 1, Event 6048, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:37.693 CEST
# %MSG-w FreeTrajectoryState:   InclusiveCandidateVertexFinder:inclusiveCandidateVertexFinderCvsL  20-Aug-2020 16:28:37 CEST Run: 1 Event: 6048
# (was exception) FreeTrajectoryState: attempt to access errors when none available
# Curvilinear error valid/values :0
# [ -1.99353e+16-9.18267e+13 3.15657e+15-4.90949e-05-7.84845e-07
#   -9.18267e+13 3.35965e+14-2.16869e+12 5.33312e-08 2.45633e-07
#    3.15657e+15-2.16869e+12-4.34721e+14 6.79915e-06 9.38858e-08
#   -4.90949e-05 5.33312e-08 6.79915e-06 0.000144841  3.9967e-06
#   -7.84845e-07 2.45633e-07 9.38858e-08  3.9967e-06 4.27142e-06 ]
# %MSG
# Begin processing the 80th record. Run 1, Event 6070, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:39.236 CEST
# Begin processing the 81st record. Run 1, Event 6094, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:40.334 CEST
# Begin processing the 82nd record. Run 1, Event 6063, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:41.728 CEST
# Begin processing the 83rd record. Run 1, Event 6059, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:43.097 CEST
# Begin processing the 84th record. Run 1, Event 6095, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:45.025 CEST
# Begin processing the 85th record. Run 1, Event 6075, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:45.768 CEST
# Begin processing the 86th record. Run 1, Event 6084, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:47.144 CEST
# Begin processing the 87th record. Run 1, Event 6082, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:48.791 CEST
# Begin processing the 88th record. Run 1, Event 6090, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:50.242 CEST
# Begin processing the 89th record. Run 1, Event 6107, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:51.853 CEST
# Begin processing the 90th record. Run 1, Event 6103, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:52.901 CEST
# Begin processing the 91st record. Run 1, Event 6121, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:54.174 CEST
# Begin processing the 92nd record. Run 1, Event 6081, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:55.675 CEST
# Begin processing the 93rd record. Run 1, Event 6055, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:57.329 CEST
# Begin processing the 94th record. Run 1, Event 6135, LumiSection 3 on stream 0 at 20-Aug-2020 16:28:59.293 CEST
# Begin processing the 95th record. Run 1, Event 6124, LumiSection 3 on stream 0 at 20-Aug-2020 16:29:00.645 CEST
# Begin processing the 96th record. Run 1, Event 6130, LumiSection 3 on stream 0 at 20-Aug-2020 16:29:02.020 CEST
# Begin processing the 97th record. Run 1, Event 6117, LumiSection 3 on stream 0 at 20-Aug-2020 16:29:03.388 CEST
# Begin processing the 98th record. Run 1, Event 6137, LumiSection 3 on stream 0 at 20-Aug-2020 16:29:05.253 CEST
# Begin processing the 99th record. Run 1, Event 6057, LumiSection 3 on stream 0 at 20-Aug-2020 16:29:06.836 CEST
# Begin processing the 100th record. Run 1, Event 6126, LumiSection 3 on stream 0 at 20-Aug-2020 16:29:08.847 CEST
# 20-Aug-2020 16:29:10 CEST  Closed file root://xrootd-cms.infn.it//store/mc/RunIIFall17MiniAODv2/ZprimeToTT_M3000_W300_TuneCP2_13TeV-madgraphMLM-pythia8/MINIAODSIM/PU2017_12Apr2018_94X_mc2017_realistic_v14-v1/80000/0C8FF51D-9A26-E911-A64C-24BE05C626B1.root
#
# =============================================
#
# MessageLogger Summary
#
#  type     category        sev    module        subroutine        count    total
#  ---- -------------------- -- ---------------- ----------------  -----    -----
#     1 FreeTrajectoryState  -w InclusiveCandida                       3        3
#     2 XrdAdaptor           -w file_open                              1        1
#     3 XrdAdaptorInternal   -w file_open                              2        2
#     4 fileAction           -s file_close                             1        1
#     5 fileAction           -s file_open                              3        3
#
#  type    category    Examples: run/evt        run/evt          run/evt
#  ---- -------------------- ---------------- ---------------- ----------------
#     1 FreeTrajectoryState  1/5938           1/5938           1/6048
#     2 XrdAdaptor           pre-events
#     3 XrdAdaptorInternal   pre-events       pre-events
#     4 fileAction           PostGlobalEndRun
#     5 fileAction           pre-events       pre-events       pre-events
#
# Severity    # Occurrences   Total Occurrences
# --------    -------------   -----------------
# Warning                 6                   6
# System                  4                   4
#
# dropped waiting message count 0

# %% [markdown]
# The config also runs an analyzer that produces histograms. The analyzer accesses each new jet collection as follows. Jet substructure variables are stored as "userFloats" associated with the `pat::Jet` object.
#
# ```c++
#   //--------------------------------------------------------------------------------------------
#   // AK R=0.8 CHS jets - from toolbox
#
#   edm::Handle<pat::JetCollection> AK8CHS;
#   iEvent.getByToken(ak8PFCHSjetToken_, AK8CHS);
#
#   edm::Handle<pat::JetCollection> AK8CHSsub;
#   iEvent.getByToken(ak8PFCHSSoftDropSubjetsToken_, AK8CHSsub);
#
#   int count_AK8CHS = 0;
#   for (const pat::Jet &ijet : *AK8CHS) {
#     count_AK8CHS++;
#     if (count_AK8CHS>=2) break;
#     double pt           = ijet.pt();
#     double mass         = ijet.mass();
#     double rapidity     = ijet.rapidity();
#     double prunedMass   = ijet.userFloat("ak8PFJetsCHSPrunedMass");
#     double trimmedMass  = ijet.userFloat("ak8PFJetsCHSTrimmedMass");
#     double filteredMass = ijet.userFloat("ak8PFJetsCHSFilteredMass");
#     double softDropMass = ijet.userFloat("ak8PFJetsCHSSoftDropMass");
#     double tau1         = ijet.userFloat("NjettinessAK8CHS:tau1");
#     double tau2         = ijet.userFloat("NjettinessAK8CHS:tau2");
#     double tau3         = ijet.userFloat("NjettinessAK8CHS:tau3");
#     double tau4         = ijet.userFloat("NjettinessAK8CHS:tau4");
#     double ndau         = ijet.numberOfDaughters();
#     double tau21 = 99;
#     double tau32 = 99;
#     if (tau1!=0) tau21 = tau2/tau1;
#     if (tau2!=0) tau32 = tau3/tau2;
#
#     double mostMassiveSDsubjetMass = 0;
#     for (const pat::Jet &isub : *AK8CHSsub) {
#       double subjetEta      = isub.eta();
#       double subjetPhi      = isub.phi();
#       double subjetMass     = isub.mass();
#       double deltaRsubjetJet = deltaR(ijet.eta(), ijet.phi(), subjetEta, subjetPhi);
#       if (deltaRsubjetJet<0.8){
#         if (verbose) cout<<"matched subjet with mass "<< subjetMass<<endl;
#         if (subjetMass > mostMassiveSDsubjetMass) mostMassiveSDsubjetMass = subjetMass;
#       }
#     }
#   }
# ```
#
# Exercise: compare the histograms stored in the output root file.
# * How does the jet area compare for CA, KT, AK R=0.8 jets?
# * How does the jet mass compare for jets of different radius?
# * At what pT do AK8 top jets merge? How about AK12?
#
# To help you get started, we'll open the file, list the histograms available, and plot a few of them.

# %%
import ROOT
f = ROOT.TFile.Open("JetClusterHistos_ZP3.root")
fdir = f.Get("ana")
fdir.ls()
# Out:
# TDirectoryFile*		ana	ana
#  KEY: TH1D	h_ak4chs_pt;1
#  KEY: TH1D	h_ak4chs_mass;1
#  KEY: TH1D	h_ak4chs_rapidity;1
#  KEY: TH1D	h_ak4chs_prunedMass;1
#  KEY: TH1D	h_ak4chs_trimmedMass;1
#  KEY: TH1D	h_ak4chs_filteredMass;1
#  KEY: TH1D	h_ak4chs_softDropMass;1
#  KEY: TH1D	h_ak4chs_tau1;1
#  KEY: TH1D	h_ak4chs_tau2;1
#  KEY: TH1D	h_ak4chs_tau3;1
#  KEY: TH1D	h_ak4chs_tau4;1
#  KEY: TH1D	h_ak4chs_tau32;1
#  KEY: TH1D	h_ak4chs_tau21;1
#  KEY: TH1D	h_ak4chs_ndau;1
#  KEY: TH1D	h_ak4chs_subjetMass;1
#  KEY: TH1D	h_ak4chs_area;1
#  KEY: TH1D	h_ak4chs_pt200_mass;1
#  KEY: TH1D	h_ak4chs_pt200_prunedMass;1
#  KEY: TH1D	h_ak4chs_pt200_trimmedMass;1
#  KEY: TH1D	h_ak4chs_pt200_filteredMass;1
#  KEY: TH1D	h_ak4chs_pt200_softDropMass;1
#  KEY: TH1D	h_ak4chs_pt200_tau32;1
#  KEY: TH1D	h_ak4chs_pt200_tau21;1
#  KEY: TH1D	h_ak4chs_pt200_subjetMass;1
#  KEY: TH1D	h_ak4chs_pt500_mass;1
#  KEY: TH1D	h_ak4chs_pt500_prunedMass;1
#  KEY: TH1D	h_ak4chs_pt500_trimmedMass;1
#  KEY: TH1D	h_ak4chs_pt500_filteredMass;1
#  KEY: TH1D	h_ak4chs_pt500_softDropMass;1
#  KEY: TH1D	h_ak4chs_pt500_tau32;1
#  KEY: TH1D	h_ak4chs_pt500_tau21;1
#  KEY: TH1D	h_ak4chs_pt500_subjetMass;1
#  KEY: TH1D	h_ak8pf_pt;1
#  KEY: TH1D	h_ak8pf_mass;1
#  KEY: TH1D	h_ak8pf_rapidity;1
#  KEY: TH1D	h_ak8pf_prunedMass;1
#  KEY: TH1D	h_ak8pf_trimmedMass;1
#  KEY: TH1D	h_ak8pf_filteredMass;1
#  KEY: TH1D	h_ak8pf_softDropMass;1
#  KEY: TH1D	h_ak8pf_tau1;1
#  KEY: TH1D	h_ak8pf_tau2;1
#  KEY: TH1D	h_ak8pf_tau3;1
#  KEY: TH1D	h_ak8pf_tau4;1
#  KEY: TH1D	h_ak8pf_tau32;1
#  KEY: TH1D	h_ak8pf_tau21;1
#  KEY: TH1D	h_ak8pf_ndau;1
#  KEY: TH1D	h_ak8pf_subjetMass;1
#  KEY: TH1D	h_ak8pf_area;1
#  KEY: TH1D	h_ak8pf_pt200_mass;1
#  KEY: TH1D	h_ak8pf_pt200_prunedMass;1
#  KEY: TH1D	h_ak8pf_pt200_trimmedMass;1
#  KEY: TH1D	h_ak8pf_pt200_filteredMass;1
#  KEY: TH1D	h_ak8pf_pt200_softDropMass;1
#  KEY: TH1D	h_ak8pf_pt200_tau32;1
#  KEY: TH1D	h_ak8pf_pt200_tau21;1
#  KEY: TH1D	h_ak8pf_pt200_subjetMass;1
#  KEY: TH1D	h_ak8pf_pt500_mass;1
#  KEY: TH1D	h_ak8pf_pt500_prunedMass;1
#  KEY: TH1D	h_ak8pf_pt500_trimmedMass;1
#  KEY: TH1D	h_ak8pf_pt500_filteredMass;1
#  KEY: TH1D	h_ak8pf_pt500_softDropMass;1
#  KEY: TH1D	h_ak8pf_pt500_tau32;1
#  KEY: TH1D	h_ak8pf_pt500_tau21;1
#  KEY: TH1D	h_ak8pf_pt500_subjetMass;1
#  KEY: TH1D	h_ak8chs_pt;1
#  KEY: TH1D	h_ak8chs_mass;1
#  KEY: TH1D	h_ak8chs_rapidity;1
#  KEY: TH1D	h_ak8chs_prunedMass;1
#  KEY: TH1D	h_ak8chs_trimmedMass;1
#  KEY: TH1D	h_ak8chs_filteredMass;1
#  KEY: TH1D	h_ak8chs_softDropMass;1
#  KEY: TH1D	h_ak8chs_tau1;1
#  KEY: TH1D	h_ak8chs_tau2;1
#  KEY: TH1D	h_ak8chs_tau3;1
#  KEY: TH1D	h_ak8chs_tau4;1
#  KEY: TH1D	h_ak8chs_tau32;1
#  KEY: TH1D	h_ak8chs_tau21;1
#  KEY: TH1D	h_ak8chs_ndau;1
#  KEY: TH1D	h_ak8chs_subjetMass;1
#  KEY: TH1D	h_ak8chs_area;1
#  KEY: TH1D	h_ak8chs_pt200_mass;1
#  KEY: TH1D	h_ak8chs_pt200_prunedMass;1
#  KEY: TH1D	h_ak8chs_pt200_trimmedMass;1
#  KEY: TH1D	h_ak8chs_pt200_filteredMass;1
#  KEY: TH1D	h_ak8chs_pt200_softDropMass;1
#  KEY: TH1D	h_ak8chs_pt200_tau32;1
#  KEY: TH1D	h_ak8chs_pt200_tau21;1
#  KEY: TH1D	h_ak8chs_pt200_subjetMass;1
#  KEY: TH1D	h_ak8chs_pt500_mass;1
#  KEY: TH1D	h_ak8chs_pt500_prunedMass;1
#  KEY: TH1D	h_ak8chs_pt500_trimmedMass;1
#  KEY: TH1D	h_ak8chs_pt500_filteredMass;1
#  KEY: TH1D	h_ak8chs_pt500_softDropMass;1
#  KEY: TH1D	h_ak8chs_pt500_tau32;1
#  KEY: TH1D	h_ak8chs_pt500_tau21;1
#  KEY: TH1D	h_ak8chs_pt500_subjetMass;1
#  KEY: TH1D	h_ak8puppi_pt;1
#  KEY: TH1D	h_ak8puppi_mass;1
#  KEY: TH1D	h_ak8puppi_rapidity;1
#  KEY: TH1D	h_ak8puppi_prunedMass;1
#  KEY: TH1D	h_ak8puppi_trimmedMass;1
#  KEY: TH1D	h_ak8puppi_filteredMass;1
#  KEY: TH1D	h_ak8puppi_softDropMass;1
#  KEY: TH1D	h_ak8puppi_tau1;1
#  KEY: TH1D	h_ak8puppi_tau2;1
#  KEY: TH1D	h_ak8puppi_tau3;1
#  KEY: TH1D	h_ak8puppi_tau4;1
#  KEY: TH1D	h_ak8puppi_tau32;1
#  KEY: TH1D	h_ak8puppi_tau21;1
#  KEY: TH1D	h_ak8puppi_ndau;1
#  KEY: TH1D	h_ak8puppi_subjetMass;1
#  KEY: TH1D	h_ak8puppi_area;1
#  KEY: TH1D	h_ak8puppi_pt200_mass;1
#  KEY: TH1D	h_ak8puppi_pt200_prunedMass;1
#  KEY: TH1D	h_ak8puppi_pt200_trimmedMass;1
#  KEY: TH1D	h_ak8puppi_pt200_filteredMass;1
#  KEY: TH1D	h_ak8puppi_pt200_softDropMass;1
#  KEY: TH1D	h_ak8puppi_pt200_tau32;1
#  KEY: TH1D	h_ak8puppi_pt200_tau21;1
#  KEY: TH1D	h_ak8puppi_pt200_subjetMass;1
#  KEY: TH1D	h_ak8puppi_pt500_mass;1
#  KEY: TH1D	h_ak8puppi_pt500_prunedMass;1
#  KEY: TH1D	h_ak8puppi_pt500_trimmedMass;1
#  KEY: TH1D	h_ak8puppi_pt500_filteredMass;1
#  KEY: TH1D	h_ak8puppi_pt500_softDropMass;1
#  KEY: TH1D	h_ak8puppi_pt500_tau32;1
#  KEY: TH1D	h_ak8puppi_pt500_tau21;1
#  KEY: TH1D	h_ak8puppi_pt500_subjetMass;1
#  KEY: TH1D	h_kt8chs_pt;1
#  KEY: TH1D	h_kt8chs_mass;1
#  KEY: TH1D	h_kt8chs_rapidity;1
#  KEY: TH1D	h_kt8chs_prunedMass;1
#  KEY: TH1D	h_kt8chs_trimmedMass;1
#  KEY: TH1D	h_kt8chs_filteredMass;1
#  KEY: TH1D	h_kt8chs_softDropMass;1
#  KEY: TH1D	h_kt8chs_tau1;1
#  KEY: TH1D	h_kt8chs_tau2;1
#  KEY: TH1D	h_kt8chs_tau3;1
#  KEY: TH1D	h_kt8chs_tau4;1
#  KEY: TH1D	h_kt8chs_tau32;1
#  KEY: TH1D	h_kt8chs_tau21;1
#  KEY: TH1D	h_kt8chs_ndau;1
#  KEY: TH1D	h_kt8chs_subjetMass;1
#  KEY: TH1D	h_kt8chs_area;1
#  KEY: TH1D	h_kt8chs_pt200_mass;1
#  KEY: TH1D	h_kt8chs_pt200_prunedMass;1
#  KEY: TH1D	h_kt8chs_pt200_trimmedMass;1
#  KEY: TH1D	h_kt8chs_pt200_filteredMass;1
#  KEY: TH1D	h_kt8chs_pt200_softDropMass;1
#  KEY: TH1D	h_kt8chs_pt200_tau32;1
#  KEY: TH1D	h_kt8chs_pt200_tau21;1
#  KEY: TH1D	h_kt8chs_pt200_subjetMass;1
#  KEY: TH1D	h_kt8chs_pt500_mass;1
#  KEY: TH1D	h_kt8chs_pt500_prunedMass;1
#  KEY: TH1D	h_kt8chs_pt500_trimmedMass;1
#  KEY: TH1D	h_kt8chs_pt500_filteredMass;1
#  KEY: TH1D	h_kt8chs_pt500_softDropMass;1
#  KEY: TH1D	h_kt8chs_pt500_tau32;1
#  KEY: TH1D	h_kt8chs_pt500_tau21;1
#  KEY: TH1D	h_kt8chs_pt500_subjetMass;1
#  KEY: TH1D	h_ca8chs_pt;1
#  KEY: TH1D	h_ca8chs_mass;1
#  KEY: TH1D	h_ca8chs_rapidity;1
#  KEY: TH1D	h_ca8chs_prunedMass;1
#  KEY: TH1D	h_ca8chs_trimmedMass;1
#  KEY: TH1D	h_ca8chs_filteredMass;1
#  KEY: TH1D	h_ca8chs_softDropMass;1
#  KEY: TH1D	h_ca8chs_tau1;1
#  KEY: TH1D	h_ca8chs_tau2;1
#  KEY: TH1D	h_ca8chs_tau3;1
#  KEY: TH1D	h_ca8chs_tau4;1
#  KEY: TH1D	h_ca8chs_tau32;1
#  KEY: TH1D	h_ca8chs_tau21;1
#  KEY: TH1D	h_ca8chs_ndau;1
#  KEY: TH1D	h_ca8chs_subjetMass;1
#  KEY: TH1D	h_ca8chs_area;1
#  KEY: TH1D	h_ca8chs_pt200_mass;1
#  KEY: TH1D	h_ca8chs_pt200_prunedMass;1
#  KEY: TH1D	h_ca8chs_pt200_trimmedMass;1
#  KEY: TH1D	h_ca8chs_pt200_filteredMass;1
#  KEY: TH1D	h_ca8chs_pt200_softDropMass;1
#  KEY: TH1D	h_ca8chs_pt200_tau32;1
#  KEY: TH1D	h_ca8chs_pt200_tau21;1
#  KEY: TH1D	h_ca8chs_pt200_subjetMass;1
#  KEY: TH1D	h_ca8chs_pt500_mass;1
#  KEY: TH1D	h_ca8chs_pt500_prunedMass;1
#  KEY: TH1D	h_ca8chs_pt500_trimmedMass;1
#  KEY: TH1D	h_ca8chs_pt500_filteredMass;1
#  KEY: TH1D	h_ca8chs_pt500_softDropMass;1
#  KEY: TH1D	h_ca8chs_pt500_tau32;1
#  KEY: TH1D	h_ca8chs_pt500_tau21;1
#  KEY: TH1D	h_ca8chs_pt500_subjetMass;1
#  KEY: TH1D	h_ak12chs_pt;1
#  KEY: TH1D	h_ak12chs_mass;1
#  KEY: TH1D	h_ak12chs_rapidity;1
#  KEY: TH1D	h_ak12chs_prunedMass;1
#  KEY: TH1D	h_ak12chs_trimmedMass;1
#  KEY: TH1D	h_ak12chs_filteredMass;1
#  KEY: TH1D	h_ak12chs_softDropMass;1
#  KEY: TH1D	h_ak12chs_tau1;1
#  KEY: TH1D	h_ak12chs_tau2;1
#  KEY: TH1D	h_ak12chs_tau3;1
#  KEY: TH1D	h_ak12chs_tau4;1
#  KEY: TH1D	h_ak12chs_tau32;1
#  KEY: TH1D	h_ak12chs_tau21;1
#  KEY: TH1D	h_ak12chs_ndau;1
#  KEY: TH1D	h_ak12chs_subjetMass;1
#  KEY: TH1D	h_ak12chs_area;1
#  KEY: TH1D	h_ak12chs_pt200_mass;1
#  KEY: TH1D	h_ak12chs_pt200_prunedMass;1
#  KEY: TH1D	h_ak12chs_pt200_trimmedMass;1
#  KEY: TH1D	h_ak12chs_pt200_filteredMass;1
#  KEY: TH1D	h_ak12chs_pt200_softDropMass;1
#  KEY: TH1D	h_ak12chs_pt200_tau32;1
#  KEY: TH1D	h_ak12chs_pt200_tau21;1
#  KEY: TH1D	h_ak12chs_pt200_subjetMass;1
#  KEY: TH1D	h_ak12chs_pt500_mass;1
#  KEY: TH1D	h_ak12chs_pt500_prunedMass;1
#  KEY: TH1D	h_ak12chs_pt500_trimmedMass;1
#  KEY: TH1D	h_ak12chs_pt500_filteredMass;1
#  KEY: TH1D	h_ak12chs_pt500_softDropMass;1
#  KEY: TH1D	h_ak12chs_pt500_tau32;1
#  KEY: TH1D	h_ak12chs_pt500_tau21;1
#  KEY: TH1D	h_ak12chs_pt500_subjetMass;1
#  KEY: TH1D	h_ak15chs_pt;1
#  KEY: TH1D	h_ak15chs_mass;1
#  KEY: TH1D	h_ak15chs_rapidity;1
#  KEY: TH1D	h_ak15chs_prunedMass;1
#  KEY: TH1D	h_ak15chs_trimmedMass;1
#  KEY: TH1D	h_ak15chs_filteredMass;1
#  KEY: TH1D	h_ak15chs_softDropMass;1
#  KEY: TH1D	h_ak15chs_tau1;1
#  KEY: TH1D	h_ak15chs_tau2;1
#  KEY: TH1D	h_ak15chs_tau3;1
#  KEY: TH1D	h_ak15chs_tau4;1
#  KEY: TH1D	h_ak15chs_tau32;1
#  KEY: TH1D	h_ak15chs_tau21;1
#  KEY: TH1D	h_ak15chs_ndau;1
#  KEY: TH1D	h_ak15chs_subjetMass;1
#  KEY: TH1D	h_ak15chs_area;1
#  KEY: TH1D	h_ak15chs_pt200_mass;1
#  KEY: TH1D	h_ak15chs_pt200_prunedMass;1
#  KEY: TH1D	h_ak15chs_pt200_trimmedMass;1
#  KEY: TH1D	h_ak15chs_pt200_filteredMass;1
#  KEY: TH1D	h_ak15chs_pt200_softDropMass;1
#  KEY: TH1D	h_ak15chs_pt200_tau32;1
#  KEY: TH1D	h_ak15chs_pt200_tau21;1
#  KEY: TH1D	h_ak15chs_pt200_subjetMass;1
#  KEY: TH1D	h_ak15chs_pt500_mass;1
#  KEY: TH1D	h_ak15chs_pt500_prunedMass;1
#  KEY: TH1D	h_ak15chs_pt500_trimmedMass;1
#  KEY: TH1D	h_ak15chs_pt500_filteredMass;1
#  KEY: TH1D	h_ak15chs_pt500_softDropMass;1
#  KEY: TH1D	h_ak15chs_pt500_tau32;1
#  KEY: TH1D	h_ak15chs_pt500_tau21;1
#  KEY: TH1D	h_ak15chs_pt500_subjetMass;1

# %%
h_ak8_area = fdir.Get("h_ak8chs_area")
c = ROOT.TCanvas('c', 'c', 800, 600)
h_ak8_area.Draw()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
