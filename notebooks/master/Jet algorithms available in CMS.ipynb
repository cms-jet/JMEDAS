# %% [markdown]
# # Jets and boosted jets

# %% [markdown]
# Jets are physics objects representing the hadronization and fragmentation of light-quarks and gluons. Currently, we use anti-kt jets with cone-size of 0.4 to reconstruct these types of jets. We have algoritms trying to distinguish heavy-flavour (b or c) quarks (which are in the domain of the BTV POG), quark- vs gluon-originated jets, and jets coming from pileup contributions vs jets coming from real particles.
#
#
# However, in the current conditions of the LHC, heavy particles such as top quarks, W/Z/Higgs bosons, or any other heavy beyond-Standard-Model proposed particle can be produced with some initial momentum. If these particles decay hadronically, the hadronization of these light quarks will be more collimated and therefore difficult to reconstruct them separatedly.
#
# We use wide cone-size jets to reconstruct these objects, which we called fatjets or boosted jets. In CMS, we use anti-kt jets with R=0.8 (AK8) as the standard boosted jet, while ATLAS uses AK10. This topic was explained in more detailed in the slides [ADD LINK TO SLIDES]. Additionally, an excellent overview of jet substructure techniques can be found here: [Boosted objects: a probe of beyond the Standard Model physics](http://arxiv.org/abs/1012.5412) by Abdesselam et al.

# %% [markdown]
# ## Jet types and algorithms available in CMS

# %% [markdown]
# All the algorithms described in the slides are implemented into the CMS software CMSSW. However, some algoritms, with specific parameters, have become standard tools studied and recommended by the JetMET POG. These algorithms are included in the centrally produced CMS samples in AOD, miniAOD or nanoAOD format, the last two are the formats more commonly used in CMS analyses. Other algorithms, with non-standard parameters, can also be tested through the JetToolbox (discussed later in the tutorial).
#
# In this part of the tutorial you will learn how to access jet collections included in CMS datasets, the different algorithms stored in them, or how to create your own collections.

# %% [markdown]
# ### AOD
#
# [This twiki](https://twiki.cern.ch/twiki/bin/view/CMSPublic/SWGuideDataFormatRecoJets) summarizes the respective labels by which each jet collection can be retrieved from the event record for general AOD files. This format is currently been used for specialized studies, but for most of the analyses you can use the other formats.

# %% [markdown]
# ### miniAOD
#
# There are three main jet collections stored in miniAOD format, as described [here](https://twiki.cern.ch/twiki/bin/view/CMSPublic/WorkBookMiniAOD2017#Jets).
#  * **slimmedJets**: are AK4 energy-corrected jets using charged hadron substraction (CHS) as the pileup removal algorithm. This is the default jet collection for CMS analyses for Run II. In this collection you can find the following jet algorithms, as well as other jet related quantities:
#    * b-tagging
#    * Pileup jet ID
#    * Quark/gluon likelihood info embedded.
#  * **slimmedJetsPUPPI**: are AK4 energy-corrected jets using the PUPPI algorithm for pileup removal. This collection will be the default for Run III analyses.
#  * **slimmedJetsAK8**: ak4 AK8 energy-corrected jets using the PUPPI algoritm for pileup removal. This has been the default collection for boosted jets in Run II. In this collection you can find the following jet algorithms, as well as other jet related quantities:
#    * Softdrop mass
#    * n-subjettiness and energy correlation variables
#    * Access to softdrop subjets
#    * Access to the associated AK8 CHS jet four momentum, including softdrop and prunning mass, and n-subjettiness.

# %% [markdown]
# #### Examples of how to access jet collections in miniAOD samples
#
# Below are two examples on how to access jet collections from these samples. This exercise do not pretend you to modify code in order to access those collections, but rather for you to look at the code and get an idea about how you could access this information if needed.

# %% [markdown]
# ##### In C++
#
# If you are on the terminal, please take a look at the file `$CMSSW_BASE/src/Analysis/JMEDAS/src/jmedas_miniAODAnalyzer.C`.  The same code can be seen by clicking in the link below:
#
# <details>
#     <summary><font color='blue'>SHOW CODE</font></summary>
# <p>
#
# In C++ you need to create a .C file inside the `src` directory.
#
# ```C
# // system include files
# #include <memory>
# #include <vector>
#
# // user include files
# #include "FWCore/Framework/interface/Frameworkfwd.h"
# #include "FWCore/Framework/interface/EDAnalyzer.h"
#
# #include "FWCore/Framework/interface/Event.h"
# #include "FWCore/Framework/interface/MakerMacros.h"
#
# #include "FWCore/ParameterSet/interface/ParameterSet.h"
#
# #include "DataFormats/VertexReco/interface/VertexFwd.h"
# #include "DataFormats/VertexReco/interface/Vertex.h"
# #include "DataFormats/PatCandidates/interface/Jet.h"
# #include "DataFormats/PatCandidates/interface/PackedCandidate.h"
# //
# // class declaration
# //
# using namespace std;
#
# class MiniAnalyzer : public edm::EDAnalyzer {
#    public:
#       explicit MiniAnalyzer (const edm::ParameterSet&);
#       ~MiniAnalyzer();
#
#    private:
#       virtual void analyze(const edm::Event&, const edm::EventSetup&) override;
#
#       // ----------member data ---------------------------
#       edm::EDGetTokenT<vector<reco::Vertex>> vtxToken_;
#       edm::EDGetTokenT<pat::JetCollection> jetToken_;
#       edm::EDGetTokenT<pat::JetCollection> fatjetToken_;
#
# };
#
# MiniAnalyzer::MiniAnalyzer(const edm::ParameterSet& iConfig):
#     vtxToken_(consumes<vector<reco::Vertex>>(iConfig.getParameter<edm::InputTag>("vertices"))),
#     jetToken_(consumes<pat::JetCollection>(iConfig.getParameter<edm::InputTag>("jets"))),
#     fatjetToken_(consumes<pat::JetCollection>(iConfig.getParameter<edm::InputTag>("fatjets")))
# {
# }
#
# MiniAnalyzer::~MiniAnalyzer()
# {
# }
#
# void
# MiniAnalyzer::analyze(const edm::Event& iEvent, const edm::EventSetup& iSetup)
# {
#
#     edm::Handle<vector<reco::Vertex>> vertices;
#     iEvent.getByToken(vtxToken_, vertices);
#     if (vertices->empty()) return; // skip the event if no PV found
#     const reco::Vertex &PV = vertices->front();
#
#     edm::Handle<pat::JetCollection> jets;
#     iEvent.getByToken(jetToken_, jets);
#     int ijet = 0;
#     for (const pat::Jet &j : *jets) {
#         if (j.pt() < 20) continue;
#         printf("jet  with pt %5.1f (raw pt %5.1f), eta %+4.2f, btag CSV %.3f, CISV %.3f, pileup mva disc %+.2f\n",
#             j.pt(), j.pt()*j.jecFactor("Uncorrected"), j.eta(), std::max(0.f,j.bDiscriminator("combinedSecondaryVertexBJetTags")), std::max(0.f,j.bDiscriminator("combinedInclusiveSecondaryVertexBJetTags")), j.userFloat("pileupJetId:fullDiscriminant"));
#         if ((++ijet) == 1) { // for the first jet, lets print the leading constituents
#             std::vector daus(j.daughterPtrVector());
#             std::sort(daus.begin(), daus.end(), [](const reco::CandidatePtr &p1, const reco::CandidatePtr &p2) { return p1->pt() > p2->pt(); }); // the joys of C++11
#             for (unsigned int i2 = 0, n = daus.size(); i2 < n && i2 <= 3; ++i2) {
#                 const pat::PackedCandidate &cand = dynamic_cast<const pat::PackedCandidate &>(*daus[i2]);
#                 printf("         constituent %3d: pt %6.2f, dz(pv) %+.3f, pdgId %+3d\n", i2,cand.pt(),cand.dz(PV.position()),cand.pdgId());
#             }
#         }
#     }
#
#     edm::Handle<pat::JetCollection> fatjets;
#     iEvent.getByToken(fatjetToken_, fatjets);
#     for (const pat::Jet &j : *fatjets) {
#         printf("AK8j with pt %5.1f (raw pt %5.1f), eta %+4.2f, mass %5.1f ungroomed, %5.1f softdrop, %5.1f pruned CHS\n",
#             j.pt(), j.pt()*j.jecFactor("Uncorrected"), j.eta(), j.mass(), j.userFloat("ak8PFJetsPuppiSoftDropMass"), j.userFloat("ak8PFJetsCHSValueMap:ak8PFJetsCHSPrunedMass") );
#
#         // To get the constituents of the AK8 jets, you have to loop over all of the
#         // daughters recursively. To save space, the first two constituents are actually
#         // the Soft Drop SUBJETS, which will then point to their daughters.
#         // The remaining constituents are those constituents removed by soft drop but
#         // still in the AK8 jet.
#         std::vector<reco::Candidate const *> constituents;
#         for ( unsigned ida = 0; ida < j.numberOfDaughters(); ++ida ) {
#      reco::Candidate const * cand = j.daughter(ida);
#      if ( cand->numberOfDaughters() == 0 )
#        constituents.push_back( cand ) ;
#      else {
#        for ( unsigned jda = 0; jda < cand->numberOfDaughters(); ++jda ) {
#          reco::Candidate const * cand2 = cand->daughter(jda);
#          constituents.push_back( cand2 );
#        }
#      }
#    }
#    std::sort( constituents.begin(), constituents.end(), [] (reco::Candidate const * ida, reco::Candidate const * jda){return ida->pt() > jda->pt();} );
#
#    for ( unsigned int ida = 0; ida < constituents.size(); ++ida ) {
#      const pat::PackedCandidate &cand = dynamic_cast<const pat::PackedCandidate &>(*constituents[ida]);
#      printf("         constituent %3d: pt %6.2f, dz(pv) %+.3f, pdgId %+3d\n", ida,cand.pt(),cand.dz(PV.position()),cand.pdgId());
#    }
#
#    auto sdSubjets = j.subjets("SoftDropPuppi");
#    for ( auto const & isd : sdSubjets ) {
#      printf("  sd subjet with pt %5.1f (raw pt %5.1f), eta %+4.2f, mass %5.1f ungroomed\n",
#        isd->pt(), isd->pt()*isd->jecFactor("Uncorrected"), isd->eta(), isd->mass() );
#
#    }
#     }
# }
#
#
# //define this as a plug-in
# DEFINE_FWK_MODULE(MiniAnalyzer);
# ```
#
# Then, you run your C script with a python configuration, through the cmsRun command:
#
# ```python
# import FWCore.ParameterSet.Config as cms
#
# process = cms.Process("Demo")
#
# process.load("FWCore.MessageService.MessageLogger_cfi")
# process.maxEvents = cms.untracked.PSet( input = cms.untracked.int32(10)  )
#
# process.source = cms.Source("PoolSource",
#                             fileNames = cms.untracked.vstring(
#                                         '/store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root'
#
#                             )
#                             )
#
# process.demo = cms.EDAnalyzer("MiniAnalyzer",
#                                   vertices = cms.InputTag("offlineSlimmedPrimaryVertices"),
#                                   jets = cms.InputTag("slimmedJets"),
#                                   fatjets = cms.InputTag("slimmedJetsAK8")
#                               )
#
# process.p = cms.Path(process.demo)
# ```
#
# </p>
# </details>

# %% [markdown]
# You can run this code by using the python config file `$CMSSW_BASE/src/Analysis/JMEDAS/scripts/jmedas_miniAODtest.py` from your terminal or in the next cell in this notebook. This script will only print out some information about the jets in that sample. Again, the most important part of this exercise is to get familiar with how to access jet collections from miniAOD.

# %%
### RUN THIS CELL ONLY IF YOU ARE USING SWAN 
import os

##### REMEMBER TO MANUALLY COPY THE PROXY TO YOUR CERNBOX FOLDER AND TO MODIFY THE NEXT LINE
#os.environ['X509_USER_PROXY'] = '/eos/home-X/Y/x509up_u0000'
os.environ['X509_USER_PROXY'] = '/eos/home-a/algomez/tmp/x509up_u15148'
if os.path.isfile(os.environ['X509_USER_PROXY']): pass
else: print("os.environ['X509_USER_PROXY'] ",os.environ['X509_USER_PROXY'])
os.environ['X509_CERT_DIR'] = '/cvmfs/cms.cern.ch/grid/etc/grid-security/certificates'
os.environ['X509_VOMS_DIR'] = '/cvmfs/cms.cern.ch/grid/etc/grid-security/vomsdir'

# %%
# %%bash
# cmsRun $CMSSW_BASE/src/Analysis/JMEDAS/scripts/jmedas_miniAODtest.py
# Out:
# jet  with pt 634.8 (raw pt 585.1), eta -0.93, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
#          constituent   0: pt 234.50, dz(pv) -0.003, pdgId +211
#          constituent   1: pt 224.38, dz(pv) +0.000, pdgId +130
#          constituent   2: pt  42.62, dz(pv) +0.000, pdgId +22
#          constituent   3: pt  24.61, dz(pv) +0.000, pdgId +22
# jet  with pt 520.5 (raw pt 490.2), eta +0.27, btag CSV 0.000, CISV 0.000, pileup mva disc +0.98
# AK8j with pt 632.2 (raw pt 567.6), eta -0.93, mass  45.6 ungroomed,   0.9 softdrop,  16.5 pruned CHS
#          constituent   0: pt 234.50, dz(pv) -0.003, pdgId +211
#          constituent   1: pt 224.38, dz(pv) +0.000, pdgId +130
#          constituent   2: pt  42.62, dz(pv) +0.000, pdgId +22
#          constituent   3: pt  24.61, dz(pv) +0.000, pdgId +22
#          constituent   4: pt   6.58, dz(pv) +0.000, pdgId +211
#          constituent   5: pt   5.48, dz(pv) +0.008, pdgId -211
#          constituent   6: pt   5.29, dz(pv) +0.000, pdgId +22
#          constituent   7: pt   3.41, dz(pv) +0.000, pdgId +22
#          constituent   8: pt   1.93, dz(pv) +0.000, pdgId +22
#          constituent   9: pt   1.80, dz(pv) +0.000, pdgId +22
#          constituent  10: pt   1.72, dz(pv) +0.000, pdgId +22
#          constituent  11: pt   1.38, dz(pv) +0.000, pdgId +130
#          constituent  12: pt   1.33, dz(pv) +0.000, pdgId +130
#          constituent  13: pt   1.32, dz(pv) +0.000, pdgId +130
#          constituent  14: pt   1.26, dz(pv) +0.010, pdgId -211
#          constituent  15: pt   1.12, dz(pv) +0.000, pdgId +22
#          constituent  16: pt   1.11, dz(pv) +0.000, pdgId +22
#          constituent  17: pt   1.11, dz(pv) +0.000, pdgId +130
#          constituent  18: pt   1.09, dz(pv) +0.000, pdgId +22
#          constituent  19: pt   0.90, dz(pv) -0.002, pdgId +211
#          constituent  20: pt   0.87, dz(pv) +0.000, pdgId +22
#          constituent  21: pt   0.87, dz(pv) +0.000, pdgId +22
#          constituent  22: pt   0.79, dz(pv) +0.000, pdgId +22
#          constituent  23: pt   0.77, dz(pv) +0.000, pdgId +22
#          constituent  24: pt   0.70, dz(pv) -0.002, pdgId +211
#          constituent  25: pt   0.64, dz(pv) +0.015, pdgId -211
#          constituent  26: pt   0.55, dz(pv) +0.000, pdgId +22
#          constituent  27: pt   0.43, dz(pv) +0.026, pdgId +211
#          constituent  28: pt   0.42, dz(pv) -0.036, pdgId +211
#          constituent  29: pt   0.30, dz(pv) -0.025, pdgId -211
#   sd subjet with pt 262.0 (raw pt 234.5), eta -0.93, mass   0.2 ungroomed
#   sd subjet with pt 250.6 (raw pt 224.3), eta -0.93, mass   0.0 ungroomed
# AK8j with pt 538.7 (raw pt 495.1), eta +0.27, mass  46.2 ungroomed,   1.0 softdrop,  10.1 pruned CHS
#          constituent   0: pt 234.75, dz(pv) +0.000, pdgId +211
#          constituent   1: pt 187.75, dz(pv) +0.000, pdgId +22
#          constituent   2: pt  35.84, dz(pv) +0.000, pdgId +130
#          constituent   3: pt   9.33, dz(pv) +0.000, pdgId +130
#          constituent   4: pt   8.05, dz(pv) -0.000, pdgId -211
#          constituent   5: pt   3.21, dz(pv) -0.003, pdgId +211
#          constituent   6: pt   2.96, dz(pv) +0.000, pdgId +22
#          constituent   7: pt   2.91, dz(pv) +0.000, pdgId +130
#          constituent   8: pt   2.59, dz(pv) -0.013, pdgId -211
#          constituent   9: pt   1.97, dz(pv) +0.000, pdgId +22
#          constituent  10: pt   1.94, dz(pv) +0.000, pdgId +130
#          constituent  11: pt   1.76, dz(pv) +0.000, pdgId +130
#          constituent  12: pt   1.41, dz(pv) +0.000, pdgId +130
#          constituent  13: pt   1.21, dz(pv) +0.001, pdgId +211
#          constituent  14: pt   1.16, dz(pv) +0.006, pdgId +211
#          constituent  15: pt   0.90, dz(pv) +0.000, pdgId -211
#          constituent  16: pt   0.83, dz(pv) +0.000, pdgId +22
#          constituent  17: pt   0.58, dz(pv) +0.000, pdgId +22
#          constituent  18: pt   0.31, dz(pv) +0.016, pdgId +211
#          constituent  19: pt   0.17, dz(pv) +0.026, pdgId +211
#   sd subjet with pt 256.0 (raw pt 234.7), eta +0.28, mass   0.2 ungroomed
#   sd subjet with pt 204.4 (raw pt 187.8), eta +0.27, mass   0.0 ungroomed
# jet  with pt 448.6 (raw pt 424.0), eta +0.27, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
#          constituent   0: pt 127.94, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  42.47, dz(pv) -0.001, pdgId +211
#          constituent   2: pt  31.91, dz(pv) -0.000, pdgId -211
#          constituent   3: pt  28.47, dz(pv) +0.001, pdgId +211
# jet  with pt 275.2 (raw pt 247.5), eta +1.19, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
# jet  with pt 217.3 (raw pt 206.4), eta +0.75, btag CSV 0.000, CISV 0.000, pileup mva disc +0.98
# jet  with pt  29.8 (raw pt  33.6), eta -3.01, btag CSV 0.000, CISV 0.000, pileup mva disc -0.56
# AK8j with pt 462.5 (raw pt 424.8), eta +0.27, mass  69.6 ungroomed,  47.3 softdrop,  48.5 pruned CHS
#          constituent   0: pt 127.94, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  42.47, dz(pv) -0.001, pdgId +211
#          constituent   2: pt  31.91, dz(pv) -0.000, pdgId -211
#          constituent   3: pt  28.47, dz(pv) +0.001, pdgId +211
#          constituent   4: pt  24.64, dz(pv) -0.001, pdgId -211
#          constituent   5: pt  19.88, dz(pv) +0.008, pdgId -211
#          constituent   6: pt  19.56, dz(pv) -0.000, pdgId -211
#          constituent   7: pt  15.68, dz(pv) +0.000, pdgId +22
#          constituent   8: pt  11.45, dz(pv) -0.004, pdgId +211
#          constituent   9: pt  10.73, dz(pv) +0.000, pdgId +22
#          constituent  10: pt  10.12, dz(pv) +0.000, pdgId +130
#          constituent  11: pt   7.86, dz(pv) -0.001, pdgId +211
#          constituent  12: pt   7.75, dz(pv) -0.001, pdgId -211
#          constituent  13: pt   7.64, dz(pv) +0.001, pdgId +211
#          constituent  14: pt   7.50, dz(pv) -0.005, pdgId +211
#          constituent  15: pt   7.04, dz(pv) +0.066, pdgId +211
#          constituent  16: pt   5.48, dz(pv) -0.004, pdgId +211
#          constituent  17: pt   4.79, dz(pv) +0.001, pdgId +211
#          constituent  18: pt   3.68, dz(pv) +0.003, pdgId -211
#          constituent  19: pt   3.54, dz(pv) +0.011, pdgId +211
#          constituent  20: pt   2.58, dz(pv) +0.000, pdgId +130
#          constituent  21: pt   2.55, dz(pv) +0.005, pdgId -211
#          constituent  22: pt   2.48, dz(pv) +0.000, pdgId +22
#          constituent  23: pt   2.44, dz(pv) +0.000, pdgId +22
#          constituent  24: pt   2.40, dz(pv) +0.000, pdgId +211
#          constituent  25: pt   1.88, dz(pv) +0.000, pdgId +22
#          constituent  26: pt   1.74, dz(pv) +0.002, pdgId -211
#          constituent  27: pt   1.58, dz(pv) +0.006, pdgId -211
#          constituent  28: pt   1.30, dz(pv) +0.000, pdgId +22
#          constituent  29: pt   1.19, dz(pv) +0.000, pdgId +22
#          constituent  30: pt   1.18, dz(pv) -0.003, pdgId -211
#          constituent  31: pt   1.18, dz(pv) +0.000, pdgId +22
#          constituent  32: pt   1.04, dz(pv) +0.000, pdgId +22
#          constituent  33: pt   1.01, dz(pv) -0.003, pdgId -211
#          constituent  34: pt   0.97, dz(pv) -0.002, pdgId -211
#          constituent  35: pt   0.97, dz(pv) +0.000, pdgId +130
#          constituent  36: pt   0.94, dz(pv) +0.000, pdgId +22
#          constituent  37: pt   0.69, dz(pv) +0.006, pdgId +211
#          constituent  38: pt   0.62, dz(pv) +0.007, pdgId +211
#          constituent  39: pt   0.52, dz(pv) +0.007, pdgId +211
#          constituent  40: pt   0.28, dz(pv) +0.017, pdgId +211
#   sd subjet with pt 343.4 (raw pt 315.0), eta +0.33, mass   9.2 ungroomed
#   sd subjet with pt  99.8 (raw pt  91.9), eta +0.09, mass   9.7 ungroomed
# AK8j with pt 281.0 (raw pt 244.0), eta +1.18, mass  47.9 ungroomed,  22.2 softdrop,  23.4 pruned CHS
#          constituent   0: pt  32.69, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  29.08, dz(pv) +0.003, pdgId +211
#          constituent   2: pt  23.39, dz(pv) +0.000, pdgId +22
#          constituent   3: pt  21.80, dz(pv) -0.042, pdgId +211
#          constituent   4: pt  19.92, dz(pv) +0.001, pdgId -211
#          constituent   5: pt  11.25, dz(pv) +0.011, pdgId +211
#          constituent   6: pt  10.81, dz(pv) +0.000, pdgId +22
#          constituent   7: pt  10.30, dz(pv) -0.005, pdgId +211
#          constituent   8: pt  10.11, dz(pv) +0.003, pdgId -211
#          constituent   9: pt   8.30, dz(pv) -0.006, pdgId -211
#          constituent  10: pt   8.01, dz(pv) +0.003, pdgId +211
#          constituent  11: pt   6.57, dz(pv) +0.006, pdgId -211
#          constituent  12: pt   6.07, dz(pv) -0.002, pdgId -211
#          constituent  13: pt   5.08, dz(pv) +0.000, pdgId +22
#          constituent  14: pt   4.10, dz(pv) +0.002, pdgId -211
#          constituent  15: pt   3.74, dz(pv) +0.000, pdgId +22
#          constituent  16: pt   3.55, dz(pv) -0.003, pdgId +211
#          constituent  17: pt   3.10, dz(pv) -0.015, pdgId -211
#          constituent  18: pt   2.57, dz(pv) -0.005, pdgId +211
#          constituent  19: pt   2.33, dz(pv) +0.000, pdgId +130
#          constituent  20: pt   2.31, dz(pv) +0.000, pdgId +22
#          constituent  21: pt   2.15, dz(pv) +0.000, pdgId +22
#          constituent  22: pt   2.11, dz(pv) -0.013, pdgId -211
#          constituent  23: pt   1.75, dz(pv) -0.007, pdgId -211
#          constituent  24: pt   1.37, dz(pv) +0.000, pdgId +22
#          constituent  25: pt   1.26, dz(pv) +0.023, pdgId +211
#          constituent  26: pt   1.25, dz(pv) +0.019, pdgId +211
#          constituent  27: pt   1.20, dz(pv) +0.006, pdgId +211
#          constituent  28: pt   0.91, dz(pv) +0.017, pdgId -211
#          constituent  29: pt   0.90, dz(pv) -0.011, pdgId +211
#          constituent  30: pt   0.89, dz(pv) +0.000, pdgId +22
#          constituent  31: pt   0.84, dz(pv) +0.000, pdgId +22
#          constituent  32: pt   0.79, dz(pv) +0.000, pdgId +22
#          constituent  33: pt   0.76, dz(pv) +0.000, pdgId +22
#          constituent  34: pt   0.73, dz(pv) +0.004, pdgId +211
#          constituent  35: pt   0.70, dz(pv) +0.000, pdgId +22
#          constituent  36: pt   0.69, dz(pv) +0.000, pdgId +130
#          constituent  37: pt   0.68, dz(pv) +0.000, pdgId +130
#          constituent  38: pt   0.68, dz(pv) +0.000, pdgId +22
#          constituent  39: pt   0.67, dz(pv) +0.000, pdgId +22
#          constituent  40: pt   0.61, dz(pv) +0.000, pdgId +22
#          constituent  41: pt   0.60, dz(pv) +0.000, pdgId +22
#          constituent  42: pt   0.59, dz(pv) +0.000, pdgId +22
#          constituent  43: pt   0.59, dz(pv) +0.000, pdgId +22
#   sd subjet with pt 175.0 (raw pt 151.1), eta +1.21, mass  11.9 ungroomed
#   sd subjet with pt  86.4 (raw pt  76.0), eta +1.11, mass   3.4 ungroomed
# AK8j with pt 213.3 (raw pt 192.3), eta +0.75, mass  22.9 ungroomed,   5.1 softdrop,   9.2 pruned CHS
#          constituent   0: pt  61.28, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  23.91, dz(pv) +0.000, pdgId +22
#          constituent   2: pt  20.47, dz(pv) +0.000, pdgId +130
#          constituent   3: pt  15.55, dz(pv) +0.002, pdgId -211
#          constituent   4: pt  13.32, dz(pv) +0.001, pdgId +211
#          constituent   5: pt  10.84, dz(pv) +0.065, pdgId +211
#          constituent   6: pt   7.89, dz(pv) +0.000, pdgId +22
#          constituent   7: pt   7.33, dz(pv) +0.000, pdgId +22
#          constituent   8: pt   5.98, dz(pv) -0.000, pdgId +211
#          constituent   9: pt   4.91, dz(pv) +0.000, pdgId +130
#          constituent  10: pt   3.29, dz(pv) +0.000, pdgId +22
#          constituent  11: pt   3.29, dz(pv) -0.000, pdgId -211
#          constituent  12: pt   3.05, dz(pv) -0.007, pdgId -211
#          constituent  13: pt   2.70, dz(pv) +0.000, pdgId +130
#          constituent  14: pt   2.00, dz(pv) +0.000, pdgId +22
#          constituent  15: pt   1.93, dz(pv) +0.000, pdgId +130
#          constituent  16: pt   1.58, dz(pv) +0.000, pdgId +22
#          constituent  17: pt   1.08, dz(pv) +0.000, pdgId +22
#          constituent  18: pt   0.89, dz(pv) +0.000, pdgId +22
#          constituent  19: pt   0.80, dz(pv) +0.000, pdgId +22
#          constituent  20: pt   0.78, dz(pv) +0.030, pdgId -211
#          constituent  21: pt   0.75, dz(pv) +0.000, pdgId +22
#          constituent  22: pt   0.68, dz(pv) +0.007, pdgId -211
#          constituent  23: pt   0.65, dz(pv) +0.000, pdgId +22
#          constituent  24: pt   0.57, dz(pv) +0.000, pdgId +22
#          constituent  25: pt   0.42, dz(pv) +0.005, pdgId -211
#          constituent  26: pt   0.25, dz(pv) -0.001, pdgId -211
#   sd subjet with pt 105.3 (raw pt  95.6), eta +0.75, mass   1.9 ungroomed
#   sd subjet with pt  70.4 (raw pt  63.7), eta +0.75, mass   1.4 ungroomed
# jet  with pt 538.0 (raw pt 502.7), eta -0.64, btag CSV 0.000, CISV 0.000, pileup mva disc +1.00
#          constituent   0: pt  87.38, dz(pv) -0.007, pdgId +211
#          constituent   1: pt  80.69, dz(pv) +0.000, pdgId +22
#          constituent   2: pt  36.72, dz(pv) -0.000, pdgId -211
#          constituent   3: pt  36.22, dz(pv) -0.003, pdgId -211
# jet  with pt 449.7 (raw pt 419.1), eta -0.74, btag CSV 0.000, CISV 0.000, pileup mva disc +1.00
# jet  with pt  92.6 (raw pt  84.4), eta -1.28, btag CSV 0.000, CISV 0.000, pileup mva disc +0.94
# jet  with pt  33.3 (raw pt  33.5), eta -0.42, btag CSV 0.000, CISV 0.000, pileup mva disc +0.90
# AK8j with pt 553.1 (raw pt 497.1), eta -0.85, mass 139.3 ungroomed, 123.9 softdrop, 122.0 pruned CHS
#          constituent   0: pt 118.50, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  51.75, dz(pv) +0.000, pdgId +22
#          constituent   2: pt  51.56, dz(pv) -0.001, pdgId -211
#          constituent   3: pt  47.00, dz(pv) +0.000, pdgId +211
#          constituent   4: pt  29.53, dz(pv) +0.002, pdgId +211
#          constituent   5: pt  22.53, dz(pv) +0.000, pdgId +22
#          constituent   6: pt  21.11, dz(pv) -0.000, pdgId -211
#          constituent   7: pt  17.25, dz(pv) +0.000, pdgId +130
#          constituent   8: pt  16.02, dz(pv) +0.005, pdgId +211
#          constituent   9: pt  13.93, dz(pv) +0.002, pdgId -211
#          constituent  10: pt  13.16, dz(pv) +0.047, pdgId -211
#          constituent  11: pt  11.95, dz(pv) +0.000, pdgId +130
#          constituent  12: pt   9.26, dz(pv) -0.003, pdgId -211
#          constituent  13: pt   9.10, dz(pv) +0.000, pdgId +22
#          constituent  14: pt   7.53, dz(pv) +0.000, pdgId +130
#          constituent  15: pt   7.39, dz(pv) +0.000, pdgId +22
#          constituent  16: pt   6.29, dz(pv) +0.000, pdgId +130
#          constituent  17: pt   4.04, dz(pv) +0.002, pdgId +211
#          constituent  18: pt   3.48, dz(pv) +0.000, pdgId +22
#          constituent  19: pt   3.41, dz(pv) +0.000, pdgId +130
#          constituent  20: pt   3.01, dz(pv) +0.000, pdgId +22
#          constituent  21: pt   2.96, dz(pv) -0.011, pdgId -211
#          constituent  22: pt   2.85, dz(pv) -0.002, pdgId +211
#          constituent  23: pt   2.79, dz(pv) +0.000, pdgId +130
#          constituent  24: pt   2.53, dz(pv) +0.000, pdgId +22
#          constituent  25: pt   2.41, dz(pv) +0.000, pdgId +22
#          constituent  26: pt   2.38, dz(pv) +0.003, pdgId +211
#          constituent  27: pt   1.83, dz(pv) +0.000, pdgId +22
#          constituent  28: pt   1.48, dz(pv) +0.000, pdgId +22
#          constituent  29: pt   1.47, dz(pv) +0.000, pdgId +130
#          constituent  30: pt   1.44, dz(pv) +0.000, pdgId +22
#          constituent  31: pt   1.30, dz(pv) +0.000, pdgId +22
#          constituent  32: pt   1.29, dz(pv) +0.000, pdgId +22
#          constituent  33: pt   1.25, dz(pv) -0.008, pdgId +211
#          constituent  34: pt   1.18, dz(pv) +0.001, pdgId -211
#          constituent  35: pt   1.12, dz(pv) +0.004, pdgId -211
#          constituent  36: pt   1.09, dz(pv) +0.000, pdgId +22
#          constituent  37: pt   1.02, dz(pv) +0.000, pdgId +130
#          constituent  38: pt   0.88, dz(pv) +0.000, pdgId +22
#          constituent  39: pt   0.85, dz(pv) +0.000, pdgId +22
#          constituent  40: pt   0.67, dz(pv) +0.000, pdgId +22
#          constituent  41: pt   0.66, dz(pv) +0.000, pdgId +22
#          constituent  42: pt   0.63, dz(pv) +0.008, pdgId +211
#          constituent  43: pt   0.23, dz(pv) -0.001, pdgId -211
#   sd subjet with pt 461.1 (raw pt 417.0), eta -0.74, mass  38.8 ungroomed
#   sd subjet with pt  95.8 (raw pt  81.6), eta -1.29, mass  15.4 ungroomed
# AK8j with pt 544.1 (raw pt 494.4), eta -0.65, mass  58.4 ungroomed,   9.0 softdrop,  22.4 pruned CHS
#          constituent   0: pt  87.38, dz(pv) -0.007, pdgId +211
#          constituent   1: pt  80.69, dz(pv) +0.000, pdgId +22
#          constituent   2: pt  36.72, dz(pv) -0.000, pdgId -211
#          constituent   3: pt  36.22, dz(pv) -0.003, pdgId -211
#          constituent   4: pt  33.84, dz(pv) +0.000, pdgId -211
#          constituent   5: pt  28.55, dz(pv) -0.001, pdgId +211
#          constituent   6: pt  26.23, dz(pv) +0.000, pdgId +22
#          constituent   7: pt  20.06, dz(pv) +0.004, pdgId +211
#          constituent   8: pt  19.47, dz(pv) -0.002, pdgId +211
#          constituent   9: pt  16.05, dz(pv) +0.002, pdgId -211
#          constituent  10: pt  13.83, dz(pv) -0.000, pdgId +211
#          constituent  11: pt  12.30, dz(pv) +0.001, pdgId +211
#          constituent  12: pt   9.97, dz(pv) +0.000, pdgId +22
#          constituent  13: pt   8.97, dz(pv) -0.002, pdgId -211
#          constituent  14: pt   6.94, dz(pv) -0.002, pdgId -211
#          constituent  15: pt   6.46, dz(pv) +0.004, pdgId -211
#          constituent  16: pt   5.32, dz(pv) +0.001, pdgId -211
#          constituent  17: pt   4.54, dz(pv) +0.003, pdgId -211
#          constituent  18: pt   3.56, dz(pv) -0.031, pdgId +211
#          constituent  19: pt   3.53, dz(pv) +0.000, pdgId -211
#          constituent  20: pt   3.19, dz(pv) -0.001, pdgId +211
#          constituent  21: pt   3.06, dz(pv) +0.000, pdgId +130
#          constituent  22: pt   2.83, dz(pv) -0.009, pdgId +211
#          constituent  23: pt   2.56, dz(pv) +0.000, pdgId +22
#          constituent  24: pt   2.55, dz(pv) +0.004, pdgId -211
#          constituent  25: pt   2.13, dz(pv) +0.001, pdgId -211
#          constituent  26: pt   1.96, dz(pv) -0.017, pdgId +211
#          constituent  27: pt   1.87, dz(pv) +0.000, pdgId +22
#          constituent  28: pt   1.56, dz(pv) +0.000, pdgId +130
#          constituent  29: pt   1.55, dz(pv) +0.000, pdgId +22
#          constituent  30: pt   1.49, dz(pv) +0.000, pdgId +22
#          constituent  31: pt   1.46, dz(pv) +0.012, pdgId +211
#          constituent  32: pt   1.40, dz(pv) +0.000, pdgId +22
#          constituent  33: pt   1.38, dz(pv) -0.078, pdgId -211
#          constituent  34: pt   1.37, dz(pv) -0.001, pdgId +211
#          constituent  35: pt   1.29, dz(pv) +0.000, pdgId +22
#          constituent  36: pt   1.19, dz(pv) +0.000, pdgId -211
#          constituent  37: pt   0.93, dz(pv) +0.005, pdgId +211
#          constituent  38: pt   0.90, dz(pv) +0.000, pdgId +130
#          constituent  39: pt   0.86, dz(pv) +0.000, pdgId +22
#          constituent  40: pt   0.79, dz(pv) -0.014, pdgId -211
#          constituent  41: pt   0.67, dz(pv) +0.023, pdgId -211
#          constituent  42: pt   0.52, dz(pv) -0.012, pdgId +211
#          constituent  43: pt   0.17, dz(pv) -0.057, pdgId -211
#   sd subjet with pt 344.5 (raw pt 312.8), eta -0.64, mass   5.9 ungroomed
#   sd subjet with pt 114.4 (raw pt 104.0), eta -0.64, mass   1.5 ungroomed
# jet  with pt 397.6 (raw pt 374.0), eta -0.29, btag CSV 0.000, CISV 0.000, pileup mva disc +1.00
#          constituent   0: pt  68.38, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  37.41, dz(pv) +0.003, pdgId +211
#          constituent   2: pt  33.47, dz(pv) -0.003, pdgId +211
#          constituent   3: pt  32.34, dz(pv) +0.006, pdgId -211
# jet  with pt 365.5 (raw pt 344.8), eta -0.04, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
# jet  with pt 194.5 (raw pt 185.7), eta +0.17, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
# jet  with pt  31.0 (raw pt  25.3), eta +2.21, btag CSV 0.000, CISV 0.000, pileup mva disc +0.94
# jet  with pt  24.5 (raw pt  24.0), eta -0.39, btag CSV 0.000, CISV 0.000, pileup mva disc +0.64
# jet  with pt  23.3 (raw pt  22.7), eta -1.19, btag CSV 0.000, CISV 0.000, pileup mva disc +0.70
# jet  with pt  20.7 (raw pt  21.1), eta -0.55, btag CSV 0.000, CISV 0.000, pileup mva disc +0.84
# AK8j with pt 431.1 (raw pt 394.6), eta -0.31, mass  79.3 ungroomed,  16.4 softdrop,  21.4 pruned CHS
#          constituent   0: pt  68.38, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  37.41, dz(pv) +0.003, pdgId +211
#          constituent   2: pt  33.47, dz(pv) -0.003, pdgId +211
#          constituent   3: pt  32.34, dz(pv) +0.006, pdgId -211
#          constituent   4: pt  29.67, dz(pv) -0.001, pdgId +211
#          constituent   5: pt  28.00, dz(pv) +0.002, pdgId +211
#          constituent   6: pt  24.38, dz(pv) +0.000, pdgId +22
#          constituent   7: pt  24.34, dz(pv) +0.010, pdgId -211
#          constituent   8: pt  13.75, dz(pv) -0.018, pdgId +211
#          constituent   9: pt  10.92, dz(pv) +0.003, pdgId +211
#          constituent  10: pt   7.74, dz(pv) -0.003, pdgId +211
#          constituent  11: pt   7.25, dz(pv) +0.000, pdgId +22
#          constituent  12: pt   6.68, dz(pv) -0.001, pdgId +211
#          constituent  13: pt   5.38, dz(pv) +0.007, pdgId -211
#          constituent  14: pt   4.93, dz(pv) +0.002, pdgId -211
#          constituent  15: pt   4.69, dz(pv) +0.001, pdgId +211
#          constituent  16: pt   3.82, dz(pv) -0.008, pdgId -211
#          constituent  17: pt   3.76, dz(pv) +0.000, pdgId +22
#          constituent  18: pt   3.68, dz(pv) -0.005, pdgId -211
#          constituent  19: pt   3.62, dz(pv) -0.012, pdgId -211
#          constituent  20: pt   3.60, dz(pv) -0.004, pdgId +211
#          constituent  21: pt   3.04, dz(pv) -0.011, pdgId -211
#          constituent  22: pt   3.03, dz(pv) +0.000, pdgId +130
#          constituent  23: pt   2.57, dz(pv) +0.017, pdgId -211
#          constituent  24: pt   2.56, dz(pv) +0.000, pdgId +22
#          constituent  25: pt   2.30, dz(pv) +0.000, pdgId +22
#          constituent  26: pt   2.21, dz(pv) +0.001, pdgId +211
#          constituent  27: pt   2.12, dz(pv) -0.005, pdgId +211
#          constituent  28: pt   2.11, dz(pv) +0.003, pdgId +211
#          constituent  29: pt   2.11, dz(pv) +0.005, pdgId -211
#          constituent  30: pt   2.09, dz(pv) -0.003, pdgId +211
#          constituent  31: pt   1.96, dz(pv) +0.032, pdgId +211
#          constituent  32: pt   1.95, dz(pv) +0.002, pdgId -211
#          constituent  33: pt   1.71, dz(pv) +0.004, pdgId +211
#          constituent  34: pt   1.64, dz(pv) -0.007, pdgId +211
#          constituent  35: pt   1.22, dz(pv) +0.000, pdgId +130
#          constituent  36: pt   1.13, dz(pv) -0.001, pdgId +211
#          constituent  37: pt   1.04, dz(pv) +0.000, pdgId +130
#          constituent  38: pt   0.99, dz(pv) -0.004, pdgId -211
#          constituent  39: pt   0.88, dz(pv) -0.006, pdgId +211
#          constituent  40: pt   0.87, dz(pv) +0.000, pdgId +22
#          constituent  41: pt   0.79, dz(pv) +0.000, pdgId +22
#          constituent  42: pt   0.72, dz(pv) +0.000, pdgId +22
#          constituent  43: pt   0.70, dz(pv) +0.000, pdgId +22
#          constituent  44: pt   0.59, dz(pv) +0.000, pdgId +22
#          constituent  45: pt   0.22, dz(pv) +0.040, pdgId -211
#   sd subjet with pt 178.6 (raw pt 163.8), eta -0.29, mass   4.9 ungroomed
#   sd subjet with pt 175.1 (raw pt 160.6), eta -0.29, mass   5.3 ungroomed
# AK8j with pt 390.8 (raw pt 358.5), eta -0.06, mass  91.6 ungroomed,  56.1 softdrop,  54.2 pruned CHS
#          constituent   0: pt  98.69, dz(pv) -0.010, pdgId -211
#          constituent   1: pt  54.78, dz(pv) +0.000, pdgId +22
#          constituent   2: pt  28.27, dz(pv) -0.016, pdgId -211
#          constituent   3: pt  25.02, dz(pv) -0.015, pdgId -211
#          constituent   4: pt  19.33, dz(pv) -0.008, pdgId +211
#          constituent   5: pt  14.10, dz(pv) -0.007, pdgId +211
#          constituent   6: pt  13.66, dz(pv) +0.069, pdgId +211
#          constituent   7: pt  13.31, dz(pv) -0.249, pdgId -211
#          constituent   8: pt  12.74, dz(pv) +0.002, pdgId -211
#          constituent   9: pt  11.80, dz(pv) -0.001, pdgId -211
#          constituent  10: pt   7.02, dz(pv) +0.000, pdgId +22
#          constituent  11: pt   5.58, dz(pv) -0.002, pdgId +211
#          constituent  12: pt   5.44, dz(pv) +0.000, pdgId +22
#          constituent  13: pt   4.63, dz(pv) -0.002, pdgId -211
#          constituent  14: pt   4.19, dz(pv) -0.006, pdgId -211
#          constituent  15: pt   3.99, dz(pv) +0.000, pdgId +22
#          constituent  16: pt   3.66, dz(pv) +0.000, pdgId +22
#          constituent  17: pt   2.77, dz(pv) +0.000, pdgId +130
#          constituent  18: pt   2.54, dz(pv) -0.033, pdgId +211
#          constituent  19: pt   2.26, dz(pv) +0.005, pdgId -211
#          constituent  20: pt   2.23, dz(pv) +0.000, pdgId +22
#          constituent  21: pt   2.19, dz(pv) -0.007, pdgId -211
#          constituent  22: pt   2.00, dz(pv) +0.000, pdgId +22
#          constituent  23: pt   1.98, dz(pv) +0.000, pdgId +22
#          constituent  24: pt   1.92, dz(pv) +0.000, pdgId +130
#          constituent  25: pt   1.77, dz(pv) +0.000, pdgId +22
#          constituent  26: pt   1.71, dz(pv) -0.002, pdgId +211
#          constituent  27: pt   1.63, dz(pv) +0.000, pdgId +22
#          constituent  28: pt   1.59, dz(pv) -0.002, pdgId +211
#          constituent  29: pt   1.34, dz(pv) -0.002, pdgId +211
#          constituent  30: pt   1.23, dz(pv) +0.004, pdgId -211
#          constituent  31: pt   1.21, dz(pv) +0.000, pdgId +130
#          constituent  32: pt   1.01, dz(pv) +0.000, pdgId +130
#          constituent  33: pt   1.00, dz(pv) +0.000, pdgId +22
#          constituent  34: pt   1.00, dz(pv) -0.016, pdgId +211
#          constituent  35: pt   0.97, dz(pv) -0.005, pdgId -211
#          constituent  36: pt   0.94, dz(pv) +0.008, pdgId +211
#          constituent  37: pt   0.86, dz(pv) +0.006, pdgId +211
#          constituent  38: pt   0.84, dz(pv) +0.000, pdgId +22
#          constituent  39: pt   0.83, dz(pv) +0.002, pdgId -211
#          constituent  40: pt   0.82, dz(pv) -0.008, pdgId +211
#          constituent  41: pt   0.73, dz(pv) +0.001, pdgId +211
#          constituent  42: pt   0.73, dz(pv) +0.000, pdgId +22
#          constituent  43: pt   0.72, dz(pv) -0.008, pdgId +211
#          constituent  44: pt   0.62, dz(pv) -0.054, pdgId +211
#          constituent  45: pt   0.20, dz(pv) -0.016, pdgId -211
#   sd subjet with pt 311.3 (raw pt 285.9), eta -0.02, mass  23.0 ungroomed
#   sd subjet with pt  60.1 (raw pt  55.1), eta -0.14, mass   6.0 ungroomed
# AK8j with pt 212.2 (raw pt 194.6), eta +0.19, mass  45.6 ungroomed,  26.9 softdrop,  38.0 pruned CHS
#          constituent   0: pt  77.06, dz(pv) +0.002, pdgId -211
#          constituent   1: pt  26.28, dz(pv) +0.003, pdgId -211
#          constituent   2: pt  21.19, dz(pv) +0.002, pdgId -211
#          constituent   3: pt  12.76, dz(pv) -0.001, pdgId +211
#          constituent   4: pt   8.83, dz(pv) +0.005, pdgId +211
#          constituent   5: pt   5.78, dz(pv) +0.003, pdgId -211
#          constituent   6: pt   4.32, dz(pv) +0.000, pdgId +211
#          constituent   7: pt   3.32, dz(pv) +0.000, pdgId +130
#          constituent   8: pt   3.31, dz(pv) +0.000, pdgId +22
#          constituent   9: pt   2.85, dz(pv) +0.005, pdgId +211
#          constituent  10: pt   2.51, dz(pv) -0.014, pdgId +211
#          constituent  11: pt   2.34, dz(pv) -0.014, pdgId +211
#          constituent  12: pt   2.34, dz(pv) -0.000, pdgId +211
#          constituent  13: pt   2.05, dz(pv) -0.004, pdgId -211
#          constituent  14: pt   1.95, dz(pv) -0.001, pdgId -211
#          constituent  15: pt   1.94, dz(pv) +0.013, pdgId +211
#          constituent  16: pt   1.78, dz(pv) +0.000, pdgId +22
#          constituent  17: pt   1.44, dz(pv) +0.047, pdgId +211
#          constituent  18: pt   1.21, dz(pv) -0.009, pdgId -211
#          constituent  19: pt   1.20, dz(pv) +0.001, pdgId +211
#          constituent  20: pt   1.07, dz(pv) +0.000, pdgId +22
#          constituent  21: pt   1.06, dz(pv) -0.006, pdgId -211
#          constituent  22: pt   1.05, dz(pv) -0.286, pdgId +211
#          constituent  23: pt   0.98, dz(pv) -0.007, pdgId -211
#          constituent  24: pt   0.90, dz(pv) +0.000, pdgId +22
#          constituent  25: pt   0.80, dz(pv) +0.000, pdgId +22
#          constituent  26: pt   0.78, dz(pv) +0.010, pdgId -211
#          constituent  27: pt   0.78, dz(pv) +0.000, pdgId +22
#          constituent  28: pt   0.74, dz(pv) +0.000, pdgId +22
#          constituent  29: pt   0.74, dz(pv) +0.001, pdgId +211
#          constituent  30: pt   0.54, dz(pv) -0.006, pdgId +211
#          constituent  31: pt   0.53, dz(pv) +0.001, pdgId +211
#          constituent  32: pt   0.52, dz(pv) +0.016, pdgId +211
#          constituent  33: pt   0.45, dz(pv) +0.000, pdgId +211
#          constituent  34: pt   0.44, dz(pv) -0.006, pdgId +211
#          constituent  35: pt   0.29, dz(pv) -0.014, pdgId -211
#          constituent  36: pt   0.25, dz(pv) +0.000, pdgId -211
#          constituent  37: pt   0.25, dz(pv) +0.017, pdgId +211
#          constituent  38: pt   0.17, dz(pv) +0.016, pdgId -211
#          constituent  39: pt   0.15, dz(pv) +0.048, pdgId -211
#   sd subjet with pt 177.9 (raw pt 163.8), eta +0.19, mass  13.7 ungroomed
#   sd subjet with pt  20.7 (raw pt  18.5), eta -0.09, mass   2.8 ungroomed
# jet  with pt 703.2 (raw pt 652.1), eta -0.79, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
#          constituent   0: pt 297.75, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  69.88, dz(pv) +0.008, pdgId -211
#          constituent   2: pt  29.14, dz(pv) +0.013, pdgId -211
#          constituent   3: pt  27.11, dz(pv) +0.000, pdgId -211
# jet  with pt 641.6 (raw pt 562.1), eta -1.40, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
# jet  with pt  29.1 (raw pt  30.9), eta -0.03, btag CSV 0.000, CISV 0.000, pileup mva disc +0.91
# jet  with pt  28.8 (raw pt  28.1), eta -1.60, btag CSV 0.000, CISV 0.000, pileup mva disc -0.77
# jet  with pt  20.5 (raw pt  20.4), eta +2.76, btag CSV 0.000, CISV 0.000, pileup mva disc -0.79
# AK8j with pt 729.4 (raw pt 658.3), eta -0.79, mass 100.0 ungroomed,   3.3 softdrop,  18.5 pruned CHS
#          constituent   0: pt 297.75, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  69.88, dz(pv) +0.008, pdgId -211
#          constituent   2: pt  29.14, dz(pv) +0.013, pdgId -211
#          constituent   3: pt  27.11, dz(pv) +0.000, pdgId -211
#          constituent   4: pt  21.97, dz(pv) -0.004, pdgId -211
#          constituent   5: pt  19.11, dz(pv) +0.000, pdgId +130
#          constituent   6: pt  18.70, dz(pv) -0.003, pdgId +211
#          constituent   7: pt  13.93, dz(pv) +0.001, pdgId +211
#          constituent   8: pt  12.87, dz(pv) -0.001, pdgId -211
#          constituent   9: pt  12.17, dz(pv) +0.001, pdgId +211
#          constituent  10: pt  12.16, dz(pv) -0.002, pdgId +211
#          constituent  11: pt  11.95, dz(pv) +0.000, pdgId +130
#          constituent  12: pt  11.52, dz(pv) +0.000, pdgId +22
#          constituent  13: pt   9.90, dz(pv) -0.004, pdgId +211
#          constituent  14: pt   8.20, dz(pv) +0.000, pdgId +22
#          constituent  15: pt   5.61, dz(pv) +0.000, pdgId +130
#          constituent  16: pt   5.60, dz(pv) +0.000, pdgId +22
#          constituent  17: pt   5.46, dz(pv) -0.004, pdgId +211
#          constituent  18: pt   4.97, dz(pv) +0.003, pdgId -211
#          constituent  19: pt   4.65, dz(pv) -0.004, pdgId -211
#          constituent  20: pt   4.57, dz(pv) +0.000, pdgId +22
#          constituent  21: pt   3.80, dz(pv) -0.000, pdgId +211
#          constituent  22: pt   3.62, dz(pv) -0.007, pdgId +211
#          constituent  23: pt   2.88, dz(pv) +0.000, pdgId +130
#          constituent  24: pt   2.86, dz(pv) +0.001, pdgId -211
#          constituent  25: pt   2.81, dz(pv) +0.016, pdgId +211
#          constituent  26: pt   2.50, dz(pv) +0.000, pdgId +22
#          constituent  27: pt   2.22, dz(pv) -0.236, pdgId +211
#          constituent  28: pt   2.13, dz(pv) -0.002, pdgId +211
#          constituent  29: pt   2.13, dz(pv) +0.011, pdgId -211
#          constituent  30: pt   2.11, dz(pv) +0.000, pdgId +22
#          constituent  31: pt   2.01, dz(pv) +0.000, pdgId +22
#          constituent  32: pt   1.99, dz(pv) -0.001, pdgId +211
#          constituent  33: pt   1.95, dz(pv) +0.000, pdgId +130
#          constituent  34: pt   1.72, dz(pv) +0.000, pdgId +22
#          constituent  35: pt   1.67, dz(pv) +0.000, pdgId +22
#          constituent  36: pt   1.64, dz(pv) +0.000, pdgId +22
#          constituent  37: pt   1.61, dz(pv) -0.007, pdgId -211
#          constituent  38: pt   1.41, dz(pv) +0.004, pdgId -211
#          constituent  39: pt   1.39, dz(pv) +0.000, pdgId -211
#          constituent  40: pt   1.21, dz(pv) +0.000, pdgId +130
#          constituent  41: pt   1.09, dz(pv) +0.000, pdgId +22
#          constituent  42: pt   1.01, dz(pv) +0.000, pdgId +130
#          constituent  43: pt   1.00, dz(pv) -0.004, pdgId +211
#          constituent  44: pt   0.96, dz(pv) +0.007, pdgId -211
#          constituent  45: pt   0.92, dz(pv) +0.000, pdgId +22
#          constituent  46: pt   0.92, dz(pv) +0.000, pdgId +22
#          constituent  47: pt   0.80, dz(pv) +0.000, pdgId +22
#          constituent  48: pt   0.79, dz(pv) +0.003, pdgId -211
#          constituent  49: pt   0.79, dz(pv) +0.000, pdgId +130
#          constituent  50: pt   0.76, dz(pv) +0.007, pdgId +211
#          constituent  51: pt   0.72, dz(pv) +0.014, pdgId -211
#          constituent  52: pt   0.71, dz(pv) +0.000, pdgId +22
#          constituent  53: pt   0.60, dz(pv) -0.020, pdgId -211
#          constituent  54: pt   0.52, dz(pv) +0.004, pdgId -211
#          constituent  55: pt   0.51, dz(pv) -0.014, pdgId +211
#          constituent  56: pt   0.45, dz(pv) -0.049, pdgId +211
#          constituent  57: pt   0.34, dz(pv) +0.116, pdgId -211
#   sd subjet with pt 400.1 (raw pt 358.8), eta -0.79, mass   1.7 ungroomed
#   sd subjet with pt  98.5 (raw pt  88.6), eta -0.80, mass   0.5 ungroomed
# AK8j with pt 643.8 (raw pt 549.5), eta -1.40, mass  62.8 ungroomed,   1.2 softdrop,  29.2 pruned CHS
#          constituent   0: pt 271.25, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  60.12, dz(pv) +0.047, pdgId +211
#          constituent   2: pt  47.12, dz(pv) -0.003, pdgId -211
#          constituent   3: pt  33.06, dz(pv) +0.000, pdgId +22
#          constituent   4: pt  15.92, dz(pv) +0.000, pdgId +22
#          constituent   5: pt  11.51, dz(pv) +0.050, pdgId -211
#          constituent   6: pt  10.81, dz(pv) +0.000, pdgId -211
#          constituent   7: pt  10.53, dz(pv) -0.000, pdgId -211
#          constituent   8: pt   9.37, dz(pv) -0.001, pdgId -211
#          constituent   9: pt   6.78, dz(pv) +0.000, pdgId +130
#          constituent  10: pt   6.57, dz(pv) -0.300, pdgId -211
#          constituent  11: pt   6.12, dz(pv) +0.001, pdgId +211
#          constituent  12: pt   5.58, dz(pv) +0.065, pdgId +211
#          constituent  13: pt   5.27, dz(pv) +0.000, pdgId +130
#          constituent  14: pt   4.89, dz(pv) +0.000, pdgId +22
#          constituent  15: pt   4.71, dz(pv) -0.003, pdgId +211
#          constituent  16: pt   4.69, dz(pv) -0.004, pdgId -211
#          constituent  17: pt   3.55, dz(pv) +0.000, pdgId +22
#          constituent  18: pt   3.50, dz(pv) +0.022, pdgId -211
#          constituent  19: pt   3.10, dz(pv) +0.000, pdgId +22
#          constituent  20: pt   3.01, dz(pv) -0.015, pdgId +211
#          constituent  21: pt   2.81, dz(pv) +0.000, pdgId +22
#          constituent  22: pt   2.53, dz(pv) +0.000, pdgId +22
#          constituent  23: pt   1.99, dz(pv) +0.150, pdgId +211
#          constituent  24: pt   1.98, dz(pv) +0.000, pdgId +22
#          constituent  25: pt   1.94, dz(pv) +0.000, pdgId +22
#          constituent  26: pt   1.82, dz(pv) +0.022, pdgId -211
#          constituent  27: pt   1.80, dz(pv) -0.011, pdgId +211
#          constituent  28: pt   1.68, dz(pv) -0.005, pdgId +211
#          constituent  29: pt   1.58, dz(pv) +0.000, pdgId +22
#          constituent  30: pt   1.49, dz(pv) +0.000, pdgId +130
#          constituent  31: pt   1.34, dz(pv) +0.000, pdgId +22
#          constituent  32: pt   1.34, dz(pv) +0.000, pdgId +130
#          constituent  33: pt   1.11, dz(pv) -0.019, pdgId -211
#          constituent  34: pt   1.07, dz(pv) +0.014, pdgId -211
#          constituent  35: pt   1.02, dz(pv) +0.000, pdgId +22
#          constituent  36: pt   0.95, dz(pv) +0.047, pdgId +211
#          constituent  37: pt   0.92, dz(pv) +0.000, pdgId +22
#          constituent  38: pt   0.88, dz(pv) +0.000, pdgId +22
#          constituent  39: pt   0.84, dz(pv) -0.006, pdgId +211
#          constituent  40: pt   0.81, dz(pv) +0.000, pdgId +22
#          constituent  41: pt   0.81, dz(pv) +0.000, pdgId +22
#          constituent  42: pt   0.75, dz(pv) +0.000, pdgId +22
#          constituent  43: pt   0.75, dz(pv) +0.000, pdgId +22
#          constituent  44: pt   0.43, dz(pv) -0.028, pdgId +211
#          constituent  45: pt   0.27, dz(pv) +0.069, pdgId -211
#   sd subjet with pt 394.9 (raw pt 331.3), eta -1.39, mass   0.7 ungroomed
#   sd subjet with pt  56.5 (raw pt  47.1), eta -1.39, mass   0.2 ungroomed
# jet  with pt 470.7 (raw pt 415.0), eta +1.39, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
#          constituent   0: pt 135.75, dz(pv) +0.002, pdgId -211
#          constituent   1: pt  46.38, dz(pv) +0.028, pdgId +211
#          constituent   2: pt  22.25, dz(pv) +0.000, pdgId +22
#          constituent   3: pt  21.80, dz(pv) -0.001, pdgId +211
# jet  with pt 291.5 (raw pt 266.4), eta +2.30, btag CSV 0.000, CISV 0.000, pileup mva disc +0.98
# jet  with pt 122.9 (raw pt 117.8), eta +0.85, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
# jet  with pt  52.8 (raw pt  45.2), eta +1.85, btag CSV 0.000, CISV 0.000, pileup mva disc +0.97
# AK8j with pt 464.1 (raw pt 395.0), eta +1.41, mass  78.5 ungroomed,  26.3 softdrop,  32.3 pruned CHS
#          constituent   0: pt 135.75, dz(pv) +0.002, pdgId -211
#          constituent   1: pt  46.38, dz(pv) +0.028, pdgId +211
#          constituent   2: pt  22.25, dz(pv) +0.000, pdgId +22
#          constituent   3: pt  21.80, dz(pv) -0.001, pdgId +211
#          constituent   4: pt  15.40, dz(pv) +0.010, pdgId +211
#          constituent   5: pt  13.19, dz(pv) +0.000, pdgId +22
#          constituent   6: pt  13.04, dz(pv) -0.003, pdgId +211
#          constituent   7: pt  12.62, dz(pv) +0.000, pdgId +130
#          constituent   8: pt  11.84, dz(pv) +0.022, pdgId -211
#          constituent   9: pt  10.77, dz(pv) +0.000, pdgId +130
#          constituent  10: pt   9.87, dz(pv) +0.004, pdgId +211
#          constituent  11: pt   7.94, dz(pv) +0.000, pdgId +130
#          constituent  12: pt   7.29, dz(pv) +0.000, pdgId +22
#          constituent  13: pt   7.08, dz(pv) +0.000, pdgId +130
#          constituent  14: pt   6.84, dz(pv) -0.004, pdgId +211
#          constituent  15: pt   6.66, dz(pv) +0.002, pdgId -211
#          constituent  16: pt   5.26, dz(pv) -0.006, pdgId +211
#          constituent  17: pt   4.71, dz(pv) +0.000, pdgId +22
#          constituent  18: pt   4.38, dz(pv) +0.000, pdgId +130
#          constituent  19: pt   3.64, dz(pv) -0.020, pdgId +211
#          constituent  20: pt   3.40, dz(pv) +0.005, pdgId -211
#          constituent  21: pt   3.36, dz(pv) +0.000, pdgId +22
#          constituent  22: pt   2.37, dz(pv) +0.000, pdgId +22
#          constituent  23: pt   2.36, dz(pv) +0.000, pdgId +130
#          constituent  24: pt   2.12, dz(pv) +0.000, pdgId +22
#          constituent  25: pt   1.94, dz(pv) -0.051, pdgId +211
#          constituent  26: pt   1.91, dz(pv) -0.034, pdgId -211
#          constituent  27: pt   1.65, dz(pv) +0.000, pdgId +22
#          constituent  28: pt   1.36, dz(pv) -0.140, pdgId -211
#          constituent  29: pt   1.29, dz(pv) +0.000, pdgId +130
#          constituent  30: pt   1.22, dz(pv) -0.003, pdgId -211
#          constituent  31: pt   0.97, dz(pv) +0.000, pdgId +22
#          constituent  32: pt   0.93, dz(pv) +0.000, pdgId +22
#          constituent  33: pt   0.93, dz(pv) +0.000, pdgId +22
#          constituent  34: pt   0.79, dz(pv) +0.000, pdgId +22
#          constituent  35: pt   0.77, dz(pv) +0.000, pdgId +22
#          constituent  36: pt   0.70, dz(pv) +0.000, pdgId +22
#          constituent  37: pt   0.66, dz(pv) +0.079, pdgId -211
#          constituent  38: pt   0.63, dz(pv) +0.000, pdgId +22
#          constituent  39: pt   0.58, dz(pv) +0.005, pdgId +211
#          constituent  40: pt   0.56, dz(pv) -0.030, pdgId +211
#          constituent  41: pt   0.49, dz(pv) -0.010, pdgId -211
#          constituent  42: pt   0.33, dz(pv) +0.061, pdgId +211
#          constituent  43: pt   0.25, dz(pv) +0.066, pdgId +211
#   sd subjet with pt 268.1 (raw pt 225.4), eta +1.42, mass   8.8 ungroomed
#   sd subjet with pt 130.4 (raw pt 110.7), eta +1.29, mass   4.6 ungroomed
# AK8j with pt 298.8 (raw pt 253.7), eta +2.30, mass  55.1 ungroomed,  42.7 softdrop,  43.8 pruned CHS
#          constituent   0: pt  47.94, dz(pv) +0.006, pdgId -211
#          constituent   1: pt  43.88, dz(pv) +0.000, pdgId +22
#          constituent   2: pt  23.42, dz(pv) +0.000, pdgId +22
#          constituent   3: pt  20.98, dz(pv) -0.009, pdgId -211
#          constituent   4: pt  16.80, dz(pv) -0.081, pdgId +211
#          constituent   5: pt  15.55, dz(pv) +0.006, pdgId +211
#          constituent   6: pt  15.32, dz(pv) -0.013, pdgId +211
#          constituent   7: pt  14.95, dz(pv) +0.028, pdgId +211
#          constituent   8: pt  10.80, dz(pv) -0.000, pdgId -211
#          constituent   9: pt   8.70, dz(pv) -0.001, pdgId +211
#          constituent  10: pt   7.22, dz(pv) +0.000, pdgId +130
#          constituent  11: pt   7.07, dz(pv) +0.002, pdgId -211
#          constituent  12: pt   6.76, dz(pv) +0.006, pdgId +211
#          constituent  13: pt   6.73, dz(pv) +0.002, pdgId +211
#          constituent  14: pt   4.16, dz(pv) +0.000, pdgId +130
#          constituent  15: pt   4.05, dz(pv) +0.000, pdgId +130
#          constituent  16: pt   2.60, dz(pv) +0.000, pdgId +22
#          constituent  17: pt   2.41, dz(pv) -0.014, pdgId +211
#          constituent  18: pt   2.30, dz(pv) +0.000, pdgId +22
#          constituent  19: pt   1.76, dz(pv) +0.000, pdgId +22
#          constituent  20: pt   1.54, dz(pv) -0.023, pdgId -211
#          constituent  21: pt   1.40, dz(pv) +0.067, pdgId -211
#          constituent  22: pt   0.97, dz(pv) +0.015, pdgId +211
#          constituent  23: pt   0.97, dz(pv) -0.107, pdgId +211
#          constituent  24: pt   0.87, dz(pv) -0.119, pdgId +211
#          constituent  25: pt   0.69, dz(pv) +0.036, pdgId -211
#          constituent  26: pt   0.68, dz(pv) +0.013, pdgId -211
#          constituent  27: pt   0.58, dz(pv) -0.086, pdgId +211
#          constituent  28: pt   0.50, dz(pv) +0.065, pdgId -211
#          constituent  29: pt   0.45, dz(pv) +0.083, pdgId -211
#          constituent  30: pt   0.27, dz(pv) +0.024, pdgId -211
#          constituent  31: pt   0.14, dz(pv) +0.168, pdgId -211
#   sd subjet with pt 216.2 (raw pt 188.8), eta +2.33, mass  14.6 ungroomed
#   sd subjet with pt  81.3 (raw pt  64.1), eta +2.17, mass   8.0 ungroomed
# AK8j with pt 127.0 (raw pt 113.7), eta +0.86, mass  22.2 ungroomed, -99999.0 softdrop,   7.8 pruned CHS
# jet  with pt 467.2 (raw pt 434.2), eta -1.78, btag CSV 0.000, CISV 0.000, pileup mva disc +0.97
#          constituent   0: pt 177.50, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  88.94, dz(pv) +0.005, pdgId -211
#          constituent   2: pt  58.31, dz(pv) +1.402, pdgId -211
#          constituent   3: pt  17.78, dz(pv) -0.003, pdgId -211
# jet  with pt 331.7 (raw pt 311.6), eta -0.34, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
# jet  with pt 190.7 (raw pt 180.2), eta -0.41, btag CSV 0.000, CISV 0.000, pileup mva disc +1.00
# jet  with pt  70.9 (raw pt  65.3), eta -1.71, btag CSV 0.000, CISV 0.000, pileup mva disc +0.98
# jet  with pt  69.7 (raw pt  66.2), eta -1.02, btag CSV 0.000, CISV 0.000, pileup mva disc +0.98
# jet  with pt  30.9 (raw pt  29.2), eta -0.85, btag CSV 0.000, CISV 0.000, pileup mva disc +0.57
# AK8j with pt 539.2 (raw pt 493.1), eta -0.41, mass 194.5 ungroomed, 177.8 softdrop, 179.1 pruned CHS
#          constituent   0: pt  56.88, dz(pv) -0.000, pdgId +211
#          constituent   1: pt  42.00, dz(pv) +0.001, pdgId +211
#          constituent   2: pt  37.78, dz(pv) -0.002, pdgId +211
#          constituent   3: pt  34.94, dz(pv) +0.000, pdgId +22
#          constituent   4: pt  25.11, dz(pv) +0.000, pdgId +130
#          constituent   5: pt  23.50, dz(pv) +0.001, pdgId -211
#          constituent   6: pt  18.17, dz(pv) -0.000, pdgId -211
#          constituent   7: pt  17.50, dz(pv) -0.001, pdgId -211
#          constituent   8: pt  14.59, dz(pv) +0.040, pdgId +11
#          constituent   9: pt  14.56, dz(pv) +0.000, pdgId +22
#          constituent  10: pt  14.45, dz(pv) +0.000, pdgId +130
#          constituent  11: pt  14.17, dz(pv) +0.004, pdgId -211
#          constituent  12: pt  10.04, dz(pv) -0.001, pdgId +211
#          constituent  13: pt   9.52, dz(pv) +0.000, pdgId +130
#          constituent  14: pt   8.70, dz(pv) -0.009, pdgId -211
#          constituent  15: pt   8.12, dz(pv) +0.002, pdgId +211
#          constituent  16: pt   8.09, dz(pv) +0.000, pdgId +22
#          constituent  17: pt   7.62, dz(pv) +0.002, pdgId +211
#          constituent  18: pt   7.24, dz(pv) -0.001, pdgId -211
#          constituent  19: pt   7.23, dz(pv) -0.005, pdgId -211
#          constituent  20: pt   5.84, dz(pv) +0.000, pdgId +130
#          constituent  21: pt   5.81, dz(pv) +0.003, pdgId -211
#          constituent  22: pt   5.75, dz(pv) +0.000, pdgId +22
#          constituent  23: pt   5.43, dz(pv) +0.002, pdgId -211
#          constituent  24: pt   5.27, dz(pv) +0.000, pdgId +130
#          constituent  25: pt   5.10, dz(pv) +0.000, pdgId +22
#          constituent  26: pt   5.09, dz(pv) +0.004, pdgId +211
#          constituent  27: pt   4.89, dz(pv) -0.003, pdgId +211
#          constituent  28: pt   4.77, dz(pv) +0.000, pdgId +22
#          constituent  29: pt   4.60, dz(pv) +0.000, pdgId +22
#          constituent  30: pt   4.58, dz(pv) +0.000, pdgId -211
#          constituent  31: pt   4.55, dz(pv) -0.002, pdgId -211
#          constituent  32: pt   4.27, dz(pv) +0.003, pdgId +211
#          constituent  33: pt   4.21, dz(pv) +0.000, pdgId +22
#          constituent  34: pt   4.04, dz(pv) +0.002, pdgId +211
#          constituent  35: pt   3.97, dz(pv) -0.007, pdgId -211
#          constituent  36: pt   3.87, dz(pv) +0.000, pdgId +22
#          constituent  37: pt   3.85, dz(pv) -0.001, pdgId +211
#          constituent  38: pt   3.59, dz(pv) -0.000, pdgId +211
#          constituent  39: pt   3.39, dz(pv) +0.000, pdgId +22
#          constituent  40: pt   3.03, dz(pv) -0.001, pdgId +211
#          constituent  41: pt   2.83, dz(pv) +0.000, pdgId +22
#          constituent  42: pt   2.58, dz(pv) +0.003, pdgId +211
#          constituent  43: pt   2.35, dz(pv) +0.002, pdgId -211
#          constituent  44: pt   2.17, dz(pv) +0.000, pdgId +22
#          constituent  45: pt   2.06, dz(pv) +0.000, pdgId +22
#          constituent  46: pt   1.88, dz(pv) +0.001, pdgId +211
#          constituent  47: pt   1.75, dz(pv) +0.000, pdgId +22
#          constituent  48: pt   1.72, dz(pv) +0.000, pdgId +22
#          constituent  49: pt   1.56, dz(pv) +0.000, pdgId +22
#          constituent  50: pt   1.55, dz(pv) +0.003, pdgId -211
#          constituent  51: pt   1.52, dz(pv) -0.005, pdgId -211
#          constituent  52: pt   1.48, dz(pv) +0.003, pdgId +211
#          constituent  53: pt   1.41, dz(pv) +0.000, pdgId +22
#          constituent  54: pt   1.32, dz(pv) +0.000, pdgId +22
#          constituent  55: pt   1.19, dz(pv) +0.000, pdgId +22
#          constituent  56: pt   1.16, dz(pv) +0.000, pdgId +22
#          constituent  57: pt   1.10, dz(pv) +0.000, pdgId +130
#          constituent  58: pt   1.07, dz(pv) +0.000, pdgId +22
#          constituent  59: pt   1.06, dz(pv) +0.000, pdgId +22
#          constituent  60: pt   1.05, dz(pv) +0.000, pdgId +22
#          constituent  61: pt   0.89, dz(pv) +0.000, pdgId +22
#          constituent  62: pt   0.87, dz(pv) +0.000, pdgId +22
#          constituent  63: pt   0.86, dz(pv) +0.000, pdgId +22
#          constituent  64: pt   0.86, dz(pv) +0.000, pdgId +22
#          constituent  65: pt   0.68, dz(pv) +0.000, pdgId +22
#          constituent  66: pt   0.67, dz(pv) +0.000, pdgId +22
# ...
#   sd subjet with pt 318.2 (raw pt 291.5), eta -0.33, mass   7.4 ungroomed
#   sd subjet with pt 104.3 (raw pt  95.2), eta -0.43, mass   4.9 ungroomed
# AK8j with pt 388.4 (raw pt 355.4), eta -0.31, mass 115.1 ungroomed, 102.2 softdrop,  84.1 pruned CHS
#          constituent   0: pt  34.03, dz(pv) +0.001, pdgId +211
#          constituent   1: pt  32.50, dz(pv) +0.000, pdgId +22
#          constituent   2: pt  30.61, dz(pv) +0.000, pdgId +130
#          constituent   3: pt  25.02, dz(pv) +0.003, pdgId -211
#          constituent   4: pt  22.20, dz(pv) +0.001, pdgId +211
#          constituent   5: pt  22.06, dz(pv) -0.004, pdgId -211
#          constituent   6: pt  19.25, dz(pv) +0.000, pdgId +22
#          constituent   7: pt  12.07, dz(pv) +0.001, pdgId -211
#          constituent   8: pt  11.71, dz(pv) -0.002, pdgId -211
#          constituent   9: pt   8.96, dz(pv) +0.000, pdgId +22
#          constituent  10: pt   8.33, dz(pv) -0.000, pdgId +211
#          constituent  11: pt   8.14, dz(pv) -0.001, pdgId +211
#          constituent  12: pt   7.84, dz(pv) -0.003, pdgId -211
#          constituent  13: pt   7.48, dz(pv) -0.002, pdgId -211
#          constituent  14: pt   7.34, dz(pv) -0.004, pdgId -211
#          constituent  15: pt   6.74, dz(pv) -0.005, pdgId +211
#          constituent  16: pt   5.53, dz(pv) -0.003, pdgId +211
#          constituent  17: pt   4.84, dz(pv) +0.005, pdgId -211
#          constituent  18: pt   3.98, dz(pv) +0.000, pdgId +22
#          constituent  19: pt   3.70, dz(pv) +0.000, pdgId +22
#          constituent  20: pt   3.53, dz(pv) -0.001, pdgId -211
#          constituent  21: pt   3.47, dz(pv) +0.000, pdgId +22
#          constituent  22: pt   3.42, dz(pv) -0.013, pdgId -211
#          constituent  23: pt   2.87, dz(pv) -0.001, pdgId +211
#          constituent  24: pt   2.81, dz(pv) +0.006, pdgId -211
#          constituent  25: pt   2.72, dz(pv) -0.001, pdgId +211
#          constituent  26: pt   2.71, dz(pv) +0.004, pdgId -211
#          constituent  27: pt   2.61, dz(pv) -0.000, pdgId -211
#          constituent  28: pt   2.58, dz(pv) -0.001, pdgId +211
#          constituent  29: pt   2.42, dz(pv) +0.000, pdgId +22
#          constituent  30: pt   2.31, dz(pv) -0.000, pdgId -211
#          constituent  31: pt   2.21, dz(pv) +0.003, pdgId +211
#          constituent  32: pt   2.19, dz(pv) +0.000, pdgId +22
#          constituent  33: pt   2.13, dz(pv) -0.005, pdgId -211
#          constituent  34: pt   2.11, dz(pv) +0.097, pdgId +211
#          constituent  35: pt   2.05, dz(pv) +0.000, pdgId +22
#          constituent  36: pt   1.99, dz(pv) +0.001, pdgId +211
#          constituent  37: pt   1.96, dz(pv) +0.003, pdgId -211
#          constituent  38: pt   1.95, dz(pv) +0.000, pdgId +22
#          constituent  39: pt   1.93, dz(pv) +0.000, pdgId +22
#          constituent  40: pt   1.59, dz(pv) +0.001, pdgId -211
#          constituent  41: pt   1.58, dz(pv) +0.000, pdgId +22
#          constituent  42: pt   1.40, dz(pv) -0.005, pdgId -211
#          constituent  43: pt   1.36, dz(pv) +0.000, pdgId +22
#          constituent  44: pt   1.33, dz(pv) +0.046, pdgId -211
#          constituent  45: pt   1.31, dz(pv) -0.004, pdgId +211
#          constituent  46: pt   1.30, dz(pv) +0.001, pdgId +211
#          constituent  47: pt   1.26, dz(pv) +0.003, pdgId +211
#          constituent  48: pt   1.25, dz(pv) -0.002, pdgId +211
#          constituent  49: pt   1.23, dz(pv) -0.005, pdgId -211
#          constituent  50: pt   1.17, dz(pv) +0.000, pdgId +22
#          constituent  51: pt   1.05, dz(pv) +0.000, pdgId +211
#          constituent  52: pt   1.01, dz(pv) +0.000, pdgId +22
#          constituent  53: pt   1.01, dz(pv) +0.005, pdgId -211
#          constituent  54: pt   0.96, dz(pv) +0.016, pdgId -211
#          constituent  55: pt   0.90, dz(pv) +0.000, pdgId +22
#          constituent  56: pt   0.83, dz(pv) +0.000, pdgId +22
#          constituent  57: pt   0.83, dz(pv) -0.022, pdgId -211
#          constituent  58: pt   0.77, dz(pv) +0.041, pdgId +211
#          constituent  59: pt   0.76, dz(pv) +0.000, pdgId +22
#          constituent  60: pt   0.71, dz(pv) +0.011, pdgId -211
#          constituent  61: pt   0.67, dz(pv) +0.015, pdgId +211
#          constituent  62: pt   0.58, dz(pv) +0.027, pdgId +211
#          constituent  63: pt   0.58, dz(pv) +0.000, pdgId +22
#          constituent  64: pt   0.57, dz(pv) +0.113, pdgId +211
#          constituent  65: pt   0.56, dz(pv) +0.010, pdgId -211
#          constituent  66: pt   0.44, dz(pv) -0.291, pdgId -211
#          constituent  67: pt   0.37, dz(pv) +0.002, pdgId +211
#          constituent  68: pt   0.31, dz(pv) -0.014, pdgId -211
#          constituent  69: pt   0.24, dz(pv) -0.003, pdgId -211
#          constituent  70: pt   0.22, dz(pv) -0.030, pdgId +211
#          constituent  71: pt   0.22, dz(pv) +0.027, pdgId +211
#   sd subjet with pt 332.3 (raw pt 303.7), eta -0.37, mass  68.8 ungroomed
#   sd subjet with pt  55.2 (raw pt  50.6), eta +0.09, mass  12.6 ungroomed
# AK8j with pt 169.8 (raw pt 152.7), eta -0.70, mass  38.9 ungroomed, -99999.0 softdrop,  17.5 pruned CHS
# jet  with pt 492.2 (raw pt 463.9), eta +0.05, btag CSV 0.000, CISV 0.000, pileup mva disc +1.00
#          constituent   0: pt 135.38, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  91.00, dz(pv) -0.006, pdgId -211
#          constituent   2: pt  70.25, dz(pv) -0.001, pdgId -211
#          constituent   3: pt  65.31, dz(pv) -0.003, pdgId +211
# jet  with pt 478.4 (raw pt 422.0), eta +1.45, btag CSV 0.000, CISV 0.000, pileup mva disc +1.00
# jet  with pt  94.7 (raw pt  83.1), eta +1.89, btag CSV 0.000, CISV 0.000, pileup mva disc +0.99
# jet  with pt  35.2 (raw pt  35.1), eta -0.02, btag CSV 0.000, CISV 0.000, pileup mva disc +0.98
# AK8j with pt 548.9 (raw pt 482.0), eta +1.55, mass 160.3 ungroomed, 140.8 softdrop, 138.1 pruned CHS
#          constituent   0: pt 148.12, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  53.16, dz(pv) -0.004, pdgId -211
#          constituent   2: pt  44.84, dz(pv) +0.009, pdgId -211
#          constituent   3: pt  35.44, dz(pv) +0.000, pdgId +130
#          constituent   4: pt  26.58, dz(pv) +0.003, pdgId +211
#          constituent   5: pt  20.45, dz(pv) +0.011, pdgId +211
#          constituent   6: pt  17.89, dz(pv) -0.042, pdgId -211
#          constituent   7: pt  13.49, dz(pv) +0.000, pdgId +22
#          constituent   8: pt   9.59, dz(pv) -0.007, pdgId +211
#          constituent   9: pt   7.62, dz(pv) -0.004, pdgId -211
#          constituent  10: pt   7.44, dz(pv) +0.000, pdgId +130
#          constituent  11: pt   7.33, dz(pv) +0.024, pdgId +11
#          constituent  12: pt   7.30, dz(pv) +0.000, pdgId +22
#          constituent  13: pt   6.86, dz(pv) -0.005, pdgId +211
#          constituent  14: pt   6.44, dz(pv) +0.000, pdgId +130
#          constituent  15: pt   5.93, dz(pv) -0.002, pdgId +211
#          constituent  16: pt   5.92, dz(pv) +0.000, pdgId +22
#          constituent  17: pt   5.50, dz(pv) +0.007, pdgId -211
#          constituent  18: pt   5.46, dz(pv) -0.003, pdgId +211
#          constituent  19: pt   4.84, dz(pv) +0.000, pdgId +22
#          constituent  20: pt   4.66, dz(pv) -0.013, pdgId +211
#          constituent  21: pt   4.65, dz(pv) -0.018, pdgId -211
#          constituent  22: pt   3.83, dz(pv) -0.001, pdgId -211
#          constituent  23: pt   3.21, dz(pv) +0.000, pdgId +22
#          constituent  24: pt   3.01, dz(pv) -0.163, pdgId +211
#          constituent  25: pt   2.66, dz(pv) +0.000, pdgId +130
#          constituent  26: pt   2.52, dz(pv) -0.006, pdgId -211
#          constituent  27: pt   2.11, dz(pv) -0.030, pdgId -211
#          constituent  28: pt   1.98, dz(pv) +0.000, pdgId +22
#          constituent  29: pt   1.91, dz(pv) +0.047, pdgId -211
#          constituent  30: pt   1.88, dz(pv) +0.010, pdgId +211
#          constituent  31: pt   1.54, dz(pv) +0.000, pdgId +22
#          constituent  32: pt   1.49, dz(pv) +0.028, pdgId +211
#          constituent  33: pt   1.39, dz(pv) -0.004, pdgId -211
#          constituent  34: pt   1.35, dz(pv) +0.000, pdgId +22
#          constituent  35: pt   1.31, dz(pv) +0.000, pdgId +22
#          constituent  36: pt   1.27, dz(pv) +0.001, pdgId -211
#          constituent  37: pt   1.19, dz(pv) +0.000, pdgId +22
#          constituent  38: pt   1.16, dz(pv) +0.000, pdgId +22
#          constituent  39: pt   1.07, dz(pv) +0.019, pdgId +211
#          constituent  40: pt   1.00, dz(pv) +0.000, pdgId +22
#          constituent  41: pt   0.98, dz(pv) +0.000, pdgId +22
#          constituent  42: pt   0.94, dz(pv) +0.000, pdgId +22
#          constituent  43: pt   0.89, dz(pv) +0.000, pdgId +22
#          constituent  44: pt   0.85, dz(pv) +0.000, pdgId +22
#          constituent  45: pt   0.84, dz(pv) +0.000, pdgId +22
#          constituent  46: pt   0.84, dz(pv) +0.000, pdgId +22
#          constituent  47: pt   0.77, dz(pv) +0.090, pdgId +211
#          constituent  48: pt   0.62, dz(pv) -0.037, pdgId +211
#          constituent  49: pt   0.59, dz(pv) -0.010, pdgId -211
#          constituent  50: pt   0.59, dz(pv) -0.177, pdgId +211
#          constituent  51: pt   0.56, dz(pv) +0.215, pdgId +211
#          constituent  52: pt   0.53, dz(pv) -0.047, pdgId -211
#          constituent  53: pt   0.42, dz(pv) -0.216, pdgId +211
#   sd subjet with pt 483.1 (raw pt 409.2), eta +1.44, mass  55.0 ungroomed
#   sd subjet with pt 102.0 (raw pt  83.0), eta +1.87, mass  15.4 ungroomed
# AK8j with pt 531.5 (raw pt 489.4), eta +0.05, mass  89.4 ungroomed,   3.5 softdrop,  15.4 pruned CHS
#          constituent   0: pt 135.38, dz(pv) +0.000, pdgId +22
#          constituent   1: pt  91.00, dz(pv) -0.006, pdgId -211
#          constituent   2: pt  70.25, dz(pv) -0.001, pdgId -211
#          constituent   3: pt  65.31, dz(pv) -0.003, pdgId +211
#          constituent   4: pt  17.88, dz(pv) +0.001, pdgId +211
#          constituent   5: pt  17.78, dz(pv) +0.001, pdgId +211
#          constituent   6: pt  15.43, dz(pv) +0.002, pdgId +211
#          constituent   7: pt  13.34, dz(pv) +0.007, pdgId -211
#          constituent   8: pt  12.12, dz(pv) +0.000, pdgId +22
#          constituent   9: pt   8.99, dz(pv) -0.004, pdgId +211
#          constituent  10: pt   6.09, dz(pv) +0.006, pdgId +211
#          constituent  11: pt   5.36, dz(pv) -0.005, pdgId +211
#          constituent  12: pt   5.04, dz(pv) -0.002, pdgId -211
#          constituent  13: pt   3.96, dz(pv) +0.002, pdgId -211
#          constituent  14: pt   3.69, dz(pv) +0.000, pdgId +22
#          constituent  15: pt   3.29, dz(pv) +0.000, pdgId +22
#          constituent  16: pt   3.01, dz(pv) +0.004, pdgId +211
#          constituent  17: pt   2.28, dz(pv) -0.001, pdgId -211
#          constituent  18: pt   2.01, dz(pv) +0.000, pdgId +130
#          constituent  19: pt   1.56, dz(pv) +0.000, pdgId +22
#          constituent  20: pt   1.52, dz(pv) +0.000, pdgId +22
#          constituent  21: pt   1.50, dz(pv) -0.000, pdgId -211
#          constituent  22: pt   1.29, dz(pv) +0.006, pdgId -211
#          constituent  23: pt   1.17, dz(pv) -0.006, pdgId -211
#          constituent  24: pt   1.11, dz(pv) -0.030, pdgId +211
#          constituent  25: pt   0.98, dz(pv) +0.004, pdgId -211
#          constituent  26: pt   0.90, dz(pv) +0.000, pdgId +22
#          constituent  27: pt   0.90, dz(pv) +0.000, pdgId +22
#          constituent  28: pt   0.87, dz(pv) +0.000, pdgId +22
#          constituent  29: pt   0.85, dz(pv) +0.000, pdgId +22
#          constituent  30: pt   0.79, dz(pv) +0.000, pdgId +22
#          constituent  31: pt   0.57, dz(pv) +0.014, pdgId +211
#          constituent  32: pt   0.45, dz(pv) +0.001, pdgId -211
#          constituent  33: pt   0.43, dz(pv) +0.006, pdgId +211
#          constituent  34: pt   0.29, dz(pv) +0.116, pdgId -211
#          constituent  35: pt   0.17, dz(pv) -0.039, pdgId -211
#   sd subjet with pt 322.8 (raw pt 296.7), eta +0.05, mass   2.0 ungroomed
#   sd subjet with pt  90.5 (raw pt  83.1), eta +0.06, mass   0.6 ungroomed
# 27-Aug-2020 14:38:57 CEST  Initiating request to open file root://eoscms.cern.ch//eos/cms/store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root
# %MSG-w XrdAdaptorInternal:  file_open 27-Aug-2020 14:38:58 CEST pre-events
# Failed to open file at URL root://eoscms.cern.ch:1094//eos/cms/store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root.
# %MSG
# %MSG-w XrdAdaptorInternal:  file_open 27-Aug-2020 14:38:58 CEST pre-events
# Failed to open file at URL root://eoscms.cern.ch:1094//eos/cms/store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root?tried=.
# %MSG
# 27-Aug-2020 14:38:58 CEST  Fallback request to file root://xrootd-cms.infn.it//store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root
# %MSG-w XrdAdaptor:  file_open 27-Aug-2020 14:39:00 CEST pre-events
# Data is served from T2_IT_Pisa instead of original site infn.it
# %MSG
# 27-Aug-2020 14:39:03 CEST  Successfully opened file root://xrootd-cms.infn.it//store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root
# Begin processing the 1st record. Run 1, Event 60232781, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.178 CEST
# Begin processing the 2nd record. Run 1, Event 60232853, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.345 CEST
# Begin processing the 3rd record. Run 1, Event 60232812, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.349 CEST
# Begin processing the 4th record. Run 1, Event 60232757, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.353 CEST
# Begin processing the 5th record. Run 1, Event 60232827, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.364 CEST
# Begin processing the 6th record. Run 1, Event 60232833, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.369 CEST
# Begin processing the 7th record. Run 1, Event 60232764, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.373 CEST
# Begin processing the 8th record. Run 1, Event 60232846, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.384 CEST
# Begin processing the 9th record. Run 1, Event 60232862, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.388 CEST
# Begin processing the 10th record. Run 1, Event 60232761, LumiSection 4579 on stream 0 at 27-Aug-2020 14:39:27.395 CEST
# 27-Aug-2020 14:39:27 CEST  Closed file root://xrootd-cms.infn.it//store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root
#
# =============================================
#
# MessageLogger Summary
#
#  type     category        sev    module        subroutine        count    total
#  ---- -------------------- -- ---------------- ----------------  -----    -----
#     1 XrdAdaptor           -w file_open                              1        1
#     2 XrdAdaptorInternal   -w file_open                              2        2
#     3 fileAction           -s file_close                             1        1
#     4 fileAction           -s file_open                              3        3
#
#  type    category    Examples: run/evt        run/evt          run/evt
#  ---- -------------------- ---------------- ---------------- ----------------
#     1 XrdAdaptor           pre-events
#     2 XrdAdaptorInternal   pre-events       pre-events
#     3 fileAction           PostGlobalEndRun
#     4 fileAction           pre-events       pre-events       pre-events
#
# Severity    # Occurrences   Total Occurrences
# --------    -------------   -----------------
# Warning                 3                   3
# System                  4                   4
#
# dropped waiting message count 0

# %% [markdown]
# ##### In Python
#
# If you are on the terminal, please take a look at the file `$CMSSW_BASE/src/Analysis/JMEDAS/scripts/jmedas_miniAODtest_purePython.py`.  The same code can be seen by clicking in the link below:
#
# <details>
#     <summary><font color='blue'>SHOW CODE</font></summary>
# <p>
#
# ```python
# # import ROOT in batch mode
# import sys
# oldargv = sys.argv[:]
# sys.argv = [ '-b-' ]
# import ROOT
# ROOT.gROOT.SetBatch(True)
# sys.argv = oldargv
#
# # load FWLite C++ libraries
# ROOT.gSystem.Load("libFWCoreFWLite.so");
# ROOT.gSystem.Load("libDataFormatsFWLite.so");
# ROOT.FWLiteEnabler.enable()
#
# # load FWlite python libraries
# from DataFormats.FWLite import Handle, Events
#
# jets, jetLabel = Handle("std::vector<pat::Jet>"), "slimmedJets"
# fatjets, fatjetLabel = Handle("std::vector<pat::Jet>"), "slimmedJetsAK8"
# vertices, vertexLabel = Handle("std::vector<reco::Vertex>"), "offlineSlimmedPrimaryVertices"
# verticesScore = Handle("edm::ValueMap<float>")
# seenIt = {} # list of things we've seen (so that we dump them in full only once)
#
# # open file (you can use 'edmFileUtil -d /store/whatever.root' to get the physical file name)
# events = Events('root://cms-xrd-global.cern.ch//store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root' )
#
# for iev,event in enumerate(events):
#     if iev >= 10: break
#     event.getByLabel(jetLabel, jets)
#     event.getByLabel(fatjetLabel, fatjets)
#     event.getByLabel(vertexLabel, vertices)
#     event.getByLabel(vertexLabel, verticesScore)
#
#     print "\nEvent %d: run %6d, lumi %4d, event %12d" % (iev,event.eventAuxiliary().run(), event.eventAuxiliary().luminosityBlock(),event.eventAuxiliary().event())
#
#     # Vertices
#     if len(vertices.product()) == 0 or vertices.product()[0].ndof() < 4:
#         print "Event has no good primary vertex."
#         continue
#     else:
#         PV = vertices.product()[0]
#         print "PV at x,y,z = %+5.3f, %+5.3f, %+6.3f, ndof: %.1f, score: (pt2 of clustered objects) %.1f" % (PV.x(), PV.y(), PV.z(), PV.ndof(),verticesScore.product().get(0))
#
#
#     # Jets (AK4, CHS and Puppi)
#     for jetLabel, algo in ("slimmedJets", "CHS"), ("slimmedJetsPuppi", "PUPPI"):
#         event.getByLabel(jetLabel, jets)
#         for i,j in enumerate(jets.product()):
#             if j.pt() < 20: continue
#             print "jet %s %3d: pt %5.1f (raw pt %5.1f, matched-calojet pt %5.1f), eta %+4.2f, btag CSVIVFv2 %.3f, CMVAv2 %.3f, pileup mva disc %+.2f" % (
#                 algo, i, j.pt(), j.pt()*j.jecFactor('Uncorrected'), j.userFloat("caloJetMap:pt") if algo == "CHS" else -99.0, j.eta(), max(0,j.bDiscriminator("pfCombinedInclusiveSecondaryVertexV2BJetTags")), max(0,j.bDiscriminator("pfCombinedMVAV2BJetTags")), j.userFloat("pileupJetId:fullDiscriminant") if algo == "CHS" else -99)
#             if 'jetAk4'+algo not in seenIt:
#                 constituents = [ j.daughter(i2) for i2 in xrange(j.numberOfDaughters()) ]
#                 constituents.sort(key = lambda c:c.pt(), reverse=True)
#                 for i2, cand in enumerate(constituents):
#                     if i2 > 12:
#                             print "         ....."
#                             break
#                     print "         constituent %3d: pt %6.2f, dz(pv) %+.3f, pdgId %+3d, hcal energy fraction %.2f, puppi weight %.3f " % (i2,cand.pt(),cand.dz(PV.position()),cand.pdgId(),cand.hcalFraction(),cand.puppiWeight())
#                 print "   btag discriminators:"
#                 for btag in j.getPairDiscri():
#                     print  "\t%s %s" % (btag.first, btag.second)
#                 print "   userFloats:"
#                 for ufl in j.userFloatNames():
#                     print  "\t%s %s" % (ufl, j.userFloat(ufl))
#                 seenIt['jetAk4'+algo] = True
#
#     # Fat AK8 Jets
#     for i,j in enumerate(fatjets.product()):
#         print "jetAK8 %3d: pt %5.1f (raw pt %5.1f), eta %+4.2f, mass %5.1f ungroomed, %5.1f softdrop, %5.1f pruned CHS. " % (
#             i, j.pt(), j.pt()*j.jecFactor('Uncorrected'), j.eta(), j.mass(), j.userFloat('ak8PFJetsPuppiSoftDropMass'), j.userFloat('ak8PFJetsCHSValueMap:ak8PFJetsCHSPrunedMass'))
#         # If you use CMSSW_9_4_<=6 to read MiniAOD, to get the constituents of the AK8 jets, you have to loop over all of the
#         # daughters recursively. To save space, the first two constituents are actually
#         # the Soft Drop SUBJETS, which will then point to their daughters.
#         # The remaining constituents are those constituents removed by soft drop but
#         # still in the AK8 jet.
#         if 'jetAk8' not in seenIt:
#             constituents = []
#             for ida in xrange( j.numberOfDaughters() ) :
#                 cand = j.daughter(ida)
#                 if cand.numberOfDaughters() == 0 :
#                     constituents.append( cand )
#                 else : # only needed in CMSSW_9_4_<=6
#                     for jda in xrange( cand.numberOfDaughters() ) : # only needed in CMSSW_9_4_<=6
#                         cand2 = cand.daughter(jda) # only needed in CMSSW_9_4_<=6
#                         constituents.append( cand2 ) # only needed in CMSSW_9_4_<=6
#             constituents.sort(key = lambda c:c.pt(), reverse=True)
#             for i2, cand in enumerate(constituents):
#                 if i2 >4:
#                             print "         ....."
#                             break
#                 print "         constituent %3d: pt %6.2f, pdgId %+3d, #dau %+3d" % (i2,cand.pt(),cand.pdgId(), cand.numberOfDaughters())
#             print "   btag discriminators:"
#             for btag in j.getPairDiscri():
#                 print  "\t%s %s" % (btag.first, btag.second)
#             print "   userFloats:"
#             for ufl in j.userFloatNames():
#                 print  "\t%s %s" % (ufl, j.userFloat(ufl))
#             seenIt['jetAk8'] = True
#         # Print Subjets
#         if 'jetAk8SD' not in seenIt:
#             sdSubjets = j.subjets('SoftDropPuppi')
#             for isd,sdsub in enumerate( sdSubjets ) :
#                 print "   w subjet %3d: pt %5.1f (raw pt %5.1f), eta %+4.2f, mass %5.1f " % (
#                     isd, sdsub.pt(), sdsub.pt()*sdsub.jecFactor('Uncorrected'), sdsub.eta(), sdsub.mass()
#                     )
#                 print "   \tbtag discriminators:"
#                 for btag in sdsub.getPairDiscri():
#                     print  "\t\t%s %s" % (btag.first, btag.second)
#                 print "   \tuserFloats:"
#                 for ufl in sdsub.userFloatNames():
#                     print  "\t\t%s %s" % (ufl, sdsub.userFloat(ufl))
#                 seenIt['jetAk8SD'] = True
#
# ```
#
# </p>
# </details>
#
# This code can be run with simple python in your terminal. Similar as in the case for C++, the output of this job is some information about jets. The most important part of the exercise is to get familiar with how to access jet collections using python from miniAOD.

# %%
# %%bash
# python $CMSSW_BASE/src/Analysis/JMEDAS/scripts/jmedas_miniAODtest_purePython.py
# Out:
# Event 0: run      1, lumi 4579, event     60232781
# PV at x,y,z = +0.011, +0.040, +3.341, ndof: 109.9, score: (pt2 of clustered objects) 74493.3
# jet CHS   0: pt 634.8 (raw pt 585.1, matched-calojet pt 593.2), eta -0.93, btag CSVIVFv2 0.178, CMVAv2 0.000, pileup mva disc +0.99
#          constituent   0: pt 234.50, dz(pv) -0.003, pdgId +211, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   1: pt 224.38, dz(pv) +0.000, pdgId +130, hcal energy fraction 1.00, puppi weight 1.000
#          constituent   2: pt  42.62, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   3: pt  24.61, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   4: pt  16.91, dz(pv) -7.348, pdgId +211, hcal energy fraction 0.00, puppi weight 0.000
#          constituent   5: pt   6.58, dz(pv) +0.000, pdgId +211, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   6: pt   5.48, dz(pv) +0.008, pdgId -211, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   7: pt   5.29, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   8: pt   3.41, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   9: pt   1.93, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent  10: pt   1.80, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent  11: pt   1.72, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent  12: pt   1.32, dz(pv) +0.000, pdgId +130, hcal energy fraction 1.00, puppi weight 1.000
#          .....
#    btag discriminators:
# 	pfJetBProbabilityBJetTags 0.0437529347837
# 	pfJetProbabilityBJetTags 0.00788074731827
# 	pfTrackCountingHighEffBJetTags 0.201953902841
# 	pfSimpleSecondaryVertexHighEffBJetTags -1.0
# 	pfSimpleInclusiveSecondaryVertexHighEffBJetTags -1.0
# 	pfCombinedSecondaryVertexV2BJetTags 0.177863776684
# 	pfCombinedInclusiveSecondaryVertexV2BJetTags 0.177863776684
# 	softPFMuonBJetTags -inf
# 	softPFElectronBJetTags -inf
# 	pfCombinedMVAV2BJetTags -0.968938529491
# 	pfCombinedCvsLJetTags -0.568447351456
# 	pfCombinedCvsBJetTags 0.619396865368
# 	pfDeepCSVJetTags:probb 0.0481289029121
# 	pfDeepCSVJetTags:probc 0.0895873829722
# 	pfDeepCSVJetTags:probudsg 0.862126588821
# 	pfDeepCSVJetTags:probbb 0.000157126385602
# 	pfDeepCSVDiscriminatorsJetTags:BvsAll 0.0482860282063
# 	pfDeepCSVDiscriminatorsJetTags:CvsB 0.64977991581
# 	pfDeepCSVDiscriminatorsJetTags:CvsL 0.0941326767206
# 	pfDeepFlavourJetTags:probb 0.0198741648346
# 	pfDeepFlavourJetTags:probc 0.105188697577
# 	pfDeepFlavourJetTags:probg 0.126428410411
# 	pfDeepFlavourJetTags:problepb 0.0176978856325
# 	pfDeepFlavourJetTags:probbb 8.58413550304e-05
# 	pfDeepFlavourJetTags:probuds 0.730725049973
#    userFloats:
# 	QGTagger:qgLikelihood 0.996465563774
# 	caloJetMap:emEnergyFraction 0.161997258663
# 	caloJetMap:pt 593.167785645
# 	pileupJetId:fullDiscriminant 0.989084362984
# jet CHS   1: pt 520.5 (raw pt 490.2, matched-calojet pt 492.0), eta +0.27, btag CSVIVFv2 0.185, CMVAv2 0.000, pileup mva disc +0.98
# jet PUPPI   0: pt 625.7 (raw pt 562.4, matched-calojet pt -99.0), eta -0.93, btag CSVIVFv2 0.198, CMVAv2 0.000, pileup mva disc -99.00
#          constituent   0: pt 234.50, dz(pv) -0.003, pdgId +211, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   1: pt 224.38, dz(pv) +0.000, pdgId +130, hcal energy fraction 1.00, puppi weight 1.000
#          constituent   2: pt  42.62, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   3: pt  24.61, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   4: pt   6.58, dz(pv) +0.000, pdgId +211, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   5: pt   5.48, dz(pv) +0.008, pdgId -211, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   6: pt   5.29, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   7: pt   3.41, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   8: pt   1.93, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent   9: pt   1.80, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent  10: pt   1.72, dz(pv) +0.000, pdgId +22, hcal energy fraction 0.00, puppi weight 1.000
#          constituent  11: pt   1.32, dz(pv) +0.000, pdgId +130, hcal energy fraction 1.00, puppi weight 1.000
#          constituent  12: pt   1.26, dz(pv) +0.010, pdgId -211, hcal energy fraction 0.00, puppi weight 1.000
#          .....
#    btag discriminators:
# 	pfSimpleInclusiveSecondaryVertexHighEffBJetTags -1.0
# 	pfJetBProbabilityBJetTags 0.0437529347837
# 	pfCombinedCvsBJetTags 0.549939274788
# 	pfCombinedInclusiveSecondaryVertexV2BJetTags 0.197895616293
# 	softPFMuonBJetTags -inf
# 	pfCombinedCvsLJetTags -0.518340408802
# 	pfDeepCSVJetTags:probbb 0.000168823215063
# 	pfDeepCSVJetTags:probudsg 0.847916603088
# 	softPFElectronBJetTags -inf
# 	pfSimpleSecondaryVertexHighEffBJetTags -1.0
# 	pfJetProbabilityBJetTags 0.00788074731827
# 	pfCombinedSecondaryVertexV2BJetTags 0.197895616293
# 	pfDeepCSVJetTags:probb 0.0548729524016
# 	pfCombinedMVAV2BJetTags -0.966681718826
# 	pfDeepCSVJetTags:probc 0.0970415920019
# 	pfTrackCountingHighEffBJetTags 0.201953902841
# 	pfDeepCSVDiscriminatorsJetTags:BvsAll 0.0550417751074
# 	pfDeepCSVDiscriminatorsJetTags:CvsB 0.638081550598
# 	pfDeepCSVDiscriminatorsJetTags:CvsL 0.102694056928
#    userFloats:
# 	patPuppiJetSpecificProducer:HFEMPuppiMultiplicity 0.0
# 	patPuppiJetSpecificProducer:HFHadronPuppiMultiplicity 0.0
# 	patPuppiJetSpecificProducer:neutralHadronPuppiMultiplicity 3.0
# 	patPuppiJetSpecificProducer:neutralPuppiMultiplicity 16.0
# 	patPuppiJetSpecificProducer:photonPuppiMultiplicity 13.0
# 	patPuppiJetSpecificProducer:puppiMultiplicity 22.0
# jet PUPPI   1: pt 530.9 (raw pt 488.4, matched-calojet pt -99.0), eta +0.27, btag CSVIVFv2 0.180, CMVAv2 0.000, pileup mva disc -99.00
# jetAK8   0: pt 632.2 (raw pt 567.6), eta -0.93, mass  45.6 ungroomed,   0.9 softdrop,  16.5 pruned CHS.
#          constituent   0: pt 234.50, pdgId +211, #dau  +0
#          constituent   1: pt 224.38, pdgId +130, #dau  +0
#          constituent   2: pt  42.62, pdgId +22, #dau  +0
#          constituent   3: pt  24.61, pdgId +22, #dau  +0
#          constituent   4: pt   6.58, pdgId +211, #dau  +0
#          .....
#    btag discriminators:
# 	pfCombinedInclusiveSecondaryVertexV2BJetTags 0.202562436461
# 	pfDeepCSVJetTags:probudsg 0.84937441349
# 	pfDeepCSVJetTags:probbb 0.000159366041771
# 	pfBoostedDoubleSecondaryVertexAK8BJetTags 0.119033008814
# 	pfCombinedSecondaryVertexV2BJetTags 0.202562436461
# 	pfCombinedMVAV2BJetTags -0.966681718826
# 	pfDeepCSVJetTags:probc 0.096207998693
# 	pfDeepCSVJetTags:probb 0.0542582459748
# 	pfDeepDoubleBJetTags:probH 0.13763140142
# 	pfDeepDoubleBJetTags:probQ 0.862368643284
#    userFloats:
# 	NjettinessAK8Puppi:tau1 0.0221699606627
# 	NjettinessAK8Puppi:tau2 0.0197976008058
# 	NjettinessAK8Puppi:tau3 0.0162035524845
# 	NjettinessAK8Puppi:tau4 0.0145795121789
# 	ak8PFJetsCHSValueMap:NjettinessAK8CHSTau1 0.0446759387851
# 	ak8PFJetsCHSValueMap:NjettinessAK8CHSTau2 0.0389557667077
# 	ak8PFJetsCHSValueMap:NjettinessAK8CHSTau3 0.0324161574244
# 	ak8PFJetsCHSValueMap:NjettinessAK8CHSTau4 0.0303050708026
# 	ak8PFJetsCHSValueMap:ak8PFJetsCHSPrunedMass 16.5404949188
# 	ak8PFJetsCHSValueMap:ak8PFJetsCHSSoftDropMass 0.873726665974
# 	ak8PFJetsCHSValueMap:eta -0.935591042042
# 	ak8PFJetsCHSValueMap:mass 81.4901809692
# 	ak8PFJetsCHSValueMap:phi -1.01717102528
# 	ak8PFJetsCHSValueMap:pt 638.746032715
# 	ak8PFJetsPuppiSoftDropMass 0.873724639416
# 	ak8PFJetsPuppiSoftDropValueMap:nb1AK8PuppiSoftDropN2 -1.0
# 	ak8PFJetsPuppiSoftDropValueMap:nb1AK8PuppiSoftDropN3 -1.0
# 	ak8PFJetsPuppiSoftDropValueMap:nb2AK8PuppiSoftDropN2 -1.0
# 	ak8PFJetsPuppiSoftDropValueMap:nb2AK8PuppiSoftDropN3 -1.0
# 	nb1AK8PuppiSoftDrop:ecfN2 -1.0
# 	nb1AK8PuppiSoftDrop:ecfN3 -1.0
# 	nb2AK8PuppiSoftDrop:ecfN2 -1.0
# 	nb2AK8PuppiSoftDrop:ecfN3 -1.0
#    w subjet   0: pt 262.0 (raw pt 234.5), eta -0.93, mass   0.2
#    	btag discriminators:
# 		pfCombinedInclusiveSecondaryVertexV2BJetTags -10.0
# 		pfCombinedMVAV2BJetTags -0.853212237358
# 		pfDeepCSVJetTags:probbb -1.0
# 		pfDeepCSVJetTags:probb -1.0
#    	userFloats:
# 		NjettinessAK8Subjets:tau1 0.0
# 		NjettinessAK8Subjets:tau2 0.0
# 		NjettinessAK8Subjets:tau3 0.0
# 		NjettinessAK8Subjets:tau4 0.0
# 		nb1AK8PuppiSoftDropSubjets:ecfN2 -1.0
# 		nb1AK8PuppiSoftDropSubjets:ecfN3 -1.0
# 		nb2AK8PuppiSoftDropSubjets:ecfN2 -1.0
# 		nb2AK8PuppiSoftDropSubjets:ecfN3 -1.0
#    w subjet   1: pt 250.6 (raw pt 224.3), eta -0.93, mass   0.0
#    	btag discriminators:
# 		pfCombinedInclusiveSecondaryVertexV2BJetTags -10.0
# 		pfCombinedMVAV2BJetTags -0.853212237358
# 		pfDeepCSVJetTags:probbb -1.0
# 		pfDeepCSVJetTags:probb -1.0
#    	userFloats:
# 		NjettinessAK8Subjets:tau1 0.0
# 		NjettinessAK8Subjets:tau2 0.0
# 		NjettinessAK8Subjets:tau3 0.0
# 		NjettinessAK8Subjets:tau4 0.0
# 		nb1AK8PuppiSoftDropSubjets:ecfN2 -1.0
# 		nb1AK8PuppiSoftDropSubjets:ecfN3 -1.0
# 		nb2AK8PuppiSoftDropSubjets:ecfN2 -1.0
# 		nb2AK8PuppiSoftDropSubjets:ecfN3 -1.0
# jetAK8   1: pt 538.7 (raw pt 495.1), eta +0.27, mass  46.2 ungroomed,   1.0 softdrop,  10.1 pruned CHS.
#
# Event 1: run      1, lumi 4579, event     60232853
# PV at x,y,z = +0.011, +0.040, -1.907, ndof: 173.9, score: (pt2 of clustered objects) 54200.0
# jet CHS   0: pt 448.6 (raw pt 424.0, matched-calojet pt 389.5), eta +0.27, btag CSVIVFv2 0.097, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   1: pt 275.2 (raw pt 247.5, matched-calojet pt 219.2), eta +1.19, btag CSVIVFv2 0.202, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   2: pt 217.3 (raw pt 206.4, matched-calojet pt 192.9), eta +0.75, btag CSVIVFv2 0.126, CMVAv2 0.000, pileup mva disc +0.98
# jet CHS   3: pt  29.8 (raw pt  33.6, matched-calojet pt  27.1), eta -3.01, btag CSVIVFv2 0.536, CMVAv2 0.000, pileup mva disc -0.56
# jet PUPPI   0: pt 447.0 (raw pt 410.8, matched-calojet pt -99.0), eta +0.27, btag CSVIVFv2 0.097, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   1: pt 272.2 (raw pt 235.9, matched-calojet pt -99.0), eta +1.19, btag CSVIVFv2 0.202, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   2: pt 210.6 (raw pt 190.6, matched-calojet pt -99.0), eta +0.75, btag CSVIVFv2 0.154, CMVAv2 0.000, pileup mva disc -99.00
# jetAK8   0: pt 462.5 (raw pt 424.8), eta +0.27, mass  69.6 ungroomed,  47.3 softdrop,  48.5 pruned CHS.
# jetAK8   1: pt 281.0 (raw pt 244.0), eta +1.18, mass  47.9 ungroomed,  22.2 softdrop,  23.4 pruned CHS.
# jetAK8   2: pt 213.3 (raw pt 192.3), eta +0.75, mass  22.9 ungroomed,   5.1 softdrop,   9.2 pruned CHS.
#
# Event 2: run      1, lumi 4579, event     60232812
# PV at x,y,z = +0.010, +0.041, -5.283, ndof: 139.5, score: (pt2 of clustered objects) 112684.3
# jet CHS   0: pt 538.0 (raw pt 502.7, matched-calojet pt 465.8), eta -0.64, btag CSVIVFv2 0.181, CMVAv2 0.000, pileup mva disc +1.00
# jet CHS   1: pt 449.7 (raw pt 419.1, matched-calojet pt 411.8), eta -0.74, btag CSVIVFv2 0.093, CMVAv2 0.000, pileup mva disc +1.00
# jet CHS   2: pt  92.6 (raw pt  84.4, matched-calojet pt  73.7), eta -1.28, btag CSVIVFv2 0.158, CMVAv2 0.000, pileup mva disc +0.94
# jet CHS   3: pt  33.3 (raw pt  33.5, matched-calojet pt  16.2), eta -0.42, btag CSVIVFv2 0.160, CMVAv2 0.000, pileup mva disc +0.90
# jet PUPPI   0: pt 533.7 (raw pt 485.6, matched-calojet pt -99.0), eta -0.65, btag CSVIVFv2 0.147, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   1: pt 459.1 (raw pt 415.2, matched-calojet pt -99.0), eta -0.74, btag CSVIVFv2 0.091, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   2: pt  95.1 (raw pt  81.0, matched-calojet pt -99.0), eta -1.28, btag CSVIVFv2 0.156, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   3: pt  31.3 (raw pt  28.0, matched-calojet pt -99.0), eta -0.42, btag CSVIVFv2 0.143, CMVAv2 0.000, pileup mva disc -99.00
# jetAK8   0: pt 553.1 (raw pt 497.1), eta -0.85, mass 139.3 ungroomed, 123.9 softdrop, 122.0 pruned CHS.
# jetAK8   1: pt 544.1 (raw pt 494.4), eta -0.65, mass  58.4 ungroomed,   9.0 softdrop,  22.4 pruned CHS.
#
# Event 3: run      1, lumi 4579, event     60232757
# PV at x,y,z = +0.011, +0.042, +8.377, ndof: 262.9, score: (pt2 of clustered objects) 104766.7
# jet CHS   0: pt 397.6 (raw pt 374.0, matched-calojet pt 325.2), eta -0.29, btag CSVIVFv2 0.067, CMVAv2 0.000, pileup mva disc +1.00
# jet CHS   1: pt 365.5 (raw pt 344.8, matched-calojet pt 268.7), eta -0.04, btag CSVIVFv2 0.190, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   2: pt 194.5 (raw pt 185.7, matched-calojet pt 151.8), eta +0.17, btag CSVIVFv2 0.121, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   3: pt  31.0 (raw pt  25.3, matched-calojet pt  17.5), eta +2.21, btag CSVIVFv2 0.183, CMVAv2 0.000, pileup mva disc +0.94
# jet CHS   4: pt  24.5 (raw pt  24.0, matched-calojet pt  17.3), eta -0.39, btag CSVIVFv2 0.195, CMVAv2 0.000, pileup mva disc +0.64
# jet CHS   5: pt  23.3 (raw pt  22.7, matched-calojet pt -99999.0), eta -1.19, btag CSVIVFv2 0.111, CMVAv2 0.000, pileup mva disc +0.70
# jet CHS   6: pt  20.7 (raw pt  21.1, matched-calojet pt  22.0), eta -0.55, btag CSVIVFv2 0.161, CMVAv2 0.000, pileup mva disc +0.84
# jet PUPPI   0: pt 395.0 (raw pt 361.8, matched-calojet pt -99.0), eta -0.29, btag CSVIVFv2 0.067, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   1: pt 364.5 (raw pt 334.9, matched-calojet pt -99.0), eta -0.04, btag CSVIVFv2 0.389, CMVAv2 0.285, pileup mva disc -99.00
# jet PUPPI   2: pt 192.7 (raw pt 177.3, matched-calojet pt -99.0), eta +0.17, btag CSVIVFv2 0.121, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   3: pt  25.7 (raw pt  22.8, matched-calojet pt -99.0), eta -0.45, btag CSVIVFv2 0.201, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   4: pt  25.1 (raw pt  16.7, matched-calojet pt -99.0), eta +2.21, btag CSVIVFv2 0.190, CMVAv2 0.000, pileup mva disc -99.00
# jetAK8   0: pt 431.1 (raw pt 394.6), eta -0.31, mass  79.3 ungroomed,  16.4 softdrop,  21.4 pruned CHS.
# jetAK8   1: pt 390.8 (raw pt 358.5), eta -0.06, mass  91.6 ungroomed,  56.1 softdrop,  54.2 pruned CHS.
# jetAK8   2: pt 212.2 (raw pt 194.6), eta +0.19, mass  45.6 ungroomed,  26.9 softdrop,  38.0 pruned CHS.
#
# Event 4: run      1, lumi 4579, event     60232827
# PV at x,y,z = +0.009, +0.042, +4.438, ndof: 156.4, score: (pt2 of clustered objects) 64075.6
# jet CHS   0: pt 703.2 (raw pt 652.1, matched-calojet pt 621.5), eta -0.79, btag CSVIVFv2 0.503, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   1: pt 641.6 (raw pt 562.1, matched-calojet pt 567.2), eta -1.40, btag CSVIVFv2 0.460, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   2: pt  29.1 (raw pt  30.9, matched-calojet pt  11.4), eta -0.03, btag CSVIVFv2 0.349, CMVAv2 0.000, pileup mva disc +0.91
# jet CHS   3: pt  28.8 (raw pt  28.1, matched-calojet pt  24.6), eta -1.60, btag CSVIVFv2 0.434, CMVAv2 0.000, pileup mva disc -0.77
# jet CHS   4: pt  20.5 (raw pt  20.4, matched-calojet pt  16.2), eta +2.76, btag CSVIVFv2 0.000, CMVAv2 0.000, pileup mva disc -0.79
# jet PUPPI   0: pt 707.2 (raw pt 638.3, matched-calojet pt -99.0), eta -0.79, btag CSVIVFv2 0.339, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   1: pt 638.5 (raw pt 540.3, matched-calojet pt -99.0), eta -1.40, btag CSVIVFv2 0.535, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   2: pt  28.2 (raw pt  25.3, matched-calojet pt -99.0), eta -0.06, btag CSVIVFv2 0.161, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   3: pt  21.9 (raw pt  10.2, matched-calojet pt -99.0), eta +2.76, btag CSVIVFv2 0.544, CMVAv2 0.000, pileup mva disc -99.00
# jetAK8   0: pt 729.4 (raw pt 658.3), eta -0.79, mass 100.0 ungroomed,   3.3 softdrop,  18.5 pruned CHS.
# jetAK8   1: pt 643.8 (raw pt 549.5), eta -1.40, mass  62.8 ungroomed,   1.2 softdrop,  29.2 pruned CHS.
#
# Event 5: run      1, lumi 4579, event     60232833
# PV at x,y,z = +0.010, +0.041, +0.991, ndof: 176.0, score: (pt2 of clustered objects) 73669.1
# jet CHS   0: pt 470.7 (raw pt 415.0, matched-calojet pt 385.6), eta +1.39, btag CSVIVFv2 0.233, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   1: pt 291.5 (raw pt 266.4, matched-calojet pt 252.7), eta +2.30, btag CSVIVFv2 0.337, CMVAv2 0.000, pileup mva disc +0.98
# jet CHS   2: pt 122.9 (raw pt 117.8, matched-calojet pt  87.4), eta +0.85, btag CSVIVFv2 0.066, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   3: pt  52.8 (raw pt  45.2, matched-calojet pt  19.1), eta +1.85, btag CSVIVFv2 0.234, CMVAv2 0.000, pileup mva disc +0.97
# jet PUPPI   0: pt 442.8 (raw pt 382.8, matched-calojet pt -99.0), eta +1.39, btag CSVIVFv2 0.182, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   1: pt 290.0 (raw pt 249.0, matched-calojet pt -99.0), eta +2.30, btag CSVIVFv2 0.324, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   2: pt 120.8 (raw pt 108.9, matched-calojet pt -99.0), eta +0.85, btag CSVIVFv2 0.085, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   3: pt  52.4 (raw pt  40.7, matched-calojet pt -99.0), eta +1.87, btag CSVIVFv2 0.690, CMVAv2 0.380, pileup mva disc -99.00
# jetAK8   0: pt 464.1 (raw pt 395.0), eta +1.41, mass  78.5 ungroomed,  26.3 softdrop,  32.3 pruned CHS.
# jetAK8   1: pt 298.8 (raw pt 253.7), eta +2.30, mass  55.1 ungroomed,  42.7 softdrop,  43.8 pruned CHS.
# jetAK8   2: pt 127.0 (raw pt 113.7), eta +0.86, mass  22.2 ungroomed, -99999.0 softdrop,   7.8 pruned CHS.
#
# Event 6: run      1, lumi 4579, event     60232764
# PV at x,y,z = +0.010, +0.042, -1.241, ndof: 140.3, score: (pt2 of clustered objects) 58171.5
# jet CHS   0: pt 467.2 (raw pt 434.2, matched-calojet pt 383.8), eta -1.78, btag CSVIVFv2 0.243, CMVAv2 0.000, pileup mva disc +0.97
# jet CHS   1: pt 331.7 (raw pt 311.6, matched-calojet pt 292.0), eta -0.34, btag CSVIVFv2 0.262, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   2: pt 190.7 (raw pt 180.2, matched-calojet pt 157.8), eta -0.41, btag CSVIVFv2 0.072, CMVAv2 0.000, pileup mva disc +1.00
# jet CHS   3: pt  70.9 (raw pt  65.3, matched-calojet pt  41.2), eta -1.71, btag CSVIVFv2 0.573, CMVAv2 0.000, pileup mva disc +0.98
# jet CHS   4: pt  69.7 (raw pt  66.2, matched-calojet pt  39.4), eta -1.02, btag CSVIVFv2 0.123, CMVAv2 0.000, pileup mva disc +0.98
# jet CHS   5: pt  30.9 (raw pt  29.2, matched-calojet pt  23.2), eta -0.85, btag CSVIVFv2 0.160, CMVAv2 0.000, pileup mva disc +0.57
# jet PUPPI   0: pt 411.9 (raw pt 356.5, matched-calojet pt -99.0), eta -1.78, btag CSVIVFv2 0.144, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   1: pt 335.7 (raw pt 307.4, matched-calojet pt -99.0), eta -0.34, btag CSVIVFv2 0.262, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   2: pt 192.7 (raw pt 175.9, matched-calojet pt -99.0), eta -0.40, btag CSVIVFv2 0.073, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   3: pt  76.6 (raw pt  62.9, matched-calojet pt -99.0), eta -1.70, btag CSVIVFv2 0.307, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   4: pt  63.4 (raw pt  56.3, matched-calojet pt -99.0), eta -1.01, btag CSVIVFv2 0.115, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   5: pt  31.8 (raw pt  28.0, matched-calojet pt -99.0), eta -0.83, btag CSVIVFv2 0.103, CMVAv2 0.000, pileup mva disc -99.00
# jetAK8   0: pt 539.2 (raw pt 493.1), eta -0.41, mass 194.5 ungroomed, 177.8 softdrop, 179.1 pruned CHS.
# jetAK8   1: pt 436.5 (raw pt 376.7), eta -1.80, mass  90.3 ungroomed,  58.9 softdrop,  68.3 pruned CHS.
# jetAK8   2: pt  84.6 (raw pt  67.4), eta -1.78, mass  21.0 ungroomed, -99999.0 softdrop, -99999.0 pruned CHS.
#
# Event 7: run      1, lumi 4579, event     60232846
# PV at x,y,z = +0.011, +0.043, +4.401, ndof: 188.0, score: (pt2 of clustered objects) 70707.2
# jet CHS   0: pt 613.9 (raw pt 559.1, matched-calojet pt 558.3), eta -1.12, btag CSVIVFv2 0.663, CMVAv2 0.000, pileup mva disc +0.95
# jet CHS   1: pt 503.1 (raw pt 446.7, matched-calojet pt 408.0), eta -1.23, btag CSVIVFv2 0.134, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   2: pt  30.1 (raw pt  32.7, matched-calojet pt  26.1), eta +0.49, btag CSVIVFv2 0.288, CMVAv2 0.000, pileup mva disc +0.96
# jet CHS   3: pt  26.5 (raw pt  25.2, matched-calojet pt  20.4), eta -1.72, btag CSVIVFv2 0.416, CMVAv2 0.000, pileup mva disc -0.24
# jet CHS   4: pt  23.2 (raw pt  24.6, matched-calojet pt  21.9), eta -0.92, btag CSVIVFv2 0.204, CMVAv2 0.000, pileup mva disc +0.01
# jet CHS   5: pt  22.0 (raw pt  19.6, matched-calojet pt  17.6), eta -1.88, btag CSVIVFv2 0.147, CMVAv2 0.000, pileup mva disc +0.80
# jet CHS   6: pt  21.2 (raw pt  19.7, matched-calojet pt  15.8), eta -2.54, btag CSVIVFv2 0.279, CMVAv2 0.000, pileup mva disc +0.55
# jet PUPPI   0: pt 618.5 (raw pt 550.9, matched-calojet pt -99.0), eta -1.12, btag CSVIVFv2 0.804, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   1: pt 500.9 (raw pt 433.2, matched-calojet pt -99.0), eta -1.23, btag CSVIVFv2 0.139, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   2: pt  28.7 (raw pt  25.6, matched-calojet pt -99.0), eta +0.49, btag CSVIVFv2 0.291, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   3: pt  20.2 (raw pt  15.0, matched-calojet pt -99.0), eta -1.84, btag CSVIVFv2 0.150, CMVAv2 0.000, pileup mva disc -99.00
# jetAK8   0: pt 642.3 (raw pt 571.9), eta -1.11, mass  79.3 ungroomed,   6.5 softdrop,  20.6 pruned CHS.
# jetAK8   1: pt 525.6 (raw pt 456.6), eta -1.26, mass  99.6 ungroomed,  23.5 softdrop,  28.2 pruned CHS.
#
# Event 8: run      1, lumi 4579, event     60232862
# PV at x,y,z = +0.010, +0.042, +1.900, ndof: 244.0, score: (pt2 of clustered objects) 60118.5
# jet CHS   0: pt 447.0 (raw pt 421.9, matched-calojet pt 389.3), eta -0.35, btag CSVIVFv2 0.323, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   1: pt 305.4 (raw pt 290.3, matched-calojet pt 257.7), eta -0.27, btag CSVIVFv2 0.349, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   2: pt 154.6 (raw pt 148.9, matched-calojet pt 122.0), eta -0.74, btag CSVIVFv2 0.774, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   3: pt  45.0 (raw pt  45.6, matched-calojet pt  29.0), eta -0.77, btag CSVIVFv2 0.188, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   4: pt  27.8 (raw pt  30.0, matched-calojet pt  26.3), eta +0.21, btag CSVIVFv2 0.152, CMVAv2 0.000, pileup mva disc +0.96
# jet PUPPI   0: pt 450.4 (raw pt 411.7, matched-calojet pt -99.0), eta -0.35, btag CSVIVFv2 0.315, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   1: pt 310.9 (raw pt 284.9, matched-calojet pt -99.0), eta -0.27, btag CSVIVFv2 0.274, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   2: pt 153.5 (raw pt 138.7, matched-calojet pt -99.0), eta -0.73, btag CSVIVFv2 0.739, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   3: pt  48.0 (raw pt  43.1, matched-calojet pt -99.0), eta -0.77, btag CSVIVFv2 0.188, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   4: pt  29.3 (raw pt  26.4, matched-calojet pt -99.0), eta +0.21, btag CSVIVFv2 0.152, CMVAv2 0.000, pileup mva disc -99.00
# jetAK8   0: pt 458.7 (raw pt 419.0), eta -0.36, mass  50.2 ungroomed,  23.8 softdrop,  27.0 pruned CHS.
# jetAK8   1: pt 388.4 (raw pt 355.4), eta -0.31, mass 115.1 ungroomed, 102.2 softdrop,  84.1 pruned CHS.
# jetAK8   2: pt 169.8 (raw pt 152.7), eta -0.70, mass  38.9 ungroomed, -99999.0 softdrop,  17.5 pruned CHS.
#
# Event 9: run      1, lumi 4579, event     60232761
# PV at x,y,z = +0.010, +0.041, +3.609, ndof: 131.8, score: (pt2 of clustered objects) 82225.1
# jet CHS   0: pt 492.2 (raw pt 463.9, matched-calojet pt 433.8), eta +0.05, btag CSVIVFv2 0.126, CMVAv2 0.000, pileup mva disc +1.00
# jet CHS   1: pt 478.4 (raw pt 422.0, matched-calojet pt 361.4), eta +1.45, btag CSVIVFv2 0.207, CMVAv2 0.000, pileup mva disc +1.00
# jet CHS   2: pt  94.7 (raw pt  83.1, matched-calojet pt  65.5), eta +1.89, btag CSVIVFv2 0.088, CMVAv2 0.000, pileup mva disc +0.99
# jet CHS   3: pt  35.2 (raw pt  35.1, matched-calojet pt  25.6), eta -0.02, btag CSVIVFv2 0.146, CMVAv2 0.000, pileup mva disc +0.98
# jet PUPPI   0: pt 499.4 (raw pt 460.5, matched-calojet pt -99.0), eta +0.05, btag CSVIVFv2 0.121, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   1: pt 476.2 (raw pt 403.3, matched-calojet pt -99.0), eta +1.44, btag CSVIVFv2 0.144, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   2: pt  98.9 (raw pt  80.2, matched-calojet pt -99.0), eta +1.89, btag CSVIVFv2 0.093, CMVAv2 0.000, pileup mva disc -99.00
# jet PUPPI   3: pt  35.4 (raw pt  31.9, matched-calojet pt -99.0), eta -0.02, btag CSVIVFv2 0.134, CMVAv2 0.000, pileup mva disc -99.00
# jetAK8   0: pt 548.9 (raw pt 482.0), eta +1.55, mass 160.3 ungroomed, 140.8 softdrop, 138.1 pruned CHS.
# jetAK8   1: pt 531.5 (raw pt 489.4), eta +0.05, mass  89.4 ungroomed,   3.5 softdrop,  15.4 pruned CHS.

# %% [markdown]
# ### nanoAOD
#
# In nanoAOD only AK4 CHS jets ( _Jet_ ) and AK8 PUPPI jets ( _FatJet_ ) are stored. Currently a set of algoritms, similar than in miniAOD, can be found in this format. A full set of variables for each jet collection can be found in this [website](https://cms-nanoaod-integration.web.cern.ch/integration/master-102X/mc102X_doc.html).
#
# NanoAOD is a "flat tree" format, meaning that you can access the information directly with simple root, or even simple python tools (like numpy or pandas). This format is becoming more and more popular within CMS due to its simplicity and accesibility. An extremely simple example can be found in `$CMSSW_BASE/src/Analysis/JMEDAS/scripts/jmedas_nanoAODtest.py`, to run it in the terminal as simple python file, or run the cell below.
#
# However, other more advance tools exist in the market which allows you to do more sophisticated analysis using nanoAOD format, like [RDataFrames](https://root.cern/doc/master/classROOT_1_1RDataFrame.html), [NanoAOD-tools](https://github.com/cms-nanoAOD/nanoAOD-tools), or [Coffea](https://github.com/CoffeaTeam/coffea). We excourage you to look at them and use the one you like the most.

# %%
from ROOT import *

inputFile = TFile.Open('root://xrootd-cms.infn.it//store/mc/RunIIAutumn18NanoAODv4/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/NANOAODSIM/Nano14Dec2018_102X_upgrade2018_realistic_v16-v1/110000/C23F77AA-3909-C74E-ADCD-8266FF68AB5D.root' )
events = inputFile.Get('Events')

for iev in xrange(events.GetEntries()):
    events.GetEntry(iev)
    if iev >= 10: break

    print "\nEvent %d: run %6d, lumi %4d, event %12d" % (iev, events.run, events.luminosityBlock, events.event )

    # AK4 CHS Jets
    for ijet in range(events.nJet):
        if events.Jet_pt < 20: continue
        print 'AK4 jet '+ str(ijet) + ': pt ' + str(events.Jet_pt[ijet]) + ', eta ' + str(events.Jet_eta[ijet]) + ', mass ' + str(events.Jet_mass[ijet]) + ',phi ' + str(events.Jet_phi[ijet]) + ', puId ' + str(events.Jet_puId[ijet]) + ', deepJet btag disc. ' + str(events.Jet_btagDeepB[ijet])

    # AK8 PUPPI Jets
    for ijet in range(events.nFatJet):
        if events.FatJet_pt < 20: continue
        print 'AK8 jet '+ str(ijet) + ': pt ' + str(events.FatJet_pt[ijet]) + ', eta ' + str(events.FatJet_eta[ijet]) + ', mass ' + str(events.FatJet_mass[ijet]) + ',phi ' + str(events.FatJet_phi[ijet]) + ', deepAK8 W tag disc. ' + str(events.FatJet_deepTag_WvsQCD[ijet])+ ', deepAK8 top tag disc. ' + str(events.FatJet_deepTag_TvsQCD[ijet])
# Out:
# Event 0: run      1, lumi    9, event       105380
# AK4 jet 0: pt 300.5, eta 2.32568359375, mass 32.46875,phi -1.01171875, puId 7, deepJet btag disc. 0.050048828125
# AK4 jet 1: pt 234.375, eta -0.723022460938, mass 47.3125,phi 1.990234375, puId 7, deepJet btag disc. 0.0530395507812
# AK4 jet 2: pt 192.75, eta 2.0302734375, mass 22.4375,phi -2.63330078125, puId 7, deepJet btag disc. 0.0307006835938
# AK4 jet 3: pt 127.0, eta -0.0839080810547, mass 17.109375,phi 0.996337890625, puId 7, deepJet btag disc. 0.155639648438
# AK4 jet 4: pt 62.0625, eta -0.604125976562, mass 11.7890625,phi 1.42114257812, puId 7, deepJet btag disc. 0.0173187255859
# AK4 jet 5: pt 46.6875, eta -1.1865234375, mass 8.078125,phi 1.64331054688, puId 7, deepJet btag disc. 0.022216796875
# AK4 jet 6: pt 27.40625, eta 3.90966796875, mass 7.09765625,phi -2.61279296875, puId 0, deepJet btag disc. -2.0
# AK4 jet 7: pt 27.375, eta 2.64013671875, mass 3.8828125,phi -0.50927734375, puId 7, deepJet btag disc. 0.155029296875
# AK4 jet 8: pt 17.09375, eta 4.45703125, mass 4.29296875,phi -2.185546875, puId 0, deepJet btag disc. -2.0
# AK8 jet 0: pt 334.25, eta -0.79150390625, mass 122.0,phi 1.84497070312, deepAK8 W tag disc. 0.69970703125, deepAK8 top tag disc. 0.0422668457031
# AK8 jet 1: pt 334.25, eta 2.34814453125, mass 57.46875,phi -0.989868164062, deepAK8 W tag disc. 0.0189819335938, deepAK8 top tag disc. 0.000248193740845
# AK8 jet 2: pt 213.25, eta 2.03125, mass 32.71875,phi -2.65966796875, deepAK8 W tag disc. 0.00779342651367, deepAK8 top tag disc. 1.8298625946e-05
#
# Event 1: run      1, lumi    9, event       105293
# AK4 jet 0: pt 499.5, eta -0.224273681641, mass 25.96875,phi 2.79931640625, puId 7, deepJet btag disc. 0.85595703125
# AK4 jet 1: pt 347.75, eta 0.253112792969, mass 60.46875,phi 0.142761230469, puId 7, deepJet btag disc. 0.0675659179688
# AK4 jet 2: pt 221.375, eta 0.225219726562, mass 29.65625,phi -0.85107421875, puId 7, deepJet btag disc. 0.037841796875
# AK4 jet 3: pt 53.59375, eta 0.860473632812, mass 9.9609375,phi -2.396484375, puId 7, deepJet btag disc. 0.87744140625
# AK4 jet 4: pt 25.671875, eta 0.524169921875, mass 5.5703125,phi -1.705078125, puId 0, deepJet btag disc. -2.0
# AK4 jet 5: pt 19.28125, eta 2.46044921875, mass 5.06640625,phi 3.00048828125, puId 6, deepJet btag disc. 0.0776977539062
# AK4 jet 6: pt 18.609375, eta -0.645629882812, mass 4.6484375,phi 1.17163085938, puId 4, deepJet btag disc. 0.10888671875
# AK8 jet 0: pt 506.25, eta -0.2275390625, mass 31.046875,phi 2.802734375, deepAK8 W tag disc. 0.00114822387695, deepAK8 top tag disc. 6.66454434395e-06
# AK8 jet 1: pt 358.75, eta 0.252868652344, mass 74.1875,phi 0.145111083984, deepAK8 W tag disc. 0.353759765625, deepAK8 top tag disc. 0.0016450881958
# AK8 jet 2: pt 225.5, eta 0.252258300781, mass 41.03125,phi -0.855712890625, deepAK8 W tag disc. 0.00622177124023, deepAK8 top tag disc. 3.24249267578e-05
#
# Event 2: run      1, lumi    9, event       105279
# AK4 jet 0: pt 509.75, eta -1.78759765625, mass 35.3125,phi 2.06787109375, puId 7, deepJet btag disc. 0.0372924804688
# AK4 jet 1: pt 454.5, eta -0.914184570312, mass 33.28125,phi -1.47119140625, puId 7, deepJet btag disc. 0.063720703125
# AK4 jet 2: pt 216.25, eta -1.658203125, mass 27.640625,phi -0.60400390625, puId 7, deepJet btag disc. 0.0287780761719
# AK4 jet 3: pt 55.71875, eta -3.5712890625, mass 10.6171875,phi 2.12939453125, puId 7, deepJet btag disc. -2.0
# AK4 jet 4: pt 28.203125, eta -1.09033203125, mass 5.734375,phi 0.944702148438, puId 7, deepJet btag disc. 0.0333251953125
# AK4 jet 5: pt 27.0625, eta -2.505859375, mass 6.22265625,phi 1.18627929688, puId 7, deepJet btag disc. 0.0599670410156
# AK4 jet 6: pt 25.078125, eta 3.60498046875, mass 5.3515625,phi 0.173034667969, puId 7, deepJet btag disc. -2.0
# AK4 jet 7: pt 15.234375, eta -1.87084960938, mass 3.759765625,phi 1.13330078125, puId 6, deepJet btag disc. 0.065185546875
# AK8 jet 0: pt 509.25, eta -1.791015625, mass 70.0625,phi 2.06396484375, deepAK8 W tag disc. 0.00818634033203, deepAK8 top tag disc. 8.75443220139e-06
# AK8 jet 1: pt 457.75, eta -0.916381835938, mass 45.5,phi -1.46875, deepAK8 W tag disc. 0.0024356842041, deepAK8 top tag disc. 1.34110450745e-06
# AK8 jet 2: pt 203.625, eta -1.65234375, mass 37.375,phi -0.588989257812, deepAK8 W tag disc. 0.00477600097656, deepAK8 top tag disc. 1.15409493446e-05
#
# Event 3: run      1, lumi    9, event       105309
# AK4 jet 0: pt 380.0, eta 0.147033691406, mass 34.40625,phi -1.85717773438, puId 7, deepJet btag disc. 0.0156555175781
# AK4 jet 1: pt 309.75, eta 1.74877929688, mass 20.953125,phi 2.5400390625, puId 7, deepJet btag disc. 0.0229949951172
# AK4 jet 2: pt 269.5, eta -0.221343994141, mass 36.15625,phi 0.294067382812, puId 7, deepJet btag disc. 0.0539855957031
# AK4 jet 3: pt 95.5625, eta -0.443176269531, mass 11.890625,phi 0.807250976562, puId 7, deepJet btag disc. 0.0231475830078
# AK4 jet 4: pt 37.3125, eta -0.0567779541016, mass 7.9609375,phi -1.14379882812, puId 7, deepJet btag disc. 0.0211181640625
# AK4 jet 5: pt 17.171875, eta -2.80126953125, mass 3.23828125,phi 0.236450195312, puId 4, deepJet btag disc. -2.0
# AK4 jet 6: pt 15.0859375, eta 3.89404296875, mass 3.564453125,phi -0.611328125, puId 4, deepJet btag disc. -2.0
# AK8 jet 0: pt 411.5, eta 0.138458251953, mass 83.375,phi -1.81103515625, deepAK8 W tag disc. 0.73828125, deepAK8 top tag disc. 0.000930786132812
# AK8 jet 1: pt 354.0, eta -0.283264160156, mass 98.1875,phi 0.421752929688, deepAK8 W tag disc. 0.8466796875, deepAK8 top tag disc. 0.00421524047852
# AK8 jet 2: pt 327.75, eta 1.76123046875, mass 34.375,phi 2.53955078125, deepAK8 W tag disc. 0.0125045776367, deepAK8 top tag disc. 7.9870223999e-06
#
# Event 4: run      1, lumi    9, event       105494
# AK4 jet 0: pt 485.25, eta 0.490234375, mass 48.28125,phi 2.8369140625, puId 7, deepJet btag disc. 0.0340270996094
# AK4 jet 1: pt 338.0, eta -0.31884765625, mass 47.875,phi -0.263977050781, puId 7, deepJet btag disc. 0.24755859375
# AK4 jet 2: pt 161.25, eta -1.0576171875, mass 15.90625,phi -0.338562011719, puId 7, deepJet btag disc. 0.179565429688
# AK4 jet 3: pt 23.4375, eta -0.4541015625, mass 5.33984375,phi -0.734375, puId 7, deepJet btag disc. 0.2666015625
# AK4 jet 4: pt 19.5, eta -3.158203125, mass 4.2109375,phi 0.407043457031, puId 7, deepJet btag disc. -2.0
# AK4 jet 5: pt 17.84375, eta -2.74560546875, mass 5.1953125,phi 1.13134765625, puId 0, deepJet btag disc. -2.0
# AK8 jet 0: pt 523.5, eta -0.589111328125, mass 201.75,phi -0.306579589844, deepAK8 W tag disc. 0.26806640625, deepAK8 top tag disc. 0.199096679688
# AK8 jet 1: pt 500.75, eta 0.488525390625, mass 61.40625,phi 2.84033203125, deepAK8 W tag disc. 0.0107421875, deepAK8 top tag disc. 6.62729144096e-06
#
# Event 5: run      1, lumi    9, event       105303
# AK4 jet 0: pt 497.0, eta 0.578247070312, mass 56.78125,phi 2.99609375, puId 7, deepJet btag disc. 0.0303039550781
# AK4 jet 1: pt 204.75, eta -1.99438476562, mass 16.453125,phi 0.106674194336, puId 7, deepJet btag disc. 0.0558776855469
# AK4 jet 2: pt 190.875, eta 0.105819702148, mass 18.984375,phi -0.929565429688, puId 7, deepJet btag disc. 0.38818359375
# AK4 jet 3: pt 174.25, eta 0.478393554688, mass 22.890625,phi 0.327758789062, puId 7, deepJet btag disc. 0.0382080078125
# AK4 jet 4: pt 18.6875, eta -0.5302734375, mass 5.41015625,phi -1.271484375, puId 6, deepJet btag disc. 0.0810546875
# AK4 jet 5: pt 16.5, eta -0.892822265625, mass 3.474609375,phi 1.8505859375, puId 4, deepJet btag disc. -2.0
# AK4 jet 6: pt 15.96875, eta -2.775390625, mass 4.3046875,phi 1.94409179688, puId 0, deepJet btag disc. -2.0
# AK8 jet 0: pt 492.25, eta 0.580078125, mass 62.5625,phi 2.9892578125, deepAK8 W tag disc. 0.0576782226562, deepAK8 top tag disc. 4.92632389069e-05
# AK8 jet 1: pt 215.75, eta -1.99267578125, mass 36.65625,phi 0.0970458984375, deepAK8 W tag disc. 0.0126800537109, deepAK8 top tag disc. 0.000128865242004
# AK8 jet 2: pt 203.5, eta 0.0751647949219, mass 37.46875,phi -0.94384765625, deepAK8 W tag disc. 0.00691986083984, deepAK8 top tag disc. 8.41617584229e-05
# AK8 jet 3: pt 184.375, eta 0.467407226562, mass 29.296875,phi 0.325988769531, deepAK8 W tag disc. 0.0337829589844, deepAK8 top tag disc. 8.11815261841e-05
#
# Event 6: run      1, lumi    9, event       105432
# AK4 jet 0: pt 415.0, eta 0.223388671875, mass 34.5,phi -2.91943359375, puId 7, deepJet btag disc. 0.0482482910156
# AK4 jet 1: pt 332.25, eta -0.270874023438, mass 41.25,phi 0.0868377685547, puId 7, deepJet btag disc. 0.0258483886719
# AK4 jet 2: pt 113.875, eta 1.98486328125, mass 13.71875,phi 0.317749023438, puId 7, deepJet btag disc. 0.0277709960938
# AK4 jet 3: pt 66.3125, eta 0.410888671875, mass 12.84375,phi 2.84033203125, puId 7, deepJet btag disc. 0.0770263671875
# AK4 jet 4: pt 38.15625, eta 4.2724609375, mass 6.9609375,phi 2.23583984375, puId 7, deepJet btag disc. -2.0
# AK4 jet 5: pt 32.0, eta 1.1552734375, mass 6.08984375,phi -0.797729492188, puId 7, deepJet btag disc. 0.0274353027344
# AK4 jet 6: pt 25.015625, eta 0.994384765625, mass 4.99609375,phi 0.447509765625, puId 0, deepJet btag disc. -2.0
# AK4 jet 7: pt 17.8125, eta 4.8974609375, mass 4.6875,phi 0.9189453125, puId 0, deepJet btag disc. -2.0
# AK4 jet 8: pt 17.171875, eta -2.48876953125, mass 4.39453125,phi -2.10205078125, puId 4, deepJet btag disc. 0.3984375
# AK4 jet 9: pt 15.7109375, eta 2.62939453125, mass 3.826171875,phi -0.720825195312, puId 7, deepJet btag disc. 0.128540039062
# AK8 jet 0: pt 481.5, eta 0.252990722656, mass 102.9375,phi -2.98828125, deepAK8 W tag disc. 0.255126953125, deepAK8 top tag disc. 9.97185707092e-05
# AK8 jet 1: pt 324.75, eta -0.248077392578, mass 45.09375,phi 0.0811767578125, deepAK8 W tag disc. 0.00363731384277, deepAK8 top tag disc. 1.86413526535e-05
#
# Event 7: run      1, lumi    9, event       105294
# AK4 jet 0: pt 468.25, eta 0.0447463989258, mass 33.4375,phi 0.462036132812, puId 7, deepJet btag disc. 0.0268096923828
# AK4 jet 1: pt 286.0, eta -0.409423828125, mass 45.0625,phi -2.90185546875, puId 7, deepJet btag disc. 0.09423828125
# AK4 jet 2: pt 176.125, eta -0.671997070312, mass 11.7421875,phi -2.3203125, puId 7, deepJet btag disc. 0.055419921875
# AK4 jet 3: pt 19.265625, eta -0.787841796875, mass 5.20703125,phi 2.71533203125, puId 7, deepJet btag disc. 0.0194549560547
# AK4 jet 4: pt 16.890625, eta -0.409118652344, mass 3.9609375,phi -0.586181640625, puId 4, deepJet btag disc. -2.0
# AK8 jet 0: pt 483.75, eta 0.0358276367188, mass 49.4375,phi 0.464111328125, deepAK8 W tag disc. 0.0103073120117, deepAK8 top tag disc. 4.65661287308e-06
# AK8 jet 1: pt 435.75, eta -0.551879882812, mass 154.875,phi -2.67724609375, deepAK8 W tag disc. 0.3974609375, deepAK8 top tag disc. 0.39599609375
#
# Event 8: run      1, lumi    9, event       105376
# AK4 jet 0: pt 441.0, eta -1.99633789062, mass 29.421875,phi -1.33325195312, puId 7, deepJet btag disc. 0.0811767578125
# AK4 jet 1: pt 351.75, eta 2.60498046875, mass 17.078125,phi 2.14208984375, puId 7, deepJet btag disc. 0.378662109375
# AK4 jet 2: pt 153.625, eta -1.05297851562, mass 21.9375,phi 1.61352539062, puId 7, deepJet btag disc. 0.0298461914062
# AK4 jet 3: pt 43.875, eta -1.06689453125, mass 9.0625,phi -0.236358642578, puId 7, deepJet btag disc. 0.0206909179688
# AK4 jet 4: pt 20.53125, eta 2.74072265625, mass 5.36328125,phi -0.574096679688, puId 0, deepJet btag disc. -2.0
# AK4 jet 5: pt 18.96875, eta 4.16015625, mass 4.40625,phi -2.25927734375, puId 6, deepJet btag disc. -2.0
# AK4 jet 6: pt 17.390625, eta 2.22509765625, mass 2.712890625,phi -2.52392578125, puId 4, deepJet btag disc. -2.0
# AK8 jet 0: pt 450.0, eta -1.99462890625, mass 36.34375,phi -1.328125, deepAK8 W tag disc. 0.00277519226074, deepAK8 top tag disc. 8.32602381706e-07
# AK8 jet 1: pt 369.25, eta 2.6005859375, mass 31.09375,phi 2.15234375, deepAK8 W tag disc. 0.081298828125, deepAK8 top tag disc. 0.00322532653809
#
# Event 9: run      1, lumi    9, event       105371
# AK4 jet 0: pt 536.5, eta 0.697021484375, mass 64.625,phi -0.568603515625, puId 7, deepJet btag disc. 0.0916137695312
# AK4 jet 1: pt 355.0, eta -1.75146484375, mass 36.21875,phi 1.37231445312, puId 7, deepJet btag disc. 0.070068359375
# AK4 jet 2: pt 248.875, eta 0.9189453125, mass 26.640625,phi -3.00634765625, puId 7, deepJet btag disc. 0.0924682617188
# AK4 jet 3: pt 245.5, eta 0.50390625, mass 25.515625,phi -3.1142578125, puId 7, deepJet btag disc. 0.0686645507812
# AK4 jet 4: pt 69.5625, eta 3.68310546875, mass 12.21875,phi -2.97509765625, puId 7, deepJet btag disc. -2.0
# AK4 jet 5: pt 59.3125, eta -0.962646484375, mass 12.3828125,phi 0.0449600219727, puId 4, deepJet btag disc. 0.0701293945312
# AK4 jet 6: pt 26.8125, eta -0.0321807861328, mass 5.34765625,phi -1.67700195312, puId 7, deepJet btag disc. 0.0220489501953
# AK4 jet 7: pt 19.65625, eta -3.9296875, mass 5.12890625,phi 1.89086914062, puId 0, deepJet btag disc. -2.0
# AK4 jet 8: pt 18.9375, eta 1.6142578125, mass 4.62890625,phi 0.50439453125, puId 4, deepJet btag disc. 0.156494140625
# AK8 jet 0: pt 535.0, eta 0.703979492188, mass 76.5,phi -0.569458007812, deepAK8 W tag disc. 0.00782775878906, deepAK8 top tag disc. 9.00030136108e-06
# AK8 jet 1: pt 483.75, eta 0.738159179688, mass 115.3125,phi -3.0556640625, deepAK8 W tag disc. 0.51318359375, deepAK8 top tag disc. 0.00344848632812
# AK8 jet 2: pt 373.75, eta -1.76318359375, mass 45.875,phi 1.37280273438, deepAK8 W tag disc. 0.0250244140625, deepAK8 top tag disc. 1.56462192535e-05
# /cvmfs/cms.cern.ch/slc7_amd64_gcc820/lcg/root/6.14.09-pafccj/lib/ROOT.py:577: UserWarning: "from ROOT import *" is not supported under IPython
#   warnings.warn( '"from ROOT import *" is not supported under IPython' )

# %% [markdown]
# ### jetToolbox
#
# Although JME generally recommends to use AK4 CHS and AK8 PUPPI jets for Run II analyses (moving fully to AK4 PUPPI jets for Run III), there are cases where certain analysis will need to use something else. Similar for the standard algorithms stored in mini/nanoAOD samples. For users who want to test a different jet collection or algorithms, JetMET had developed a user-friendly tool to compute them: [JetToolbox](https://twiki.cern.ch/twiki/bin/view/CMS/JetToolbox).
#
# The JetToolbox is *not* part of CMSSW because JME wants to have the freedom to incorporate and test as many tools as possible without these algorithms being part on any central sample. That is the reason that, in real life, you would need to clone the [JetToolbox repository](https://github.com/cms-jet/JetToolbox) inside your CMSSW src folder as:
# ~~~
# cd $CMSSW_BASE/src/
# git clone git@github.com:cms-jet/JetToolbox.git JMEAnalysis/JetToolbox -b jetToolbox_102X_v3
# scram b
# ~~~
#
# In this tutorial, this step was done for you in the initial setup. _You do not need to do it now_. You can find more information about how to set up the JetToolbox in the [README.md](https://github.com/cms-jet/JetToolbox) of the github repository or in the [twiki](https://twiki.cern.ch/twiki/bin/view/CMS/JetToolbox).

# %% [markdown]
# For instance, imagine that you want to create a new jet collection using the Cambridge-Aachen clustering algorithm with cone-size 1.2, using PUPPI as pileup removal algorithm, some selection, including the prunning and softdrop grooming algorithms, and use different parameters for the softdrop algoritm. Then in your python config file you need to include something like this:
#
# ```
# from Analysis.JetToolbox.jetToolbox_cff import *                 # Load the jetTOolbox
#
# jetToolbox( process, 'ca10', 'jetSequence', 'out',               # cone size and basic setup
#   Cut="pt>170 && abs(eta)<2.5",                                  # selection
#   dataTier="miniAOD",                                            # input file: miniAOD or nanoAOD?
#   PUMethod='PUPPI',                                              # PUPPI/CHS/SK/PF
#   addPruning=True, addSoftDrop=True , betaCut = 1.0,             # add basic grooming
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']   # for jet corrections
# )
# ```
#
# A full list of algorithms and parameters can be found in the [JetToolbox twiki](https://twiki.cern.ch/twiki/bin/viewauth/CMS/JetToolbox#Arguments). A more complete example can be found in `$CMSSW_BASE/src/Analysis/JMEDAS/scripts/ClusterWithToolboxAndMakeHistos.py`, or by clicking in the link below.

# %% [markdown]
# <details>
#     <summary><font color='blue'>SHOW CODE</font></summary>
# <p>
#
# ```python
# import FWCore.ParameterSet.Config as cms
# ###
# ### cmsRun ClusterWithToolboxAndPlot.py
# ###  make jet plots from miniAOD with some additional jet collections clustered
# ### Jet Algorithm HATS 2015 - Dolen, Rappoccio, Stupak
# ### Updated for Jet Algorithm HATS 2016 - Dolen, Pilot, Kries, Perloff, Tran
# ###
#
#
# process = cms.Process("Ana")
#
# ### SETUP
# process.load("FWCore.MessageService.MessageLogger_cfi")
# process.load("Configuration.EventContent.EventContent_cff")
# process.load('Configuration.Geometry.GeometryRecoDB_cff')
# process.load('Configuration.StandardSequences.MagneticField_38T_cff')
# process.load('Configuration.StandardSequences.Services_cff')
# process.load('Configuration.StandardSequences.FrontierConditions_GlobalTag_condDBv2_cff')
# process.GlobalTag.globaltag = '92X_upgrade2017_realistic_v1'
# process.GlobalTag.globaltag = '94X_mc2017_realistic_v12'
# process.options = cms.untracked.PSet( wantSummary = cms.untracked.bool(True) )
# process.options.allowUnscheduled = cms.untracked.bool(True)
# process.MessageLogger.cerr.FwkReport.reportEvery = 1000
#
# ### INPUT
# process.maxEvents = cms.untracked.PSet( input = cms.untracked.int32(100) )
#
# process.source = cms.Source("PoolSource",
#     fileNames = cms.untracked.vstring('/store/mc/RunIIAutumn18MiniAOD/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15_ext1-v2/20000/7E65457A-87E5-C146-8321-9A48B4F56ED1.root'),
# )
#
# #from PhysicsTools.PatAlgos.patInputFiles_cff import filesRelValTTbarPileUpMINIAODSIM
# #process.source.fileNames = filesRelValTTbarPileUpMINIAODSIM
#
# btagDiscAK4 = [
#             'pfCombinedInclusiveSecondaryVertexV2BJetTags',
#             'pfCombinedCvsLJetTags',
#             'pfCombinedCvsBJetTags',
#             'pfDeepCSVJetTags:probb',
#             'pfDeepCSVJetTags:probbb',
#             'pfDeepCSVJetTags:probc',
#             'pfDeepCSVJetTags:probudsg',
#             'pfDeepFlavourJetTags:probb',
#             'pfDeepFlavourJetTags:probbb',
#             'pfDeepFlavourJetTags:problepb',
#             'pfDeepFlavourJetTags:probc',
#             'pfDeepFlavourJetTags:probuds',
#             'pfDeepFlavourJetTags:probg',
#         ]
#
# btagDiscAK8 = [
#             'pfBoostedDoubleSecondaryVertexAK8BJetTags',
#             #'pfMassIndependentDeepDoubleBvLJetTags:probQCD',
#             #'pfMassIndependentDeepDoubleBvLJetTags:probHbb',
#             #'pfMassIndependentDeepDoubleCvLJetTags:probQCD',
#             #'pfMassIndependentDeepDoubleCvLJetTags:probHcc',
#             #'pfMassIndependentDeepDoubleCvBJetTags:probHbb',
#             #'pfMassIndependentDeepDoubleCvBJetTags:probHcc',
# 	    "pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:bbvsLight",
# 	    "pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ccvsLight",
# 	    "pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:TvsQCD",
# 	    "pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZHccvsQCD",
#  	    "pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:WvsQCD",
#  	    "pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZHbbvsQCD"
#             ]
#
# ### ADD SOME NEW JET COLLECTIONS
# from Analysis.JetToolbox.jetToolbox_cff import *
#
# # updating slimmedJets (ak4 CHS jets) from miniAOD
# jetToolbox( process, 'ak4', 'ak4UpdJetSubs', 'noOutput',
#         dataTier="miniAOD",
#         updateCollection='slimmedJets',
#         JETCorrPayload='AK4PFchs',
#         postFix='Updated',
#         bTagDiscriminators=btagDiscAK4
#         )
#
# # AK R=0.4 jets from CHS inputs
# jetToolbox( process, 'ak4', 'ak4JetSubs', 'noOutput',
#   dataTier="miniAOD",
#   PUMethod='CHS',
# #  JETCorrPayload = 'AK4PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
#   addPUJetID=True,
#   addQGTagger=True,
#   Cut='pt>30 && abs(eta)<2.5'
# )
#
# # AK R=0.4 jets from Puppi inputs
# jetToolbox( process, 'ak4', 'ak4JetSubs', 'noOutput',
#   dataTier="miniAOD",
#   PUMethod='Puppi',
# #  JETCorrPayload = 'AK4PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
#   Cut='pt>30 && abs(eta)<2.5'
# )
#
# # AK R=0.4 jets from PF inputs
# jetToolbox( process, 'ak4', 'ak4JetSubs', 'noOutput',
#   dataTier="miniAOD",
#   PUMethod='Plain',
# #  JETCorrPayload = 'AK4PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
#   Cut='pt>30 && abs(eta)<2.5'
# )
#
#
#
# # updating slimmedAK8Jets (ak8 puppi jets) from miniAOD
# jetToolbox( process, 'ak8', 'ak8UpdJetSubs', 'noOutput',
#         dataTier="miniAOD",
#         PUMethod='Puppi',
#         updateCollection='slimmedJetsAK8',
#         JETCorrPayload='AK8PFPuppi',
#         postFix='Updated',
#         bTagDiscriminators=btagDiscAK8
#         )
#
# # AK R=0.8 jets from CHS
# jetToolbox( process, 'ak8', 'ak8JetSubs', 'noOutput',
#   dataTier="miniAOD",
#   Cut="pt>170 && abs(eta)<2.5",
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   addTrimming=True, addFiltering=True,
#   addSoftDropSubjets=True,
#   addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute'],
# )
#
# # AK R=0.8 from PUPPI
# jetToolbox( process, 'ak8', 'ak8JetSubs', 'noOutput',
#   dataTier="miniAOD",
#   PUMethod='Puppi',
#   Cut="pt>170 && abs(eta)<2.5",
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   addTrimming=True, addFiltering=True,
#   addSoftDropSubjets=True,
#   addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
#   addEnergyCorrFunc=True,
#   #JETCorrPayload = 'AK8PFPuppi', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # CA R=0.8 jets from CHS
# jetToolbox( process, 'ca8', 'ca8JetSubs', 'noOutput',
#   Cut="pt>170 && abs(eta)<2.5",
#   dataTier="miniAOD",
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # KT R=0.8 jets from CHS
# jetToolbox( process, 'kt8', 'kt8JetSubs', 'noOutput',
#   Cut="pt>170 && abs(eta)<2.5",
#   dataTier="miniAOD",
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # KT R=0.8 jets from CHS
# jetToolbox( process, 'kt8', 'kt8JetSubs', 'noOutput',
#   dataTier="miniAOD",
#   Cut="pt>170 && abs(eta)<2.5",
#   PUMethod='CHS',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # AK R=0.8 jets from Puppi, modified Softdrop
# jetToolbox( process, 'ak8', 'ak8JetSubs', 'noOutput',
#   dataTier="miniAOD",
#   Cut="pt>170 && abs(eta)<2.5",
#   PUMethod='Puppi',
#   postFix='modSD',
#   addSoftDrop=True , betaCut=1,           # add basic grooming
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# # AK R=0.8 jets from SK
# jetToolbox( process, 'ak8', 'ak8JetSubs', 'noOutput',
#   dataTier="miniAOD",
#   Cut="pt>170 && abs(eta)<2.5",
#   PUMethod='SK',
#   addPruning=True, addSoftDrop=True ,           # add basic grooming
#   JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# )
#
# ## AK R=0.8 jets from CS
# #jetToolbox( process, 'ak8', 'ak8JetSubs', 'noOutput',
# #  PUMethod='CS',
# #  addPruning=True, addSoftDrop=True ,           # add basic grooming
# #  JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# #)
#
# # CA R=1.2 jets from CHS inputs with basic grooming, W tagging, and top tagging
# #jetToolbox( process, 'ca12', 'ca12JetSubs', 'noOutput',
# #  PUMethod='CHS',
# #  addHEPTopTagger=True,
# #)
#
#
# ## AK R=1.2 jets from CHS inputs with basic grooming, W tagging, and top tagging
# #jetToolbox( process, 'ak12', 'ak12JetSubs', 'noOutput',
# #  PUMethod='CHS',
# #  addPruning=True, addSoftDrop=True ,           # add basic grooming
# #  addTrimming=True, addFiltering=True,
# #  addSoftDropSubjets=True,
# #  addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
# #  JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# #)
# #
# ## AK R=1.5 jets from CHS inputs with basic grooming, W tagging, and top tagging
# #jetToolbox( process, 'ak15', 'ak15JetSubs', 'noOutput',
# #  PUMethod='CHS',
# #  addPruning=True, addSoftDrop=True ,           # add basic grooming
# #  addTrimming=True, addFiltering=True,
# #  addSoftDropSubjets=True,
# #  addNsub=True, maxTau=4,                       # add Nsubjettiness tau1, tau2, tau3, tau4
# #  JETCorrPayload = 'AK8PFchs', JETCorrLevels = ['L2Relative', 'L3Absolute']
# #)
#
# ### MAKE SOME HISTOGRAMS
# process.ana = cms.EDAnalyzer('JetTester'
# )
#
# ### OUT
# process.TFileService = cms.Service("TFileService",
#       fileName = cms.string("JetClusterHistos_ZP3.root"),
#       closeFileFast = cms.untracked.bool(True)
#   )
#
# process.p = cms.Path(process.ana)
#
# ```
#
# </p>
# </details>
#
# Now you can run the script in your terminal, or in the next cell to create a bunch of new jet collections:

# %%
# %%bash
# cmsRun $CMSSW_BASE/src/Analysis/JMEDAS/scripts/ClusterWithToolboxAndMakeHistos.py
# Out:
# |---- jetToolbox: Initializing collection... (with postfix Updated)
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags', 'pfDeepCSVJetTags:probb', 'pfDeepCSVJetTags:probbb', 'pfDeepCSVJetTags:probc', 'pfDeepCSVJetTags:probudsg', 'pfDeepFlavourJetTags:probb', 'pfDeepFlavourJetTags:probbb', 'pfDeepFlavourJetTags:problepb', 'pfDeepFlavourJetTags:probc', 'pfDeepFlavourJetTags:probuds', 'pfDeepFlavourJetTags:probg'] in the jet collection.
# |---- jetToolBox: JETTOOLBOX IS UPDATING slimmedJets collection
# |---- jetToolBox: Applying these corrections: ('AK4PFchs', ['L1FastJet', 'L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating selectedPatJetsAK4PFCHSUpdated collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the jet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK4 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK4PFchs', ['L1FastJet', 'L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Running QGTaggerAK4PFCHS, AK4PFCHSpileupJetIdEvaluator.
# |---- jetToolBox: Creating selectedPatJetsAK4PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the jet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK4 JETS USING Puppi
# |---- jetToolBox: Applying these corrections: ('AK4PFPuppi', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating selectedPatJetsAK4PFPuppi collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the jet collection.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK4 JETS USING Plain
# |---- jetToolBox: Applying these corrections: ('AK4PF', ['L1FastJet', 'L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating selectedPatJetsAK4PFPlain collection.
# |---- jetToolbox: Initializing collection... (with postfix Updated)
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags', 'pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:bbvsLight', 'pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ccvsLight', 'pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:TvsQCD', 'pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZHccvsQCD', 'pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:WvsQCD', 'pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZHbbvsQCD'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX IS UPDATING slimmedJetsAK8 collection
# |---- jetToolBox: Applying these corrections: ('AK8PFPuppi', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating selectedPatJetsAK8PFPuppiUpdated collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags', 'pfMassIndependentDeepDoubleBvLJetTags:probQCD', 'pfMassIndependentDeepDoubleBvLJetTags:probHbb', 'pfMassIndependentDeepDoubleCvLJetTags:probQCD', 'pfMassIndependentDeepDoubleCvLJetTags:probHcc', 'pfMassIndependentDeepDoubleCvBJetTags:probHbb', 'pfMassIndependentDeepDoubleCvBJetTags:probHcc'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK8 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsAK8PFCHSSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ak8PFJetsCHSSoftDropMass, selectedPatJetsAK8PFCHSSoftDropPacked:SubJets, ak8PFJetsCHSPrunedMass, ak8PFJetsCHSTrimmedMass, ak8PFJetsCHSFilteredMass, NjettinessAK8CHS.
# |---- jetToolBox: Creating selectedPatJetsAK8PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags', 'pfMassIndependentDeepDoubleBvLJetTags:probQCD', 'pfMassIndependentDeepDoubleBvLJetTags:probHbb', 'pfMassIndependentDeepDoubleCvLJetTags:probQCD', 'pfMassIndependentDeepDoubleCvLJetTags:probHcc', 'pfMassIndependentDeepDoubleCvBJetTags:probHbb', 'pfMassIndependentDeepDoubleCvBJetTags:probHcc'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK8 JETS USING Puppi
# |---- jetToolBox: Applying these corrections: ('AK8PFPuppi', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsAK8PFPuppiSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ak8PFJetsPuppiSoftDropMass, selectedPatJetsAK8PFPuppiSoftDropPacked:SubJets, ak8PFJetsPuppiPrunedMass, ak8PFJetsPuppiTrimmedMass, ak8PFJetsPuppiFilteredMass, NjettinessAK8Puppi, nb1AK8PuppiSoftDrop.
# |---- jetToolBox: Creating selectedPatJetsAK8PFPuppi collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags', 'pfMassIndependentDeepDoubleBvLJetTags:probQCD', 'pfMassIndependentDeepDoubleBvLJetTags:probHbb', 'pfMassIndependentDeepDoubleCvLJetTags:probQCD', 'pfMassIndependentDeepDoubleCvLJetTags:probHcc', 'pfMassIndependentDeepDoubleCvBJetTags:probHbb', 'pfMassIndependentDeepDoubleCvBJetTags:probHcc'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR CA8 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Running ca8PFJetsCHSSoftDropMass, ca8PFJetsCHSPrunedMass.
# |---- jetToolBox: Creating selectedPatJetsCA8PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: CMS recommends the following jet algorithms: ak4 ak8 ca4 ca8 ca10 ca15. You are using kt8 .
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags', 'pfMassIndependentDeepDoubleBvLJetTags:probQCD', 'pfMassIndependentDeepDoubleBvLJetTags:probHbb', 'pfMassIndependentDeepDoubleCvLJetTags:probQCD', 'pfMassIndependentDeepDoubleCvLJetTags:probHcc', 'pfMassIndependentDeepDoubleCvBJetTags:probHbb', 'pfMassIndependentDeepDoubleCvBJetTags:probHcc'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR KT8 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Running kt8PFJetsCHSSoftDropMass, kt8PFJetsCHSPrunedMass.
# |---- jetToolBox: Creating selectedPatJetsKT8PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: CMS recommends the following jet algorithms: ak4 ak8 ca4 ca8 ca10 ca15. You are using kt8 .
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags', 'pfMassIndependentDeepDoubleBvLJetTags:probQCD', 'pfMassIndependentDeepDoubleBvLJetTags:probHbb', 'pfMassIndependentDeepDoubleCvLJetTags:probQCD', 'pfMassIndependentDeepDoubleCvLJetTags:probHcc', 'pfMassIndependentDeepDoubleCvBJetTags:probHbb', 'pfMassIndependentDeepDoubleCvBJetTags:probHcc'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR KT8 JETS USING CHS
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Running kt8PFJetsCHSSoftDropMass, kt8PFJetsCHSPrunedMass.
# |---- jetToolBox: Creating selectedPatJetsKT8PFCHS collection.
# |---- jetToolbox: Initializing collection... (with postfix modSD)
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags', 'pfMassIndependentDeepDoubleBvLJetTags:probQCD', 'pfMassIndependentDeepDoubleBvLJetTags:probHbb', 'pfMassIndependentDeepDoubleCvLJetTags:probQCD', 'pfMassIndependentDeepDoubleCvLJetTags:probHcc', 'pfMassIndependentDeepDoubleCvBJetTags:probHbb', 'pfMassIndependentDeepDoubleCvBJetTags:probHcc'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK8 JETS USING Puppi
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Running ak8PFJetsPuppimodSDSoftDropMass.
# |---- jetToolBox: Creating selectedPatJetsAK8PFPuppimodSD collection.
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags', 'pfMassIndependentDeepDoubleBvLJetTags:probQCD', 'pfMassIndependentDeepDoubleBvLJetTags:probHbb', 'pfMassIndependentDeepDoubleCvLJetTags:probQCD', 'pfMassIndependentDeepDoubleCvLJetTags:probHcc', 'pfMassIndependentDeepDoubleCvBJetTags:probHbb', 'pfMassIndependentDeepDoubleCvBJetTags:probHcc'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK8 JETS USING SK
# |---- jetToolBox: Applying these corrections: ('AK8PFchs', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Running ak8PFJetsSKSoftDropMass, ak8PFJetsSKPrunedMass.
# |---- jetToolBox: Creating selectedPatJetsAK8PFSK collection.
# **************************************************************
# b tagging needs to be run on uncorrected jets. Hence, the JECs
# will first be undone for 'updatedPatJetsAK4PFCHSUpdated' and then applied to
# 'updatedPatJetsTransientCorrectedAK4PFCHSUpdated'.
# **************************************************************
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# **************************************************************
# b tagging needs to be run on uncorrected jets. Hence, the JECs
# will first be undone for 'updatedPatJetsAK8PFPuppiUpdated' and then applied to
# 'updatedPatJetsTransientCorrectedAK8PFPuppiUpdated'.
# **************************************************************
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# 27-Aug-2020 17:04:43 CEST  Initiating request to open file root://eoscms.cern.ch//eos/cms/store/mc/RunIIAutumn18MiniAOD/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15_ext1-v2/20000/7E65457A-87E5-C146-8321-9A48B4F56ED1.root
# %MSG-w XrdAdaptorInternal:  file_open 27-Aug-2020 17:04:45 CEST pre-events
# Failed to open file at URL root://eoscms.cern.ch:1094//eos/cms/store/mc/RunIIAutumn18MiniAOD/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15_ext1-v2/20000/7E65457A-87E5-C146-8321-9A48B4F56ED1.root.
# %MSG
# %MSG-w XrdAdaptorInternal:  file_open 27-Aug-2020 17:04:45 CEST pre-events
# Failed to open file at URL root://eoscms.cern.ch:1094//eos/cms/store/mc/RunIIAutumn18MiniAOD/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15_ext1-v2/20000/7E65457A-87E5-C146-8321-9A48B4F56ED1.root?tried=.
# %MSG
# 27-Aug-2020 17:04:45 CEST  Fallback request to file root://xrootd-cms.infn.it//store/mc/RunIIAutumn18MiniAOD/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15_ext1-v2/20000/7E65457A-87E5-C146-8321-9A48B4F56ED1.root
# %MSG-w XrdAdaptor:  file_open 27-Aug-2020 17:04:48 CEST pre-events
# Data is served from T1_UK_RAL instead of original site infn.it
# %MSG
# 27-Aug-2020 17:04:51 CEST  Successfully opened file root://xrootd-cms.infn.it//store/mc/RunIIAutumn18MiniAOD/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15_ext1-v2/20000/7E65457A-87E5-C146-8321-9A48B4F56ED1.root
# %MSG-w XrdAdaptor:  (NoModuleName) 27-Aug-2020 17:05:45 CEST pre-events
# Data is now served from T1_UK_RAL, jinr-t1.ru instead of previous T1_UK_RAL
# %MSG
# %MSG-w XrdAdaptor:  source 27-Aug-2020 17:07:00 CEST PostStreamBeginLumi
# Data is now served from jinr-t1.ru instead of previous T1_UK_RAL, jinr-t1.ru
# %MSG
# Begin processing the 1st record. Run 1, Event 67193011, LumiSection 47022 on stream 0 at 27-Aug-2020 17:07:01.027 CEST
# 27-Aug-2020 17:08:32 CEST  Closed file root://xrootd-cms.infn.it//store/mc/RunIIAutumn18MiniAOD/TTJets_TuneCP5_13TeV-amcatnloFXFX-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15_ext1-v2/20000/7E65457A-87E5-C146-8321-9A48B4F56ED1.root
#
# TrigReport ---------- Event  Summary ------------
# TrigReport Events total = 100 passed = 100 failed = 0
#
# TrigReport ---------- Path   Summary ------------
# TrigReport  Trig Bit#   Executed     Passed     Failed      Error Name
# TrigReport     1    0        100        100          0          0 p
#
# TrigReport -------End-Path   Summary ------------
# TrigReport  Trig Bit#   Executed     Passed     Failed      Error Name
#
# TrigReport ---------- Modules in Path: p ------------
# TrigReport  Trig Bit#    Visited     Passed     Failed      Error Name
# TrigReport     1    0        100        100          0          0 ana
#
# TrigReport ---------- Module Summary ------------
# TrigReport    Visited   Executed     Passed     Failed      Error Name
# TrigReport        100        100        100          0          0 AK4PFCHSpileupJetIdCalculator
# TrigReport        300        100        100          0          0 AK4PFCHSpileupJetIdEvaluator
# TrigReport        400        100        100          0          0 NjettinessAK8CHS
# TrigReport        400        100        100          0          0 NjettinessAK8Puppi
# TrigReport        100        100        100          0          0 QGTaggerAK4PFCHS
# TrigReport        100        100        100          0          0 TriggerResults
# TrigReport        100        100        100          0          0 ak4GenJetsNoNu
# TrigReport        100        100        100          0          0 ak4PFJets
# TrigReport        100        100        100          0          0 ak4PFJetsCHS
# TrigReport          0          0          0          0          0 ak4PFJetsCHSConstituents
# TrigReport          0          0          0          0          0 ak4PFJetsConstituents
# TrigReport        100        100        100          0          0 ak4PFJetsPuppi
# TrigReport          0          0          0          0          0 ak4PFJetsPuppiConstituents
# TrigReport        100        100        100          0          0 ak8GenJetsNoNu
# TrigReport        100        100        100          0          0 ak8GenJetsNoNuSoftDrop
# TrigReport        100        100        100          0          0 ak8PFJetsCHS
# TrigReport        100        100        100          0          0 ak8PFJetsCHSConstituents
# TrigReport        100        100        100          0          0 ak8PFJetsCHSFiltered
# TrigReport        100        100        100          0          0 ak8PFJetsCHSFilteredMass
# TrigReport        100        100        100          0          0 ak8PFJetsCHSPruned
# TrigReport        100        100        100          0          0 ak8PFJetsCHSPrunedMass
# TrigReport        200        100        100          0          0 ak8PFJetsCHSSoftDrop
# TrigReport        100        100        100          0          0 ak8PFJetsCHSSoftDropMass
# TrigReport        100        100        100          0          0 ak8PFJetsCHSTrimmed
# TrigReport        100        100        100          0          0 ak8PFJetsCHSTrimmedMass
# TrigReport        100        100        100          0          0 ak8PFJetsPuppi
# TrigReport        100        100        100          0          0 ak8PFJetsPuppiConstituents
# TrigReport        100        100        100          0          0 ak8PFJetsPuppiFiltered
# TrigReport        100        100        100          0          0 ak8PFJetsPuppiFilteredMass
# TrigReport        100        100        100          0          0 ak8PFJetsPuppiPruned
# TrigReport        100        100        100          0          0 ak8PFJetsPuppiPrunedMass
# TrigReport        200        100        100          0          0 ak8PFJetsPuppiSoftDrop
# TrigReport        100        100        100          0          0 ak8PFJetsPuppiSoftDropMass
# TrigReport        200        100        100          0          0 ak8PFJetsPuppiSoftDropValueMap
# TrigReport        100        100        100          0          0 ak8PFJetsPuppiTrimmed
# TrigReport        100        100        100          0          0 ak8PFJetsPuppiTrimmedMass
# TrigReport        100        100        100          0          0 ak8PFJetsPuppimodSD
# TrigReport        100        100        100          0          0 ak8PFJetsPuppimodSDConstituents
# TrigReport        100        100        100          0          0 ak8PFJetsPuppimodSDSoftDrop
# TrigReport        100        100        100          0          0 ak8PFJetsPuppimodSDSoftDropMass
# TrigReport        100        100        100          0          0 ak8PFJetsSK
# TrigReport        100        100        100          0          0 ak8PFJetsSKConstituents
# TrigReport        100        100        100          0          0 ak8PFJetsSKPruned
# TrigReport        100        100        100          0          0 ak8PFJetsSKPrunedMass
# TrigReport        100        100        100          0          0 ak8PFJetsSKSoftDrop
# TrigReport        100        100        100          0          0 ak8PFJetsSKSoftDropMass
# TrigReport        100        100        100          0          0 ana
# TrigReport        100        100        100          0          0 ca8GenJetsNoNu
# TrigReport        100        100        100          0          0 ca8PFJetsCHS
# TrigReport        100        100        100          0          0 ca8PFJetsCHSConstituents
# TrigReport        100        100        100          0          0 ca8PFJetsCHSPruned
# TrigReport        100        100        100          0          0 ca8PFJetsCHSPrunedMass
# TrigReport        100        100        100          0          0 ca8PFJetsCHSSoftDrop
# TrigReport        100        100        100          0          0 ca8PFJetsCHSSoftDropMass
# TrigReport          0          0          0          0          0 candidateVertexArbitrator
# TrigReport        100        100        100          0          0 candidateVertexArbitratorCvsL
# TrigReport          0          0          0          0          0 candidateVertexArbitratorDefault
# TrigReport          0          0          0          0          0 candidateVertexMerger
# TrigReport        100        100        100          0          0 candidateVertexMergerCvsL
# TrigReport        100        100        100          0          0 chs
# TrigReport        100        100        100          0          0 endpath
# TrigReport          0          0          0          0          0 inclusiveCandidateSecondaryVertices
# TrigReport          0          0          0          0          0 inclusiveCandidateSecondaryVerticesCvsL
# TrigReport          0          0          0          0          0 inclusiveCandidateVertexFinder
# TrigReport        100        100        100          0          0 inclusiveCandidateVertexFinderCvsL
# TrigReport          0          0          0          0          0 inclusiveCandidateVertexFinderDefault
# TrigReport          0          0          0          0          0 inclusiveSecondaryVertices
# TrigReport          0          0          0          0          0 inclusiveVertexFinder
# TrigReport          0          0          0          0          0 inclusiveVertexFinderDefault
# TrigReport        100        100        100          0          0 kt8GenJetsNoNu
# TrigReport        100        100        100          0          0 kt8PFJetsCHS
# TrigReport        100        100        100          0          0 kt8PFJetsCHSConstituents
# TrigReport        100        100        100          0          0 kt8PFJetsCHSPruned
# TrigReport        100        100        100          0          0 kt8PFJetsCHSPrunedMass
# TrigReport        100        100        100          0          0 kt8PFJetsCHSSoftDrop
# TrigReport        100        100        100          0          0 kt8PFJetsCHSSoftDropMass
# TrigReport        200        100        100          0          0 nb1AK8PuppiSoftDrop
# TrigReport        100        100        100          0          0 p
# TrigReport        100        100        100          0          0 packedGenParticlesForJetsNoNu
# TrigReport        100        100        100          0          0 packedPatJetsAK8PFCHSSoftDrop
# TrigReport        100        100        100          0          0 packedPatJetsAK8PFPuppiSoftDrop
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK4PFCHS
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK4PFPlain
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK4PFPuppi
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK8PFCHS
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK8PFCHSSoftDrop
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK8PFPuppi
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK8PFPuppiSoftDrop
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK8PFPuppiUpdated
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 patJetCorrFactorsAK8PFSK
# TrigReport        100        100        100          0          0 patJetCorrFactorsCA8PFCHS
# TrigReport        100        100        100          0          0 patJetCorrFactorsKT8PFCHS
# TrigReport        100        100        100          0          0 patJetCorrFactorsTransientCorrectedAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 patJetCorrFactorsTransientCorrectedAK8PFPuppiUpdated
# TrigReport        100        100        100          0          0 patJetFlavourAssociationAK4PFCHS
# TrigReport        100        100        100          0          0 patJetFlavourAssociationAK4PFPlain
# TrigReport        100        100        100          0          0 patJetFlavourAssociationAK4PFPuppi
# TrigReport        100        100        100          0          0 patJetFlavourAssociationAK8PFCHS
# TrigReport        100        100        100          0          0 patJetFlavourAssociationAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 patJetFlavourAssociationAK8PFPuppi
# TrigReport        100        100        100          0          0 patJetFlavourAssociationAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 patJetFlavourAssociationAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 patJetFlavourAssociationAK8PFSK
# TrigReport        100        100        100          0          0 patJetFlavourAssociationCA8PFCHS
# TrigReport        100        100        100          0          0 patJetFlavourAssociationKT8PFCHS
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyAK4PFCHS
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyAK4PFPlain
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyAK4PFPuppi
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyAK8PFCHS
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyAK8PFCHSSoftDropSubjets
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyAK8PFPuppi
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyAK8PFPuppiSoftDropSubjets
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyAK8PFPuppimodSD
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyAK8PFSK
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyCA8PFCHS
# TrigReport          0          0          0          0          0 patJetFlavourAssociationLegacyKT8PFCHS
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK4PFCHS
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK4PFPlain
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK4PFPuppi
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK8PFCHS
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK8PFCHSSoftDrop
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK8PFPuppi
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK8PFPuppiSoftDrop
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 patJetGenJetMatchAK8PFSK
# TrigReport        100        100        100          0          0 patJetGenJetMatchCA8PFCHS
# TrigReport        100        100        100          0          0 patJetGenJetMatchKT8PFCHS
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyAK4PFCHS
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyAK4PFPlain
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyAK4PFPuppi
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyAK8PFCHS
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyAK8PFCHSSoftDropSubjets
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyAK8PFPuppi
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyAK8PFPuppiSoftDropSubjets
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyAK8PFPuppimodSD
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyAK8PFSK
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyCA8PFCHS
# TrigReport          0          0          0          0          0 patJetPartonAssociationLegacyKT8PFCHS
# TrigReport        100        100        100          0          0 patJetPartonMatchAK4PFCHS
# TrigReport        100        100        100          0          0 patJetPartonMatchAK4PFPlain
# TrigReport        100        100        100          0          0 patJetPartonMatchAK4PFPuppi
# TrigReport        100        100        100          0          0 patJetPartonMatchAK8PFCHS
# TrigReport        100        100        100          0          0 patJetPartonMatchAK8PFCHSSoftDrop
# TrigReport        100        100        100          0          0 patJetPartonMatchAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 patJetPartonMatchAK8PFPuppi
# TrigReport        100        100        100          0          0 patJetPartonMatchAK8PFPuppiSoftDrop
# TrigReport        100        100        100          0          0 patJetPartonMatchAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 patJetPartonMatchAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 patJetPartonMatchAK8PFSK
# TrigReport        100        100        100          0          0 patJetPartonMatchCA8PFCHS
# TrigReport        100        100        100          0          0 patJetPartonMatchKT8PFCHS
# TrigReport        400        100        100          0          0 patJetPartons
# TrigReport          0          0          0          0          0 patJetPartonsLegacy
# TrigReport          0          0          0          0          0 patJetPartonsLegacymodSD
# TrigReport        400        100        100          0          0 patJetPartonsmodSD
# TrigReport        100        100        100          0          0 patJetsAK4PFCHS
# TrigReport          0          0          0          0          0 patJetsAK4PFCHSPATJetswithUserData
# TrigReport          0          0          0          0          0 patJetsAK4PFCHSlooseJetId
# TrigReport          0          0          0          0          0 patJetsAK4PFCHStightJetId
# TrigReport          0          0          0          0          0 patJetsAK4PFCHStightJetIdLepVeto
# TrigReport        100        100        100          0          0 patJetsAK4PFPlain
# TrigReport          0          0          0          0          0 patJetsAK4PFPlainPATJetswithUserData
# TrigReport          0          0          0          0          0 patJetsAK4PFPlainlooseJetId
# TrigReport          0          0          0          0          0 patJetsAK4PFPlaintightJetId
# TrigReport          0          0          0          0          0 patJetsAK4PFPlaintightJetIdLepVeto
# TrigReport        100        100        100          0          0 patJetsAK4PFPuppi
# TrigReport          0          0          0          0          0 patJetsAK4PFPuppiPATJetswithUserData
# TrigReport          0          0          0          0          0 patJetsAK4PFPuppilooseJetId
# TrigReport          0          0          0          0          0 patJetsAK4PFPuppitightJetId
# TrigReport          0          0          0          0          0 patJetsAK4PFPuppitightJetIdLepVeto
# TrigReport        100        100        100          0          0 patJetsAK8PFCHS
# TrigReport          0          0          0          0          0 patJetsAK8PFCHSPATJetswithUserData
# TrigReport        100        100        100          0          0 patJetsAK8PFCHSSoftDrop
# TrigReport        100        100        100          0          0 patJetsAK8PFCHSSoftDropSubjets
# TrigReport          0          0          0          0          0 patJetsAK8PFCHSlooseJetId
# TrigReport          0          0          0          0          0 patJetsAK8PFCHStightJetId
# TrigReport          0          0          0          0          0 patJetsAK8PFCHStightJetIdLepVeto
# TrigReport        100        100        100          0          0 patJetsAK8PFPuppi
# TrigReport          0          0          0          0          0 patJetsAK8PFPuppiPATJetswithUserData
# TrigReport        100        100        100          0          0 patJetsAK8PFPuppiSoftDrop
# TrigReport        100        100        100          0          0 patJetsAK8PFPuppiSoftDropSubjets
# TrigReport          0          0          0          0          0 patJetsAK8PFPuppilooseJetId
# TrigReport        100        100        100          0          0 patJetsAK8PFPuppimodSD
# TrigReport          0          0          0          0          0 patJetsAK8PFPuppimodSDPATJetswithUserData
# TrigReport          0          0          0          0          0 patJetsAK8PFPuppimodSDlooseJetId
# TrigReport          0          0          0          0          0 patJetsAK8PFPuppimodSDtightJetId
# TrigReport          0          0          0          0          0 patJetsAK8PFPuppimodSDtightJetIdLepVeto
# TrigReport          0          0          0          0          0 patJetsAK8PFPuppitightJetId
# TrigReport          0          0          0          0          0 patJetsAK8PFPuppitightJetIdLepVeto
# TrigReport        100        100        100          0          0 patJetsAK8PFSK
# TrigReport          0          0          0          0          0 patJetsAK8PFSKPATJetswithUserData
# TrigReport          0          0          0          0          0 patJetsAK8PFSKlooseJetId
# TrigReport          0          0          0          0          0 patJetsAK8PFSKtightJetId
# TrigReport          0          0          0          0          0 patJetsAK8PFSKtightJetIdLepVeto
# TrigReport        100        100        100          0          0 patJetsCA8PFCHS
# TrigReport          0          0          0          0          0 patJetsCA8PFCHSPATJetswithUserData
# TrigReport          0          0          0          0          0 patJetsCA8PFCHSlooseJetId
# TrigReport          0          0          0          0          0 patJetsCA8PFCHStightJetId
# TrigReport          0          0          0          0          0 patJetsCA8PFCHStightJetIdLepVeto
# TrigReport        100        100        100          0          0 patJetsKT8PFCHS
# TrigReport          0          0          0          0          0 patJetsKT8PFCHSPATJetswithUserData
# TrigReport          0          0          0          0          0 patJetsKT8PFCHSlooseJetId
# TrigReport          0          0          0          0          0 patJetsKT8PFCHStightJetId
# TrigReport          0          0          0          0          0 patJetsKT8PFCHStightJetIdLepVeto
# TrigReport        100        100        100          0          0 pfBoostedDoubleSVAK8TagInfosAK8PFCHS
# TrigReport        100        100        100          0          0 pfBoostedDoubleSVAK8TagInfosAK8PFPuppi
# TrigReport        100        100        100          0          0 pfBoostedDoubleSVAK8TagInfosAK8PFPuppiUpdated
# TrigReport        100        100        100          0          0 pfBoostedDoubleSVAK8TagInfosAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 pfBoostedDoubleSVAK8TagInfosAK8PFSK
# TrigReport        100        100        100          0          0 pfBoostedDoubleSVAK8TagInfosCA8PFCHS
# TrigReport        100        100        100          0          0 pfBoostedDoubleSVAK8TagInfosKT8PFCHS
# TrigReport        100        100        100          0          0 pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFCHS
# TrigReport        100        100        100          0          0 pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFPuppi
# TrigReport        100        100        100          0          0 pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFPuppiUpdated
# TrigReport        100        100        100          0          0 pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFSK
# TrigReport        100        100        100          0          0 pfBoostedDoubleSecondaryVertexAK8BJetTagsCA8PFCHS
# TrigReport        100        100        100          0          0 pfBoostedDoubleSecondaryVertexAK8BJetTagsKT8PFCHS
# TrigReport        100        100        100          0          0 pfCombinedCvsBJetTagsAK4PFCHS
# TrigReport        100        100        100          0          0 pfCombinedCvsBJetTagsAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfCombinedCvsBJetTagsAK4PFPlain
# TrigReport        100        100        100          0          0 pfCombinedCvsBJetTagsAK4PFPuppi
# TrigReport        100        100        100          0          0 pfCombinedCvsBJetTagsAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 pfCombinedCvsBJetTagsAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 pfCombinedCvsLJetTagsAK4PFCHS
# TrigReport        100        100        100          0          0 pfCombinedCvsLJetTagsAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfCombinedCvsLJetTagsAK4PFPlain
# TrigReport        100        100        100          0          0 pfCombinedCvsLJetTagsAK4PFPuppi
# TrigReport        100        100        100          0          0 pfCombinedCvsLJetTagsAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 pfCombinedCvsLJetTagsAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 pfCombinedInclusiveSecondaryVertexV2BJetTagsAK4PFCHS
# TrigReport        100        100        100          0          0 pfCombinedInclusiveSecondaryVertexV2BJetTagsAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfCombinedInclusiveSecondaryVertexV2BJetTagsAK4PFPlain
# TrigReport        100        100        100          0          0 pfCombinedInclusiveSecondaryVertexV2BJetTagsAK4PFPuppi
# TrigReport        100        100        100          0          0 pfCombinedInclusiveSecondaryVertexV2BJetTagsAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 pfCombinedInclusiveSecondaryVertexV2BJetTagsAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 pfDeepBoostedJetTagInfosAK8PFPuppiUpdated
# TrigReport        400        100        100          0          0 pfDeepCSVJetTagsAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfDeepCSVTagInfosAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfDeepDoubleXTagInfosAK8PFCHS
# TrigReport        100        100        100          0          0 pfDeepDoubleXTagInfosAK8PFPuppi
# TrigReport        100        100        100          0          0 pfDeepDoubleXTagInfosAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 pfDeepDoubleXTagInfosAK8PFSK
# TrigReport        100        100        100          0          0 pfDeepDoubleXTagInfosCA8PFCHS
# TrigReport        100        100        100          0          0 pfDeepDoubleXTagInfosKT8PFCHS
# TrigReport        600        100        100          0          0 pfDeepFlavourJetTagsAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfDeepFlavourTagInfosAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfImpactParameterAK8TagInfosAK8PFCHS
# TrigReport        100        100        100          0          0 pfImpactParameterAK8TagInfosAK8PFPuppi
# TrigReport        100        100        100          0          0 pfImpactParameterAK8TagInfosAK8PFPuppiUpdated
# TrigReport        100        100        100          0          0 pfImpactParameterAK8TagInfosAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 pfImpactParameterAK8TagInfosAK8PFSK
# TrigReport        100        100        100          0          0 pfImpactParameterAK8TagInfosCA8PFCHS
# TrigReport        100        100        100          0          0 pfImpactParameterAK8TagInfosKT8PFCHS
# TrigReport        100        100        100          0          0 pfImpactParameterTagInfosAK4PFCHS
# TrigReport        100        100        100          0          0 pfImpactParameterTagInfosAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfImpactParameterTagInfosAK4PFPlain
# TrigReport        100        100        100          0          0 pfImpactParameterTagInfosAK4PFPuppi
# TrigReport        100        100        100          0          0 pfImpactParameterTagInfosAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 pfImpactParameterTagInfosAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFCHS
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFPuppi
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFPuppiUpdated
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFSK
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderAK8TagInfosCA8PFCHS
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderAK8TagInfosKT8PFCHS
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderCvsLTagInfosAK4PFCHS
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderCvsLTagInfosAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderCvsLTagInfosAK4PFPlain
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderCvsLTagInfosAK4PFPuppi
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderCvsLTagInfosAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderCvsLTagInfosAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderTagInfosAK4PFCHS
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderTagInfosAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderTagInfosAK4PFPlain
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderTagInfosAK4PFPuppi
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderTagInfosAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 pfInclusiveSecondaryVertexFinderTagInfosAK8PFPuppiSoftDropSubjets
# TrigReport        600        100        100          0          0 pfMassDecorrelatedDeepBoostedDiscriminatorsJetTagsAK8PFPuppiUpdated
# TrigReport       1700        100        100          0          0 pfMassDecorrelatedDeepBoostedJetTagsAK8PFPuppiUpdated
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleBvLJetTagsAK8PFCHS
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleBvLJetTagsAK8PFPuppi
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleBvLJetTagsAK8PFPuppimodSD
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleBvLJetTagsAK8PFSK
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleBvLJetTagsCA8PFCHS
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleBvLJetTagsKT8PFCHS
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvBJetTagsAK8PFCHS
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvBJetTagsAK8PFPuppi
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvBJetTagsAK8PFPuppimodSD
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvBJetTagsAK8PFSK
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvBJetTagsCA8PFCHS
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvBJetTagsKT8PFCHS
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvLJetTagsAK8PFCHS
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvLJetTagsAK8PFPuppi
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvLJetTagsAK8PFPuppimodSD
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvLJetTagsAK8PFSK
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvLJetTagsCA8PFCHS
# TrigReport        200        100        100          0          0 pfMassIndependentDeepDoubleCvLJetTagsKT8PFCHS
# TrigReport        200        100        100          0          0 puppi
# TrigReport        100        100        100          0          0 selectedPatJetsAK4PFCHS
# TrigReport        100        100        100          0          0 selectedPatJetsAK4PFCHSUpdated
# TrigReport        100        100        100          0          0 selectedPatJetsAK4PFPlain
# TrigReport        100        100        100          0          0 selectedPatJetsAK4PFPuppi
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFCHS
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFCHSSoftDrop
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFCHSSoftDropPacked
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFCHSSoftDropSubjets
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFPuppi
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFPuppiSoftDrop
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFPuppiSoftDropPacked
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFPuppiSoftDropSubjets
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFPuppiUpdated
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFPuppimodSD
# TrigReport        100        100        100          0          0 selectedPatJetsAK8PFSK
# ...
# TimeReport   0.000669     0.000669     0.000669  patJetsAK8PFSK
# TimeReport   0.000000     0.000000     0.000000  patJetsAK8PFSKPATJetswithUserData
# TimeReport   0.000000     0.000000     0.000000  patJetsAK8PFSKlooseJetId
# TimeReport   0.000000     0.000000     0.000000  patJetsAK8PFSKtightJetId
# TimeReport   0.000000     0.000000     0.000000  patJetsAK8PFSKtightJetIdLepVeto
# TimeReport   0.001069     0.001069     0.001069  patJetsCA8PFCHS
# TimeReport   0.000000     0.000000     0.000000  patJetsCA8PFCHSPATJetswithUserData
# TimeReport   0.000000     0.000000     0.000000  patJetsCA8PFCHSlooseJetId
# TimeReport   0.000000     0.000000     0.000000  patJetsCA8PFCHStightJetId
# TimeReport   0.000000     0.000000     0.000000  patJetsCA8PFCHStightJetIdLepVeto
# TimeReport   0.001077     0.001077     0.001077  patJetsKT8PFCHS
# TimeReport   0.000000     0.000000     0.000000  patJetsKT8PFCHSPATJetswithUserData
# TimeReport   0.000000     0.000000     0.000000  patJetsKT8PFCHSlooseJetId
# TimeReport   0.000000     0.000000     0.000000  patJetsKT8PFCHStightJetId
# TimeReport   0.000000     0.000000     0.000000  patJetsKT8PFCHStightJetIdLepVeto
# TimeReport   0.015763     0.015763     0.015763  pfBoostedDoubleSVAK8TagInfosAK8PFCHS
# TimeReport   0.002623     0.002623     0.002623  pfBoostedDoubleSVAK8TagInfosAK8PFPuppi
# TimeReport   0.000555     0.000555     0.000555  pfBoostedDoubleSVAK8TagInfosAK8PFPuppiUpdated
# TimeReport   0.002667     0.002667     0.002667  pfBoostedDoubleSVAK8TagInfosAK8PFPuppimodSD
# TimeReport   0.006493     0.006493     0.006493  pfBoostedDoubleSVAK8TagInfosAK8PFSK
# TimeReport   0.016541     0.016541     0.016541  pfBoostedDoubleSVAK8TagInfosCA8PFCHS
# TimeReport   0.016231     0.016231     0.016231  pfBoostedDoubleSVAK8TagInfosKT8PFCHS
# TimeReport   0.000506     0.000506     0.000506  pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFCHS
# TimeReport   0.000171     0.000171     0.000171  pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFPuppi
# TimeReport   0.001877     0.001877     0.001877  pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFPuppiUpdated
# TimeReport   0.000160     0.000160     0.000160  pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFPuppimodSD
# TimeReport   0.000404     0.000404     0.000404  pfBoostedDoubleSecondaryVertexAK8BJetTagsAK8PFSK
# TimeReport   0.000595     0.000595     0.000595  pfBoostedDoubleSecondaryVertexAK8BJetTagsCA8PFCHS
# TimeReport   0.000567     0.000567     0.000567  pfBoostedDoubleSecondaryVertexAK8BJetTagsKT8PFCHS
# TimeReport   0.003696     0.003696     0.003696  pfCombinedCvsBJetTagsAK4PFCHS
# TimeReport   0.000960     0.000960     0.000960  pfCombinedCvsBJetTagsAK4PFCHSUpdated
# TimeReport   0.004529     0.004529     0.004529  pfCombinedCvsBJetTagsAK4PFPlain
# TimeReport   0.007775     0.007775     0.007775  pfCombinedCvsBJetTagsAK4PFPuppi
# TimeReport   0.000077     0.000077     0.000077  pfCombinedCvsBJetTagsAK8PFCHSSoftDropSubjets
# TimeReport   0.000048     0.000048     0.000048  pfCombinedCvsBJetTagsAK8PFPuppiSoftDropSubjets
# TimeReport   0.005464     0.005464     0.005464  pfCombinedCvsLJetTagsAK4PFCHS
# TimeReport   0.001381     0.001381     0.001381  pfCombinedCvsLJetTagsAK4PFCHSUpdated
# TimeReport   0.006802     0.006802     0.006802  pfCombinedCvsLJetTagsAK4PFPlain
# TimeReport   0.018702     0.018702     0.018702  pfCombinedCvsLJetTagsAK4PFPuppi
# TimeReport   0.000109     0.000109     0.000109  pfCombinedCvsLJetTagsAK8PFCHSSoftDropSubjets
# TimeReport   0.000067     0.000067     0.000067  pfCombinedCvsLJetTagsAK8PFPuppiSoftDropSubjets
# TimeReport   0.000730     0.000730     0.000730  pfCombinedInclusiveSecondaryVertexV2BJetTagsAK4PFCHS
# TimeReport   0.000379     0.000379     0.000379  pfCombinedInclusiveSecondaryVertexV2BJetTagsAK4PFCHSUpdated
# TimeReport   0.000934     0.000934     0.000934  pfCombinedInclusiveSecondaryVertexV2BJetTagsAK4PFPlain
# TimeReport   0.002182     0.002182     0.002182  pfCombinedInclusiveSecondaryVertexV2BJetTagsAK4PFPuppi
# TimeReport   0.000056     0.000056     0.000056  pfCombinedInclusiveSecondaryVertexV2BJetTagsAK8PFCHSSoftDropSubjets
# TimeReport   0.000034     0.000034     0.000034  pfCombinedInclusiveSecondaryVertexV2BJetTagsAK8PFPuppiSoftDropSubjets
# TimeReport   0.188455     0.188455     0.188455  pfDeepBoostedJetTagInfosAK8PFPuppiUpdated
# TimeReport   0.000472     0.000472     0.000472  pfDeepCSVJetTagsAK4PFCHSUpdated
# TimeReport   0.000249     0.000249     0.000249  pfDeepCSVTagInfosAK4PFCHSUpdated
# TimeReport   0.000130     0.000130     0.000130  pfDeepDoubleXTagInfosAK8PFCHS
# TimeReport   0.000077     0.000077     0.000077  pfDeepDoubleXTagInfosAK8PFPuppi
# TimeReport   0.000068     0.000068     0.000068  pfDeepDoubleXTagInfosAK8PFPuppimodSD
# TimeReport   0.000059     0.000059     0.000059  pfDeepDoubleXTagInfosAK8PFSK
# TimeReport   0.000117     0.000117     0.000117  pfDeepDoubleXTagInfosCA8PFCHS
# TimeReport   0.000111     0.000111     0.000111  pfDeepDoubleXTagInfosKT8PFCHS
# TimeReport   0.063596     0.063596     0.063596  pfDeepFlavourJetTagsAK4PFCHSUpdated
# TimeReport   0.000602     0.000602     0.000602  pfDeepFlavourTagInfosAK4PFCHSUpdated
# TimeReport   0.003152     0.003152     0.003152  pfImpactParameterAK8TagInfosAK8PFCHS
# TimeReport   0.001281     0.001281     0.001281  pfImpactParameterAK8TagInfosAK8PFPuppi
# TimeReport   0.004639     0.004639     0.004639  pfImpactParameterAK8TagInfosAK8PFPuppiUpdated
# TimeReport   0.001287     0.001287     0.001287  pfImpactParameterAK8TagInfosAK8PFPuppimodSD
# TimeReport   0.002710     0.002710     0.002710  pfImpactParameterAK8TagInfosAK8PFSK
# TimeReport   0.003724     0.003724     0.003724  pfImpactParameterAK8TagInfosCA8PFCHS
# TimeReport   0.003542     0.003542     0.003542  pfImpactParameterAK8TagInfosKT8PFCHS
# TimeReport   0.010333     0.010333     0.010333  pfImpactParameterTagInfosAK4PFCHS
# TimeReport   0.004187     0.004187     0.004187  pfImpactParameterTagInfosAK4PFCHSUpdated
# TimeReport   0.013430     0.013430     0.013430  pfImpactParameterTagInfosAK4PFPlain
# TimeReport   0.003798     0.003798     0.003798  pfImpactParameterTagInfosAK4PFPuppi
# TimeReport   0.000386     0.000386     0.000386  pfImpactParameterTagInfosAK8PFCHSSoftDropSubjets
# TimeReport   0.000250     0.000250     0.000250  pfImpactParameterTagInfosAK8PFPuppiSoftDropSubjets
# TimeReport   0.000313     0.000313     0.000313  pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFCHS
# TimeReport   0.000202     0.000202     0.000202  pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFPuppi
# TimeReport   0.000189     0.000189     0.000189  pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFPuppiUpdated
# TimeReport   0.000207     0.000207     0.000207  pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFPuppimodSD
# TimeReport   0.000296     0.000296     0.000296  pfInclusiveSecondaryVertexFinderAK8TagInfosAK8PFSK
# TimeReport   0.000360     0.000360     0.000360  pfInclusiveSecondaryVertexFinderAK8TagInfosCA8PFCHS
# TimeReport   0.000342     0.000342     0.000342  pfInclusiveSecondaryVertexFinderAK8TagInfosKT8PFCHS
# TimeReport   0.000319     0.000319     0.000319  pfInclusiveSecondaryVertexFinderCvsLTagInfosAK4PFCHS
# TimeReport   0.000171     0.000171     0.000171  pfInclusiveSecondaryVertexFinderCvsLTagInfosAK4PFCHSUpdated
# TimeReport   0.000383     0.000383     0.000383  pfInclusiveSecondaryVertexFinderCvsLTagInfosAK4PFPlain
# TimeReport   0.000178     0.000178     0.000178  pfInclusiveSecondaryVertexFinderCvsLTagInfosAK4PFPuppi
# TimeReport   0.000762     0.000762     0.000762  pfInclusiveSecondaryVertexFinderCvsLTagInfosAK8PFCHSSoftDropSubjets
# TimeReport   0.000130     0.000130     0.000130  pfInclusiveSecondaryVertexFinderCvsLTagInfosAK8PFPuppiSoftDropSubjets
# TimeReport   0.000268     0.000268     0.000268  pfInclusiveSecondaryVertexFinderTagInfosAK4PFCHS
# TimeReport   0.000143     0.000143     0.000143  pfInclusiveSecondaryVertexFinderTagInfosAK4PFCHSUpdated
# TimeReport   0.000326     0.000326     0.000326  pfInclusiveSecondaryVertexFinderTagInfosAK4PFPlain
# TimeReport   0.000134     0.000134     0.000134  pfInclusiveSecondaryVertexFinderTagInfosAK4PFPuppi
# TimeReport   0.000741     0.000741     0.000741  pfInclusiveSecondaryVertexFinderTagInfosAK8PFCHSSoftDropSubjets
# TimeReport   0.000104     0.000104     0.000104  pfInclusiveSecondaryVertexFinderTagInfosAK8PFPuppiSoftDropSubjets
# TimeReport   0.000055     0.000055     0.000055  pfMassDecorrelatedDeepBoostedDiscriminatorsJetTagsAK8PFPuppiUpdated
# TimeReport   0.001715     0.001715     0.001715  pfMassDecorrelatedDeepBoostedJetTagsAK8PFPuppiUpdated
# TimeReport   0.003619     0.003619     0.003619  pfMassIndependentDeepDoubleBvLJetTagsAK8PFCHS
# TimeReport   0.002790     0.002790     0.002790  pfMassIndependentDeepDoubleBvLJetTagsAK8PFPuppi
# TimeReport   0.002755     0.002755     0.002755  pfMassIndependentDeepDoubleBvLJetTagsAK8PFPuppimodSD
# TimeReport   0.002726     0.002726     0.002726  pfMassIndependentDeepDoubleBvLJetTagsAK8PFSK
# TimeReport   0.002899     0.002899     0.002899  pfMassIndependentDeepDoubleBvLJetTagsCA8PFCHS
# TimeReport   0.002821     0.002821     0.002821  pfMassIndependentDeepDoubleBvLJetTagsKT8PFCHS
# TimeReport   0.003549     0.003549     0.003549  pfMassIndependentDeepDoubleCvBJetTagsAK8PFCHS
# TimeReport   0.002868     0.002868     0.002868  pfMassIndependentDeepDoubleCvBJetTagsAK8PFPuppi
# TimeReport   0.002735     0.002735     0.002735  pfMassIndependentDeepDoubleCvBJetTagsAK8PFPuppimodSD
# TimeReport   0.002733     0.002733     0.002733  pfMassIndependentDeepDoubleCvBJetTagsAK8PFSK
# TimeReport   0.002896     0.002896     0.002896  pfMassIndependentDeepDoubleCvBJetTagsCA8PFCHS
# TimeReport   0.002812     0.002812     0.002812  pfMassIndependentDeepDoubleCvBJetTagsKT8PFCHS
# TimeReport   0.003730     0.003730     0.003730  pfMassIndependentDeepDoubleCvLJetTagsAK8PFCHS
# TimeReport   0.003325     0.003325     0.003325  pfMassIndependentDeepDoubleCvLJetTagsAK8PFPuppi
# TimeReport   0.003001     0.003001     0.003001  pfMassIndependentDeepDoubleCvLJetTagsAK8PFPuppimodSD
# TimeReport   0.002826     0.002826     0.002826  pfMassIndependentDeepDoubleCvLJetTagsAK8PFSK
# TimeReport   0.003011     0.003011     0.003011  pfMassIndependentDeepDoubleCvLJetTagsCA8PFCHS
# TimeReport   0.002889     0.002889     0.002889  pfMassIndependentDeepDoubleCvLJetTagsKT8PFCHS
# TimeReport   0.023605     0.023605     0.023605  puppi
# TimeReport   0.000086     0.000086     0.000086  selectedPatJetsAK4PFCHS
# TimeReport   0.003402     0.003402     0.003402  selectedPatJetsAK4PFCHSUpdated
# TimeReport   0.000083     0.000083     0.000083  selectedPatJetsAK4PFPlain
# TimeReport   0.000066     0.000066     0.000066  selectedPatJetsAK4PFPuppi
# TimeReport   0.000029     0.000029     0.000029  selectedPatJetsAK8PFCHS
# TimeReport   0.000012     0.000012     0.000012  selectedPatJetsAK8PFCHSSoftDrop
# TimeReport   0.000013     0.000013     0.000013  selectedPatJetsAK8PFCHSSoftDropPacked
# TimeReport   0.000014     0.000014     0.000014  selectedPatJetsAK8PFCHSSoftDropSubjets
# TimeReport   0.000021     0.000021     0.000021  selectedPatJetsAK8PFPuppi
# TimeReport   0.000011     0.000011     0.000011  selectedPatJetsAK8PFPuppiSoftDrop
# TimeReport   0.000012     0.000012     0.000012  selectedPatJetsAK8PFPuppiSoftDropPacked
# TimeReport   0.000011     0.000011     0.000011  selectedPatJetsAK8PFPuppiSoftDropSubjets
# TimeReport   0.000163     0.000163     0.000163  selectedPatJetsAK8PFPuppiUpdated
# TimeReport   0.000019     0.000019     0.000019  selectedPatJetsAK8PFPuppimodSD
# TimeReport   0.000027     0.000027     0.000027  selectedPatJetsAK8PFSK
# TimeReport   0.000030     0.000030     0.000030  selectedPatJetsCA8PFCHS
# TimeReport   0.000028     0.000028     0.000028  selectedPatJetsKT8PFCHS
# TimeReport   0.000000     0.000000     0.000000  selectedUpdatedPatJetsAK4PFCHSUpdated
# TimeReport   0.000000     0.000000     0.000000  selectedUpdatedPatJetsAK8PFPuppiUpdated
# TimeReport   0.000018     0.000018     0.000018  slimmedSecondaryVerticesCvsL
# TimeReport   0.001991     0.001991     0.001991  softKiller
# TimeReport   0.000081     0.000081     0.000081  softPFElectronsTagInfosAK4PFCHS
# TimeReport   0.000039     0.000039     0.000039  softPFElectronsTagInfosAK4PFCHSUpdated
# TimeReport   0.000091     0.000091     0.000091  softPFElectronsTagInfosAK4PFPlain
# TimeReport   0.000146     0.000146     0.000146  softPFElectronsTagInfosAK4PFPuppi
# TimeReport   0.000009     0.000009     0.000009  softPFElectronsTagInfosAK8PFCHSSoftDropSubjets
# TimeReport   0.000007     0.000007     0.000007  softPFElectronsTagInfosAK8PFPuppiSoftDropSubjets
# TimeReport   0.000075     0.000075     0.000075  softPFMuonsTagInfosAK4PFCHS
# TimeReport   0.000043     0.000043     0.000043  softPFMuonsTagInfosAK4PFCHSUpdated
# TimeReport   0.000091     0.000091     0.000091  softPFMuonsTagInfosAK4PFPlain
# TimeReport   0.000023     0.000023     0.000023  softPFMuonsTagInfosAK4PFPuppi
# TimeReport   0.000010     0.000010     0.000010  softPFMuonsTagInfosAK8PFCHSSoftDropSubjets
# TimeReport   0.000007     0.000007     0.000007  softPFMuonsTagInfosAK8PFPuppiSoftDropSubjets
# TimeReport   0.000000     0.000000     0.000000  trackVertexArbitrator
# TimeReport   0.000000     0.000000     0.000000  trackVertexArbitratorDefault
# TimeReport   0.000354     0.000354     0.000354  updatedPatJetsAK4PFCHSUpdated
# TimeReport   0.000102     0.000102     0.000102  updatedPatJetsAK8PFPuppiUpdated
# TimeReport   0.000481     0.000481     0.000481  updatedPatJetsTransientCorrectedAK4PFCHSUpdated
# TimeReport   0.000000     0.000000     0.000000  updatedPatJetsTransientCorrectedAK4PFCHSUpdatedPATJetswithUserData
# TimeReport   0.000000     0.000000     0.000000  updatedPatJetsTransientCorrectedAK4PFCHSUpdatedlooseJetId
# TimeReport   0.000000     0.000000     0.000000  updatedPatJetsTransientCorrectedAK4PFCHSUpdatedtightJetId
# TimeReport   0.000000     0.000000     0.000000  updatedPatJetsTransientCorrectedAK4PFCHSUpdatedtightJetIdLepVeto
# TimeReport   0.000109     0.000109     0.000109  updatedPatJetsTransientCorrectedAK8PFPuppiUpdated
# TimeReport   0.000000     0.000000     0.000000  updatedPatJetsTransientCorrectedAK8PFPuppiUpdatedPATJetswithUserData
# TimeReport   0.000000     0.000000     0.000000  updatedPatJetsTransientCorrectedAK8PFPuppiUpdatedlooseJetId
# TimeReport   0.000000     0.000000     0.000000  updatedPatJetsTransientCorrectedAK8PFPuppiUpdatedtightJetId
# TimeReport   0.000000     0.000000     0.000000  updatedPatJetsTransientCorrectedAK8PFPuppiUpdatedtightJetIdLepVeto
# TimeReport   0.000000     0.000000     0.000000  vertexMerger
# TimeReport  per event     per exec    per visit  Name
#
# T---Report end!
#
#
# =============================================
#
# MessageLogger Summary
#
#  type     category        sev    module        subroutine        count    total
#  ---- -------------------- -- ---------------- ----------------  -----    -----
#     1 XrdAdaptor           -w (NoModuleName)                         1        1
#     2 XrdAdaptor           -w file_open                              1        1
#     3 XrdAdaptor           -w source                                 1        1
#     4 XrdAdaptorInternal   -w file_open                              2        2
#     5 fileAction           -s file_close                             1        1
#     6 fileAction           -s file_open                              3        3
#
#  type    category    Examples: run/evt        run/evt          run/evt
#  ---- -------------------- ---------------- ---------------- ----------------
#     1 XrdAdaptor           pre-events
#     2 XrdAdaptor           pre-events
#     3 XrdAdaptor           PostStreamBeginL
#     4 XrdAdaptorInternal   pre-events       pre-events
#     5 fileAction           PostGlobalEndRun
#     6 fileAction           pre-events       pre-events       pre-events
#
# Severity    # Occurrences   Total Occurrences
# --------    -------------   -----------------
# Warning                 5                   5
# System                  4                   4
#
# dropped waiting message count 0

# %% [markdown]
# Running the jetToolbox as explained above does create a miniAOD-like output. To know the name of the newly create jet collection, jetToolbox prints out some information like this:
# ```
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK8 JETS USING Puppi
# |---- jetToolBox: Applying these corrections: ('AK8PFPuppi', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsAK8PFPuppiSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ak8PFJetsPuppiSoftDropMass, selectedPatJetsAK8PFPuppiSoftDropPacked:SubJets, ak8PFJetsPuppiPrunedMass, ak8PFJetsPuppiTrimmedMass, ak8PFJetsPuppiFilteredMass, NjettinessAK8Puppi, nb1AK8PuppiSoftDrop.
# |---- jetToolBox: Creating selectedPatJetsAK8PFPuppi collection.
# ```
#
# The name of the new jet collection in this case will be `selectedPatJetsAK8PFPuppi`. To access it, you can follow the same procedure you did for the `slimmedJets` or `slimmedAK8Jets` in the miniAOD example above.

# %% [markdown]
# Because the nanoAOD format is becoming very popular in CMS, there is a "beta" version of the jetToolbox which will create nanoAOD-like samples including new jet collections. For example, to create a nanoAOD like sample, you need to include a file like the one below in your folder `$CMSSW_BASE/src/Analysis/JMEDAS/python/`:
#
# <details>
#     <summary><font color='blue'>SHOW CODE</font></summary>
# <p>
#
# ```python
# import FWCore.ParameterSet.Config as cms
# from  PhysicsTools.NanoAOD.common_cff import *
# ### NanoAOD v5 (for 2016,2017,2018), for different recipe please modify accordingly
# from Configuration.Eras.Modifier_run2_nanoAOD_94X2016_cff import run2_nanoAOD_94X2016
# from Configuration.Eras.Modifier_run2_nanoAOD_94XMiniAODv2_cff import run2_nanoAOD_94XMiniAODv2
# from Configuration.Eras.Modifier_run2_nanoAOD_102Xv1_cff import run2_nanoAOD_102Xv1
# from JMEAnalysis.JetToolbox.jetToolbox_cff import jetToolbox
#
# # ---------------------------------------------------------
# # This is the part the user should modify
# def setupCustomizedJetToolbox(process):
#
#     #### AK4 PUPPI jets
#
#     ak4btagdiscriminators = [
#             'pfDeepCSVJetTags:probb',
#             'pfDeepCSVJetTags:probbb',
#             'pfDeepCSVJetTags:probc',
#             'pfDeepCSVJetTags:probudsg',
#     ]
#     ak4btaginfos = [ 'pfDeepCSVTagInfos' ]
#
#     jetToolbox(process, 'ak4', 'dummyseq', 'noOutput',
#                dataTier='nanoAOD',
#                PUMethod='Puppi', JETCorrPayload='AK4PFPuppi',
#                #addQGTagger=True,
#                runOnMC=True,
#                Cut='pt > 15.0 && abs(eta) < 2.4',
#                bTagDiscriminators=ak4btagdiscriminators,
#                bTagInfos=ak4btaginfos,
#                verbosity=4
#                )
#
#     #### AK8 PUPPI jets
#     ak8btagdiscriminators = [
#                         'pfBoostedDoubleSecondaryVertexAK8BJetTags',
#                         'pfMassIndependentDeepDoubleBvLJetTags:probQCD',
#                         'pfMassIndependentDeepDoubleBvLJetTags:probHbb',
#                         'pfMassIndependentDeepDoubleCvLJetTags:probQCD',
#                         'pfMassIndependentDeepDoubleCvLJetTags:probHcc',
#                         'pfMassIndependentDeepDoubleCvBJetTags:probHbb',
#                         'pfMassIndependentDeepDoubleCvBJetTags:probHcc',
#             ]
#
#     jetToolbox(process, 'ak8', 'adummyseq', 'noOutput',
#                dataTier='nanoAOD',
#                PUMethod='Puppi', JETCorrPayload='AK8PFPuppi',
#                runOnMC=True,
#                Cut='pt > 170.0 && abs(eta) < 2.4',
#                bTagDiscriminators=ak8btagdiscriminators,
#                addSoftDrop=True,
#                addSoftDropSubjets=True,
#                addPruning=True,
#                addNsub=True,
#                addEnergyCorrFunc=True,
#                )
#     return process
#
# # ---------------------------------------------------------
#
# def nanoJTB_customizeMC(process):
#     run2_nanoAOD_94X2016.toModify(process, setupCustomizedJetToolbox)
#     run2_nanoAOD_94XMiniAODv2.toModify(process, setupCustomizedJetToolbox)
#     run2_nanoAOD_102Xv1.toModify(process, setupCustomizedJetToolbox)
#     process.NANOAODSIMoutput.fakeNameForCrab = cms.untracked.bool(True)  # needed for crab publication
#     return process
#
# ```
#
# </p>
# </details>
#
# This file is already included in this tutorial. _Do not try to copy this file in your working directory._
#
# Then to create a nanoAOD-like file, run the next line in your terminal, or in the next cell.

# %%
# %%bash
# cmsDriver.py nanoAOD_jetToolbox_cff -s NANO --mc --eventcontent NANOAODSIM --datatier NANOAODSIM -n 100  --conditions 102X_upgrade2018_realistic_v20 --era Run2_2018,run2_nanoAOD_102Xv1 --customise_commands="process.add_(cms.Service('InitRootHandlers', EnableIMT = cms.untracked.bool(False)))" --customise Analysis/JMEDAS/nanoAOD_jetToolbox_cff.nanoJTB_customizeMC --filein /store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root --fileout file:jetToolbox_nano_mc.root
# Out:
# NANO,ENDJOB
# entry /store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root
# Step: NANO Spec:
# Step: ENDJOB Spec:
# customising the process with nanoAOD_customizeMC from PhysicsTools/NanoAOD/nano_cff
# Updating process to run DeepBoostedJet on datasets before 103X
# Updating process to run DeepDoubleX on datasets before 104X
# Will recalculate the following discriminators on AK8 jets: pfDeepBoostedJetTags:probTbcq, pfDeepBoostedJetTags:probTbqq, pfDeepBoostedJetTags:probTbc, pfDeepBoostedJetTags:probTbq, pfDeepBoostedJetTags:probWcq, pfDeepBoostedJetTags:probWqq, pfDeepBoostedJetTags:probZbb, pfDeepBoostedJetTags:probZcc, pfDeepBoostedJetTags:probZqq, pfDeepBoostedJetTags:probHbb, pfDeepBoostedJetTags:probHcc, pfDeepBoostedJetTags:probHqqqq, pfDeepBoostedJetTags:probQCDbb, pfDeepBoostedJetTags:probQCDcc, pfDeepBoostedJetTags:probQCDb, pfDeepBoostedJetTags:probQCDc, pfDeepBoostedJetTags:probQCDothers, pfDeepBoostedDiscriminatorsJetTags:TvsQCD, pfDeepBoostedDiscriminatorsJetTags:WvsQCD, pfDeepBoostedDiscriminatorsJetTags:ZvsQCD, pfDeepBoostedDiscriminatorsJetTags:ZbbvsQCD, pfDeepBoostedDiscriminatorsJetTags:HbbvsQCD, pfDeepBoostedDiscriminatorsJetTags:H4qvsQCD, pfMassDecorrelatedDeepBoostedJetTags:probTbcq, pfMassDecorrelatedDeepBoostedJetTags:probTbqq, pfMassDecorrelatedDeepBoostedJetTags:probTbc, pfMassDecorrelatedDeepBoostedJetTags:probTbq, pfMassDecorrelatedDeepBoostedJetTags:probWcq, pfMassDecorrelatedDeepBoostedJetTags:probWqq, pfMassDecorrelatedDeepBoostedJetTags:probZbb, pfMassDecorrelatedDeepBoostedJetTags:probZcc, pfMassDecorrelatedDeepBoostedJetTags:probZqq, pfMassDecorrelatedDeepBoostedJetTags:probHbb, pfMassDecorrelatedDeepBoostedJetTags:probHcc, pfMassDecorrelatedDeepBoostedJetTags:probHqqqq, pfMassDecorrelatedDeepBoostedJetTags:probQCDbb, pfMassDecorrelatedDeepBoostedJetTags:probQCDcc, pfMassDecorrelatedDeepBoostedJetTags:probQCDb, pfMassDecorrelatedDeepBoostedJetTags:probQCDc, pfMassDecorrelatedDeepBoostedJetTags:probQCDothers, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:TvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:WvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZHbbvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZbbvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:HbbvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:H4qvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZHccvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:bbvsLight, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ccvsLight, pfDeepDoubleBvLJetTags:probHbb, pfDeepDoubleCvLJetTags:probHcc, pfDeepDoubleCvBJetTags:probHcc, pfMassIndependentDeepDoubleBvLJetTags:probHbb, pfMassIndependentDeepDoubleCvLJetTags:probHcc, pfMassIndependentDeepDoubleCvBJetTags:probHcc
# customising the process with nanoJTB_customizeMC from Analysis/JMEDAS/nanoAOD_jetToolbox_cff
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfDeepCSVJetTags:probb', 'pfDeepCSVJetTags:probbb', 'pfDeepCSVJetTags:probc', 'pfDeepCSVJetTags:probudsg'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK4 JETS USING Puppi
# |---- jetToolBox: Applying these corrections: ('AK4PFPuppi', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating selectedPatJetsAK4PFPuppi collection.
# |---- jetToolBox: RUNNING FROM MINIAOD BUT STORING VARIABLES IN NANOAOD FORMAT.
# |---- jetToolBox: List of modules created (and other internal names):
#       PATJetsLabel = AK4PFPuppi
#       PATJetsLabelPost = AK4PFPuppi
#       SubstructureLabel = AK4Puppi
#       GenJetsNoNu = ak4GenJetsNoNu
#       GenParticlesNoNu = packedGenParticlesForJetsNoNu
#       PFJets = ak4PFJetsPuppi
#       PFJetsConstituents = ak4PFJetsPuppiCoUpdating process to run DeepBoostedJet on datasets before 103X
# Updating process to run DeepDoubleX on datasets before 104X
# Will recalculate the following discriminators on AK8 jets: pfDeepBoostedJetTags:probTbcq, pfDeepBoostedJetTags:probTbqq, pfDeepBoostedJetTags:probTbc, pfDeepBoostedJetTags:probTbq, pfDeepBoostedJetTags:probWcq, pfDeepBoostedJetTags:probWqq, pfDeepBoostedJetTags:probZbb, pfDeepBoostedJetTags:probZcc, pfDeepBoostedJetTags:probZqq, pfDeepBoostedJetTags:probHbb, pfDeepBoostedJetTags:probHcc, pfDeepBoostedJetTags:probHqqqq, pfDeepBoostedJetTags:probQCDbb, pfDeepBoostedJetTags:probQCDcc, pfDeepBoostedJetTags:probQCDb, pfDeepBoostedJetTags:probQCDc, pfDeepBoostedJetTags:probQCDothers, pfDeepBoostedDiscriminatorsJetTags:TvsQCD, pfDeepBoostedDiscriminatorsJetTags:WvsQCD, pfDeepBoostedDiscriminatorsJetTags:ZvsQCD, pfDeepBoostedDiscriminatorsJetTags:ZbbvsQCD, pfDeepBoostedDiscriminatorsJetTags:HbbvsQCD, pfDeepBoostedDiscriminatorsJetTags:H4qvsQCD, pfMassDecorrelatedDeepBoostedJetTags:probTbcq, pfMassDecorrelatedDeepBoostedJetTags:probTbqq, pfMassDecorrelatedDeepBoostedJetTags:probTbc, pfMassDecorrelatedDeepBoostedJetTags:probTbq, pfMassDecorrelatedDeepBoostedJetTags:probWcq, pfMassDecorrelatedDeepBoostedJetTags:probWqq, pfMassDecorrelatedDeepBoostedJetTags:probZbb, pfMassDecorrelatedDeepBoostedJetTags:probZcc, pfMassDecorrelatedDeepBoostedJetTags:probZqq, pfMassDecorrelatedDeepBoostedJetTags:probHbb, pfMassDecorrelatedDeepBoostedJetTags:probHcc, pfMassDecorrelatedDeepBoostedJetTags:probHqqqq, pfMassDecorrelatedDeepBoostedJetTags:probQCDbb, pfMassDecorrelatedDeepBoostedJetTags:probQCDcc, pfMassDecorrelatedDeepBoostedJetTags:probQCDb, pfMassDecorrelatedDeepBoostedJetTags:probQCDc, pfMassDecorrelatedDeepBoostedJetTags:probQCDothers, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:TvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:WvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZHbbvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZbbvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:HbbvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:H4qvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ZHccvsQCD, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:bbvsLight, pfMassDecorrelatedDeepBoostedDiscriminatorsJetTags:ccvsLight, pfDeepDoubleBvLJetTags:probHbb, pfDeepDoubleCvLJetTags:probHcc, pfDeepDoubleCvBJetTags:probHcc, pfMassIndependentDeepDoubleBvLJetTags:probHbb, pfMassIndependentDeepDoubleCvLJetTags:probHcc, pfMassIndependentDeepDoubleCvBJetTags:probHcc
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfDeepCSVJetTags:probb', 'pfDeepCSVJetTags:probbb', 'pfDeepCSVJetTags:probc', 'pfDeepCSVJetTags:probudsg'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK4 JETS USING Puppi
# |---- jetToolBox: Applying these corrections: ('AK4PFPuppi', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating selectedPatJetsAK4PFPuppi collection.
# |---- jetToolBox: RUNNING FROM MINIAOD BUT STORING VARIABLES IN NANOAOD FORMAT.
# |---- jetToolBox: List of modules created (and other internal names):
#       PATJetsLabel = AK4PFPuppi
#       PATJetsLabelPost = AK4PFPuppi
#       SubstructureLabel = AK4Puppi
#       GenJetsNoNu = ak4GenJetsNoNu
#       GenParticlesNoNu = packedGenParticlesForJetsNoNu
#       PFJets = ak4PFJetsPuppi
#       PFJetsConstituents = ak4PFJetsPuppiConstituents
#       PFJetsConstituentsColon = ak4PFJetsPuppiConstituents:constituents
#       PFJetsConstituentsColonOrUpdate = ak4PFJetsPuppiConstituents:constituents
#       PATJets = patJetsAK4PFPuppi
#       selPATJets = selectedPatJetsAK4PFPuppi
#       PFJetsOrUpdate = ak4PFJetsPuppi
#       looseJetId = patJetsAK4PFPuppilooseJetId
#       tightJetId = patJetsAK4PFPuppitightJetId
#       tightJetIdLepVeto = patJetsAK4PFPuppitightJetIdLepVeto
#       PATJetswithUserData = patJetsAK4PFPuppiPATJetswithUserData
#       jetToolboxGenJetTable = ak4GenJetsNoNuJTBTable
#       jetToolboxJetTable = selectedPatJetsAK4PFPuppiJTBTable
# |---- jetToolbox: Initializing collection... (with postfix )
# |---- jetToolBox: Adding these btag discriminators: ['pfCombinedInclusiveSecondaryVertexV2BJetTags', 'pfCombinedCvsLJetTags', 'pfCombinedCvsBJetTags'] in the subjet collection.
# |---- jetToolBox: Adding these btag discriminators: ['pfBoostedDoubleSecondaryVertexAK8BJetTags', 'pfMassIndependentDeepDoubleBvLJetTags:probQCD', 'pfMassIndependentDeepDoubleBvLJetTags:probHbb', 'pfMassIndependentDeepDoubleCvLJetTags:probQCD', 'pfMassIndependentDeepDoubleCvLJetTags:probHcc', 'pfMassIndependentDeepDoubleCvBJetTags:probHbb', 'pfMassIndependentDeepDoubleCvBJetTags:probHcc'] in the jet collection.
# |---- jetToolBox: DeepCSV and DeepFlavour btag discriminators were trained for AK4 CHS jets. You are trying to use it in other configuration. Use it at your own risk.
# |---- jetToolBox: JETTOOLBOX RUNNING ON MiniAOD FOR AK8 JETS USING Puppi
# |---- jetToolBox: Applying these corrections: ('AK8PFPuppi', ['L2Relative', 'L3Absolute'], 'None')
# |---- jetToolBox: Creating packedPatJetsAK8PFPuppiSoftDrop collection with SoftDrop subjets.
# |---- jetToolBox: Running ak8PFJetsPuppiSoftDropMass, selectedPatJetsAK8PFPuppiSoftDropPacked:SubJets, ak8PFJetsPuppiPrunedMass, NjettinessAK8Puppi, nb1AK8PuppiSoftDrop.
# |---- jetToolBox: Creating selectedPatJetsAK8PFPuppi collection.
# |---- jetToolBox: RUNNING FROM MINIAOD BUT STORING VARIABLES IN NANOAOD FORMAT.
#                          : Booking "JetReg" of type "BDT" from /cvmfs/cms.cern.ch/slc7_amd64_gcc820/cms/cmssw/CMSSW_10_6_6/external/slc7_amd64_gcc820/data/PhysicsTools/NanoAOD/data/bjet-regression.xml.
#                          : Reading weight file: /cvmfs/cms.cern.ch/slc7_amd64_gcc820/cms/cmssw/CMSSW_10_6_6/external/slc7_amd64_gcc820/data/PhysicsTools/NanoAOD/data/bjet-regression.xml
# <HEADER> DataSetInfo              : [Default] : Added class "Regression"
#                          : Booked classifier "BDTG" of type: "BDT"
#                          : Booking "muonMVATTH" of type "BDT" from /cvmfs/cms.cern.ch/slc7_amd64_gcc820/cms/cmssw/CMSSW_10_6_6/external/slc7_amd64_gcc820/data/PhysicsTools/NanoAOD/data/mu_BDTG_2017.weights.xml.
#                          : Reading weight file: /cvmfs/cms.cern.ch/slc7_amd64_gcc820/cms/cmssw/CMSSW_10_6_6/external/slc7_amd64_gcc820/data/PhysicsTools/NanoAOD/data/mu_BDTG_2017.weights.xml
# <HEADER> DataSetInfo              : [Default] : Added class "Signal"
# <HEADER> DataSetInfo              : [Default] : Added class "Background"
#                          : Booked classifier "BDTG" of type: "BDT"
#                          : Booking "muonMVALowPt" of type "BDT" from /cvmfs/cms.cern.ch/slc7_amd64_gcc820/cms/cmssw/CMSSW_10_6_6/external/slc7_amd64_gcc820/data/PhysicsTools/NanoAOD/data/mu_BDTG_lowpt.weights.xml.
#                          : Reading weight file: /cvmfs/cms.cern.ch/slc7_amd64_gcc820/cms/cmssw/CMSSW_10_6_6/external/slc7_amd64_gcc820/data/PhysicsTools/NanoAOD/data/mu_BDTG_lowpt.weights.xml
# <HEADER> DataSetInfo              : [Default] : Added class "Signal"
# <HEADER> DataSetInfo              : [Default] : Added class "Background"
#                          : Booked classifier "BDTG" of type: "BDT"
#                          : Booking "electronMVATTH" of type "BDT" from /cvmfs/cms.cern.ch/slc7_amd64_gcc820/cms/cmssw/CMSSW_10_6_6/external/slc7_amd64_gcc820/data/PhysicsTools/NanoAOD/data/el_BDTG_2017.weights.xml.
#                          : Reading weight file: /cvmfs/cms.cern.ch/slc7_amd64_gcc820/cms/cmssw/CMSSW_10_6_6/external/slc7_amd64_gcc820/data/PhysicsTools/NanoAOD/data/el_BDTG_2017.weights.xml
# <HEADER> DataSetInfo              : [Default] : Added class "Signal"
# <HEADER> DataSetInfo              : [Default] : Added class "Background"
#                          : Booked classifier "BDTG" of type: "BDT"
# Rivet.Analysis.Handler: WARN  Analysis 'HiggsTemplateCrossSections' is unvalidated: be careful, it may be broken!
# ==============================================================
# ========     HiggsTemplateCrossSections Initialization     =========
# ==============================================================
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  No HIGGSPRODMODE shell variable found. Needed when running Rivet stand-alone.
# ==============================================================
# ========             Higgs prod mode 0              =========
# ========          Sucessful Initialization           =========
# ==============================================================
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: WARN  Unkown Higgs production mechanism. Cannot classify event. Classification for all events will most likely fail.
# Rivet.Analysis.HiggsTemplateCrossSections: INFO   ======================================================
# Rivet.Analysis.HiggsTemplateCrossSections: INFO        Higgs Template X-Sec Categorization Tool
# Rivet.Analysis.HiggsTemplateCrossSections: INFO                  Status Code Summary
# Rivet.Analysis.HiggsTemplateCrossSections: INFO   ======================================================
# Rivet.Analysis.HiggsTemplateCrossSections: INFO       >>>> All 0 events successfully categorized!
# Rivet.Analysis.HiggsTemplateCrossSections: INFO   ======================================================
# Rivet.Analysis.HiggsTemplateCrossSections: INFO   ======================================================
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# -------------------------------------------------------------------
#  Info: To run c tagging on MiniAOD, c-tag-specific IVF secondary
#        vertices will be remade.
# -------------------------------------------------------------------
# 27-Aug-2020 19:29:05 CEST  Initiating request to open file root://eoscms.cern.ch//eos/cms/store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root
# %MSG-w XrdAdaptorInternal:  file_open 27-Aug-2020 19:29:06 CEST pre-events
# Failed to open file at URL root://eoscms.cern.ch:1094//eos/cms/store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root.
# %MSG
# %MSG-w XrdAdaptorInternal:  file_open 27-Aug-2020 19:29:06 CEST pre-events
# Failed to open file at URL root://eoscms.cern.ch:1094//eos/cms/store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root?tried=.
# %MSG
# 27-Aug-2020 19:29:06 CEST  Fallback request to file root://xrootd-cms.infn.it//store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root
# 27-Aug-2020 19:29:13 CEST  Successfully opened file root://xrootd-cms.infn.it//store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root
# 2020-08-27 19:29:25.820765: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# %MSG-w BTagSFProducer:  BTagSFProducer:btagWeightTable@ctor  27-Aug-2020 19:29:53 CEST pre-events
# Skipped loading BTagCalibration for CMVA as it was marked as unavailable in the configuration file. Event weights will not be stored.
#
# %MSG
# %MSG-w LogicError:  GenWeightsTableProducer:genWeightsTable@beginRun  27-Aug-2020 19:30:09 CEST Run: 1
# ::getByLabel: An attempt was made to read a Run product before endRun() was called.
# The product is of type 'LHERunInfoProduct'.
# The specified ModuleLabel was 'externalLHEProducer'.
# The specified productInstanceName was ''.
#
# %MSG
# %MSG-w LogicError:  HTXSRivetProducer:rivetProducerHTXS@beginRun  27-Aug-2020 19:30:09 CEST Run: 1
# ::getByLabel: An attempt was made to read a Run product before endRun() was called.
# The product is of type 'LHERunInfoProduct'.
# The specified ModuleLabel was 'externalLHEProducer'.
# The specified productInstanceName was ''.
#
# %MSG
# Begin processing the 1st record. Run 1, Event 60232781, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:02.075 CEST
# Begin processing the 2nd record. Run 1, Event 60232853, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:29.099 CEST
# Begin processing the 3rd record. Run 1, Event 60232812, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:29.599 CEST
# Begin processing the 4th record. Run 1, Event 60232757, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:30.288 CEST
# Begin processing the 5th record. Run 1, Event 60232827, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:31.165 CEST
# Begin processing the 6th record. Run 1, Event 60232833, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:31.515 CEST
# Begin processing the 7th record. Run 1, Event 60232764, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:31.894 CEST
# Begin processing the 8th record. Run 1, Event 60232846, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:32.320 CEST
# Begin processing the 9th record. Run 1, Event 60232862, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:32.661 CEST
# Begin processing the 10th record. Run 1, Event 60232761, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:33.086 CEST
# Begin processing the 11th record. Run 1, Event 60232760, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:33.412 CEST
# Begin processing the 12th record. Run 1, Event 60232748, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:33.845 CEST
# Begin processing the 13th record. Run 1, Event 60233047, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:34.184 CEST
# Begin processing the 14th record. Run 1, Event 60232816, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:34.470 CEST
# Begin processing the 15th record. Run 1, Event 60232779, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:34.910 CEST
# Begin processing the 16th record. Run 1, Event 60232783, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:35.270 CEST
# Begin processing the 17th record. Run 1, Event 60232967, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:35.683 CEST
# Begin processing the 18th record. Run 1, Event 60232937, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:36.082 CEST
# Begin processing the 19th record. Run 1, Event 60232861, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:36.374 CEST
# Begin processing the 20th record. Run 1, Event 60233012, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:36.717 CEST
# Begin processing the 21st record. Run 1, Event 60233022, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:37.076 CEST
# Begin processing the 22nd record. Run 1, Event 60232994, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:38.457 CEST
# Begin processing the 23rd record. Run 1, Event 60233055, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:38.843 CEST
# Begin processing the 24th record. Run 1, Event 60233079, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:39.195 CEST
# Begin processing the 25th record. Run 1, Event 60233093, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:39.611 CEST
# Begin processing the 26th record. Run 1, Event 60233060, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:39.938 CEST
# Begin processing the 27th record. Run 1, Event 60233068, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:40.300 CEST
# Begin processing the 28th record. Run 1, Event 60233073, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:40.802 CEST
# Begin processing the 29th record. Run 1, Event 60233087, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:41.216 CEST
# Begin processing the 30th record. Run 1, Event 60233048, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:41.572 CEST
# Begin processing the 31st record. Run 1, Event 60233098, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:41.964 CEST
# Begin processing the 32nd record. Run 1, Event 60233071, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:42.331 CEST
# Begin processing the 33rd record. Run 1, Event 60233105, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:42.738 CEST
# Begin processing the 34th record. Run 1, Event 60233059, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:43.073 CEST
# Begin processing the 35th record. Run 1, Event 60233213, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:43.516 CEST
# Begin processing the 36th record. Run 1, Event 60233129, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:43.863 CEST
# Begin processing the 37th record. Run 1, Event 60233173, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:44.335 CEST
# Begin processing the 38th record. Run 1, Event 60233112, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:44.663 CEST
# Begin processing the 39th record. Run 1, Event 60233204, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:45.189 CEST
# Begin processing the 40th record. Run 1, Event 60233126, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:45.612 CEST
# Begin processing the 41st record. Run 1, Event 60233162, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:46.005 CEST
# Begin processing the 42nd record. Run 1, Event 60233224, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:46.246 CEST
# Begin processing the 43rd record. Run 1, Event 60233172, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:46.575 CEST
# Begin processing the 44th record. Run 1, Event 60233201, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:46.895 CEST
# Begin processing the 45th record. Run 1, Event 60233222, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:47.223 CEST
# Begin processing the 46th record. Run 1, Event 60233207, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:47.579 CEST
# Begin processing the 47th record. Run 1, Event 60233300, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:48.008 CEST
# Begin processing the 48th record. Run 1, Event 60233291, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:48.280 CEST
# Begin processing the 49th record. Run 1, Event 60233251, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:48.741 CEST
# Begin processing the 50th record. Run 1, Event 60233316, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:49.046 CEST
# Begin processing the 51st record. Run 1, Event 60233244, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:49.399 CEST
# Begin processing the 52nd record. Run 1, Event 60233243, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:49.741 CEST
# Begin processing the 53rd record. Run 1, Event 60233336, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:50.076 CEST
# Begin processing the 54th record. Run 1, Event 60233294, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:50.426 CEST
# Begin processing the 55th record. Run 1, Event 60233418, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:50.719 CEST
# Begin processing the 56th record. Run 1, Event 60233390, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:50.964 CEST
# Begin processing the 57th record. Run 1, Event 60233234, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:51.206 CEST
# Begin processing the 58th record. Run 1, Event 60233451, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:51.718 CEST
# Begin processing the 59th record. Run 1, Event 60233333, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:52.026 CEST
# Begin processing the 60th record. Run 1, Event 60233544, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:52.465 CEST
# Begin processing the 61st record. Run 1, Event 60233508, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:52.713 CEST
# Begin processing the 62nd record. Run 1, Event 60233392, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:53.057 CEST
# Begin processing the 63rd record. Run 1, Event 60233436, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:53.492 CEST
# Begin processing the 64th record. Run 1, Event 60233464, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:53.812 CEST
# Begin processing the 65th record. Run 1, Event 60233525, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:54.041 CEST
# Begin processing the 66th record. Run 1, Event 60233639, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:54.369 CEST
# Begin processing the 67th record. Run 1, Event 60233428, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:54.676 CEST
# Begin processing the 68th record. Run 1, Event 60233372, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:55.068 CEST
# Begin processing the 69th record. Run 1, Event 60233595, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:55.416 CEST
# Begin processing the 70th record. Run 1, Event 60233465, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:55.812 CEST
# Begin processing the 71st record. Run 1, Event 60233714, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:56.207 CEST
# Begin processing the 72nd record. Run 1, Event 60233681, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:56.528 CEST
# Begin processing the 73rd record. Run 1, Event 60233699, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:56.880 CEST
# Begin processing the 74th record. Run 1, Event 60233494, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:57.261 CEST
# Begin processing the 75th record. Run 1, Event 60233732, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:57.661 CEST
# Begin processing the 76th record. Run 1, Event 60233722, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:58.008 CEST
# Begin processing the 77th record. Run 1, Event 60233763, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:58.274 CEST
# Begin processing the 78th record. Run 1, Event 60233628, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:58.687 CEST
# Begin processing the 79th record. Run 1, Event 60233780, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:59.175 CEST
# Begin processing the 80th record. Run 1, Event 60233651, LumiSection 4579 on stream 0 at 27-Aug-2020 19:31:59.496 CEST
# Begin processing the 81st record. Run 1, Event 60233752, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:00.087 CEST
# Begin processing the 82nd record. Run 1, Event 60233759, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:00.398 CEST
# Begin processing the 83rd record. Run 1, Event 60233774, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:00.750 CEST
# Begin processing the 84th record. Run 1, Event 60233657, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:01.215 CEST
# Begin processing the 85th record. Run 1, Event 60233779, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:01.761 CEST
# Begin processing the 86th record. Run 1, Event 60233869, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:02.128 CEST
# Begin processing the 87th record. Run 1, Event 60233962, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:02.462 CEST
# Begin processing the 88th record. Run 1, Event 60233961, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:02.831 CEST
# Begin processing the 89th record. Run 1, Event 60233761, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:03.292 CEST
# Begin processing the 90th record. Run 1, Event 60233951, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:03.934 CEST
# Begin processing the 91st record. Run 1, Event 60233860, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:04.288 CEST
# Begin processing the 92nd record. Run 1, Event 60233868, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:04.575 CEST
# Begin processing the 93rd record. Run 1, Event 60233806, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:05.003 CEST
# Begin processing the 94th record. Run 1, Event 60233971, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:05.432 CEST
# Begin processing the 95th record. Run 1, Event 60233978, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:05.826 CEST
# Begin processing the 96th record. Run 1, Event 60234111, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:06.150 CEST
# Begin processing the 97th record. Run 1, Event 60233984, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:06.503 CEST
# Begin processing the 98th record. Run 1, Event 60234081, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:06.919 CEST
# Begin processing the 99th record. Run 1, Event 60234105, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:07.291 CEST
# Begin processing the 100th record. Run 1, Event 60234011, LumiSection 4579 on stream 0 at 27-Aug-2020 19:32:07.531 CEST
# 27-Aug-2020 19:32:07 CEST  Closed file root://xrootd-cms.infn.it//store/mc/RunIIAutumn18MiniAOD/QCD_HT1000to1500_TuneCP5_13TeV-madgraphMLM-pythia8/MINIAODSIM/102X_upgrade2018_realistic_v15-v1/210000/DA20DC21-E781-C540-9FCD-7BCF2144CA4E.root
#
# =============================================
#
# MessageLogger Summary
#
#  type     category        sev    module        subroutine        count    total
#  ---- -------------------- -- ---------------- ----------------  -----    -----
#     1 BTagSFProducer       -w BTagSFProducer:b                       1        1
#     2 LogicError           -w GenWeightsTableP                       1        1
#     3 LogicError           -w HTXSRivetProduce                       1        1
#     4 XrdAdaptorInternal   -w file_open                              2        2
#     5 fileAction           -s file_close                             1        1
#     6 fileAction           -s file_open                              3        3
#
#  type    category    Examples: run/evt        run/evt          run/evt
#  ---- -------------------- ---------------- ---------------- ----------------
#     1 BTagSFProducer       pre-events
#     2 LogicError           Run: 1
#     3 LogicError           Run: 1
#     4 XrdAdaptorInternal   pre-events       pre-events
#     5 fileAction           PostGlobalEndRun
#     6 fileAction           pre-events       pre-events       pre-events
#
# Severity    # Occurrences   Total Occurrences
# --------    -------------   -----------------
# Warning                 5                   5
# System                  4                   4
#
# dropped waiting message count 0

# %% [markdown]
# The output file in this case, called `jetToolbox_nano_mc.root` will be a nanoAOD file with all the content from the central nanoAOD sample but including an extra collection which name starts with `selectedPatJetsAK8PFPuppi` (Or the name indicated in the jetToolbox print outs).
